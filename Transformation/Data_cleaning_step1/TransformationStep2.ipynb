# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(columns = [
    "Species",
    "Family",
    "BE",
    "Letzter_Nachweis",
    "Deutscher_Name",
    "Reference"
])
df
# Out:
# Empty DataFrame
# Columns: [Species, Family, BE, Letzter_Nachweis, Deutscher_Name, Reference]
# Index: []

# %%
import glob
filenames = glob.glob('*.csv')

# %%
filenames.sort()

# %%
dataframes = [pd.read_csv(f) for f in filenames]

# %%
i = 0
while i < 27:
    df = pd.concat([df, dataframes[i]], axis = 0)
    i = i + 1
df
# Out:
#                      Species            Family BE Letzter_Nachweis  \
# 0        Donacia brevicornis     Chrysomelidae  0         vor 1907
# 1            Donacia dentata     Chrysomelidae  0             1937
# 2            Donacia obscura     Chrysomelidae  0         vor 1907
# 3         Donacia thalassina     Chrysomelidae  0         vor 1950
# 4          Donacia tomentosa     Chrysomelidae  0             1943
# ..                       ...               ... ..              ...
# 31        Emberiza hortulana       Emberizidae  0              NaN
# 0   Barbastella barbastellus  Vespertilionidae  0              NaN
# 1          Cricetus cricetus        Cricetidae  0              NaN
# 2              Rattus rattus           Muridae  0              NaN
# 3             Cervus elaphus          Cervidae  0              NaN
#
#     Deutscher_Name                                          Reference
# 0              NaN  Rote Liste und Gesamtartenliste der Blattkäfer...
# 1              NaN  Rote Liste und Gesamtartenliste der Blattkäfer...
# 2              NaN  Rote Liste und Gesamtartenliste der Blattkäfer...
# 3              NaN  Rote Liste und Gesamtartenliste der Blattkäfer...
# 4              NaN  Rote Liste und Gesamtartenliste der Blattkäfer...
# ..             ...                                                ...
# 31         Ortolan  Rote Liste und Liste der Brutvögel (Aves) von ...
# 0   Mopsfledermaus  Rote Liste und Gesamtartenliste der Säugetiere...
# 1          Hamster  Rote Liste und Gesamtartenliste der Säugetiere...
# 2        Hausratte  Rote Liste und Gesamtartenliste der Säugetiere...
# 3        Rothirsch  Rote Liste und Gesamtartenliste der Säugetiere...
#
# [929 rows x 6 columns]

# %%
df.reset_index(drop=True, inplace = True)

# %%
df
# Out:
#                       Species            Family BE Letzter_Nachweis  \
# 0         Donacia brevicornis     Chrysomelidae  0         vor 1907
# 1             Donacia dentata     Chrysomelidae  0             1937
# 2             Donacia obscura     Chrysomelidae  0         vor 1907
# 3          Donacia thalassina     Chrysomelidae  0         vor 1950
# 4           Donacia tomentosa     Chrysomelidae  0             1943
# ..                        ...               ... ..              ...
# 924        Emberiza hortulana       Emberizidae  0              NaN
# 925  Barbastella barbastellus  Vespertilionidae  0              NaN
# 926         Cricetus cricetus        Cricetidae  0              NaN
# 927             Rattus rattus           Muridae  0              NaN
# 928            Cervus elaphus          Cervidae  0              NaN
#
#      Deutscher_Name                                          Reference
# 0               NaN  Rote Liste und Gesamtartenliste der Blattkäfer...
# 1               NaN  Rote Liste und Gesamtartenliste der Blattkäfer...
# 2               NaN  Rote Liste und Gesamtartenliste der Blattkäfer...
# 3               NaN  Rote Liste und Gesamtartenliste der Blattkäfer...
# 4               NaN  Rote Liste und Gesamtartenliste der Blattkäfer...
# ..              ...                                                ...
# 924         Ortolan  Rote Liste und Liste der Brutvögel (Aves) von ...
# 925  Mopsfledermaus  Rote Liste und Gesamtartenliste der Säugetiere...
# 926         Hamster  Rote Liste und Gesamtartenliste der Säugetiere...
# 927       Hausratte  Rote Liste und Gesamtartenliste der Säugetiere...
# 928       Rothirsch  Rote Liste und Gesamtartenliste der Säugetiere...
#
# [929 rows x 6 columns]
