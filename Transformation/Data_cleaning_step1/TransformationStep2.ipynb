# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(columns = [
    "Species",
    "Family",
    "BE",
    "Letzter_Nachweis",
    "Deutscher_Name",
    "Reference"
])
df
# Out:
# Empty DataFrame
# Columns: [Species, Family, BE, Letzter_Nachweis, Deutscher_Name, Reference]
# Index: []

# %%
import glob
filenames = glob.glob('*.csv')

# %%
filenames.sort()

# %%
dataframes = [pd.read_csv(f) for f in filenames]

# %%
i = 0
while i < 20:
    df = pd.concat([df, dataframes[i]], axis = 0)
    i = i + 1
df
# Out:
#                  Species         Family BE Letzter_Nachweis  \
# 0    Donacia brevicornis  Chrysomelidae  0         vor 1907
# 1        Donacia dentata  Chrysomelidae  0             1937
# 2        Donacia obscura  Chrysomelidae  0         vor 1907
# 3     Donacia thalassina  Chrysomelidae  0         vor 1950
# 4      Donacia tomentosa  Chrysomelidae  0             1943
# ..                   ...            ... ..              ...
# 145    Xestia stigmatica      Noctuidae  0       x vor 1900
# 146      Xestia castanea      Noctuidae  0       x vor 1900
# 147    Xestia ashworthii      Noctuidae  0       x vor 1900
# 148       Eugraphe sigma      Noctuidae  0       x vor 1900
# 149  Protolampra sobrina      Noctuidae  0       x vor 1900
#
#               Deutscher_Name  \
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ..                       ...
# 145        Rhombus-Bodeneule
# 146  Ginsterheiden-Bodeneule
# 147      Aschgraue Bodeneule
# 148          Sigma-Bodeneule
# 149      Heidemoor-Bodeneule
#
#                                              Reference
# 0    Rote Liste und Gesamtartenliste der Blattkäfer...
# 1    Rote Liste und Gesamtartenliste der Blattkäfer...
# 2    Rote Liste und Gesamtartenliste der Blattkäfer...
# 3    Rote Liste und Gesamtartenliste der Blattkäfer...
# 4    Rote Liste und Gesamtartenliste der Blattkäfer...
# ..                                                 ...
# 145  Rote Liste und Gesamtartenliste der Großschmet...
# 146  Rote Liste und Gesamtartenliste der Großschmet...
# 147  Rote Liste und Gesamtartenliste der Großschmet...
# 148  Rote Liste und Gesamtartenliste der Großschmet...
# 149  Rote Liste und Gesamtartenliste der Großschmet...
#
# [818 rows x 6 columns]

# %%
df.reset_index(drop=True, inplace = True)

# %%
df
# Out:
#                  Species         Family BE Letzter_Nachweis  \
# 0    Donacia brevicornis  Chrysomelidae  0         vor 1907
# 1        Donacia dentata  Chrysomelidae  0             1937
# 2        Donacia obscura  Chrysomelidae  0         vor 1907
# 3     Donacia thalassina  Chrysomelidae  0         vor 1950
# 4      Donacia tomentosa  Chrysomelidae  0             1943
# ..                   ...            ... ..              ...
# 813    Xestia stigmatica      Noctuidae  0       x vor 1900
# 814      Xestia castanea      Noctuidae  0       x vor 1900
# 815    Xestia ashworthii      Noctuidae  0       x vor 1900
# 816       Eugraphe sigma      Noctuidae  0       x vor 1900
# 817  Protolampra sobrina      Noctuidae  0       x vor 1900
#
#               Deutscher_Name  \
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ..                       ...
# 813        Rhombus-Bodeneule
# 814  Ginsterheiden-Bodeneule
# 815      Aschgraue Bodeneule
# 816          Sigma-Bodeneule
# 817      Heidemoor-Bodeneule
#
#                                              Reference
# 0    Rote Liste und Gesamtartenliste der Blattkäfer...
# 1    Rote Liste und Gesamtartenliste der Blattkäfer...
# 2    Rote Liste und Gesamtartenliste der Blattkäfer...
# 3    Rote Liste und Gesamtartenliste der Blattkäfer...
# 4    Rote Liste und Gesamtartenliste der Blattkäfer...
# ..                                                 ...
# 813  Rote Liste und Gesamtartenliste der Großschmet...
# 814  Rote Liste und Gesamtartenliste der Großschmet...
# 815  Rote Liste und Gesamtartenliste der Großschmet...
# 816  Rote Liste und Gesamtartenliste der Großschmet...
# 817  Rote Liste und Gesamtartenliste der Großschmet...
#
# [818 rows x 6 columns]
