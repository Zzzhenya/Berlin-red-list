# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(columns = [
    "Species",
    "Family",
    "BE",
    "Letzter_Nachweis",
    "Deutscher_Name",
    "Reference"
])
df
# Out:
# Empty DataFrame
# Columns: [Species, Family, BE, Letzter_Nachweis, Deutscher_Name, Reference]
# Index: []

# %%
import glob
filenames = glob.glob('*.csv')

# %%
filenames.sort()

# %%
dataframes = [pd.read_csv(f) for f in filenames]

# %%
i = 0
while i < 34:
    df = pd.concat([df, dataframes[i]], axis = 0)
    i = i + 1
df
# Out:
#                 Species         Family BE Letzter_Nachweis Deutscher_Name  \
# 0   Donacia brevicornis  Chrysomelidae  0         vor 1907            NaN
# 1       Donacia dentata  Chrysomelidae  0             1937            NaN
# 2       Donacia obscura  Chrysomelidae  0         vor 1907            NaN
# 3    Donacia thalassina  Chrysomelidae  0         vor 1950            NaN
# 4     Donacia tomentosa  Chrysomelidae  0             1943            NaN
# ..                  ...            ... ..              ...            ...
# 6   Nitella confervacea      Characeae  0              NaN            NaN
# 7      Nitella gracilis      Characeae  0              NaN            NaN
# 8         Nitella opaca      Characeae  0              NaN            NaN
# 9    Nitella tenuissima      Characeae  0              NaN            NaN
# 10  Tolypella intricata      Characeae  0              NaN            NaN
#
#                                             Reference
# ...

# %%
df.reset_index(drop=True, inplace = True)

# %%
df
# Out:
#                   Species         Family BE Letzter_Nachweis Deutscher_Name  \
# 0     Donacia brevicornis  Chrysomelidae  0         vor 1907            NaN
# 1         Donacia dentata  Chrysomelidae  0             1937            NaN
# 2         Donacia obscura  Chrysomelidae  0         vor 1907            NaN
# 3      Donacia thalassina  Chrysomelidae  0         vor 1950            NaN
# 4       Donacia tomentosa  Chrysomelidae  0             1943            NaN
# ...                   ...            ... ..              ...            ...
# 1407  Nitella confervacea      Characeae  0              NaN            NaN
# 1408     Nitella gracilis      Characeae  0              NaN            NaN
# 1409        Nitella opaca      Characeae  0              NaN            NaN
# 1410   Nitella tenuissima      Characeae  0              NaN            NaN
# 1411  Tolypella intricata      Characeae  0              NaN            NaN
#
#                                               Reference
# ...

# %%
# Saving the transformed dataframe to Data_cleaning_step2
# export the dataframe as CSV

df.to_csv('../../Transformation/Data_cleaning_step2/Extinct_species_without_meta.csv', 
          index=False)
