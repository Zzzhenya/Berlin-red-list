# %%
import pandas as pd
import numpy as np
from pygbif import species

# %% [markdown]
# # 01.  Chrysomelidae_ Megalopodidae_Blattkäfer.csv

# %%
# Read file into dataframe

df = pd.read_csv('Chrysomelidae_ Megalopodidae_Blattkäfer.csv')
df.head()
# Out:
#                                       Species  BE Bestand  Trend_lang  \
# 0            Donacia brevicornis AHRENS, 1810   0      ex         NaN
# 1                 Donacia dentata HOPPE, 1795   0      ex         NaN
# 2             Donacia obscura GYLLENHAL, 1813   0      ex         NaN
# 3  Donacia thalassina thalassina GERMAR, 1811   0      ex         NaN
# 4              Donacia tomentosa AHRENS, 1810   0      ex         NaN
#
#    Trend_kurz  RF   BB  D                GfU Letzter_Nachweis          Quelle
# 0         NaN NaN  NaN  2   1c, 2d, 3b, 11c,         vor 1907  REINECK (1907)
# 1         NaN NaN    2  2  1c, 11c, 14a, 14g             1937        CHRYFAUN
# 2         NaN NaN    2  1   1c, 2d, 8b, 11c,         vor 1907  REINECK (1907)
# 3         NaN NaN    p  V  1c, 2d, 11c, 14a,         vor 1950     MOHR (1985)
# 4         NaN NaN    0  1  1c, 2d, 11c, 14a,             1943        CHRYFAUN

# %%
df.describe(include = 'all')
# Out:
#                                  Species    BE Bestand  Trend_lang  \
# count                                 32  32.0      32         0.0
# unique                                32   NaN       1         NaN
# top     Donacia brevicornis AHRENS, 1810   NaN      ex         NaN
# freq                                   1   NaN      32         NaN
# mean                                 NaN   0.0     NaN         NaN
# std                                  NaN   0.0     NaN         NaN
# min                                  NaN   0.0     NaN         NaN
# 25%                                  NaN   0.0     NaN         NaN
# 50%                                  NaN   0.0     NaN         NaN
# 75%                                  NaN   0.0     NaN         NaN
# max                                  NaN   0.0     NaN         NaN
#
#         Trend_kurz   RF   BB    D  GfU Letzter_Nachweis    Quelle
# count          0.0  0.0   17   32   32               32        32
# unique         NaN  NaN    5    7   27               20        20
# top            NaN  NaN    0    3  14a         vor 1950  CHRYFAUN
# freq           NaN  NaN    6   10    3                9         6
# mean           NaN  NaN  NaN  NaN  NaN              NaN       NaN
# std            NaN  NaN  NaN  NaN  NaN              NaN       NaN
# min            NaN  NaN  NaN  NaN  NaN              NaN       NaN
# 25%            NaN  NaN  NaN  NaN  NaN              NaN       NaN
# 50%            NaN  NaN  NaN  NaN  NaN              NaN       NaN
# 75%            NaN  NaN  NaN  NaN  NaN              NaN       NaN
# max            NaN  NaN  NaN  NaN  NaN              NaN       NaN

# %%
df.Trend_lang.isna().sum()
# Out:
# 32

# %%
df.Trend_kurz.isna().sum()
# Out:
# 32

# %%
# dropping Trend_kurz and Trend_lang columns

df.drop(columns = ["Trend_kurz", "Trend_lang"], inplace = True)

# %%
df.describe(include = 'all')
# Out:
#                                  Species    BE Bestand   RF   BB    D  GfU  \
# count                                 32  32.0      32  0.0   17   32   32
# unique                                32   NaN       1  NaN    5    7   27
# top     Donacia brevicornis AHRENS, 1810   NaN      ex  NaN    0    3  14a
# freq                                   1   NaN      32  NaN    6   10    3
# mean                                 NaN   0.0     NaN  NaN  NaN  NaN  NaN
# std                                  NaN   0.0     NaN  NaN  NaN  NaN  NaN
# min                                  NaN   0.0     NaN  NaN  NaN  NaN  NaN
# 25%                                  NaN   0.0     NaN  NaN  NaN  NaN  NaN
# 50%                                  NaN   0.0     NaN  NaN  NaN  NaN  NaN
# 75%                                  NaN   0.0     NaN  NaN  NaN  NaN  NaN
# max                                  NaN   0.0     NaN  NaN  NaN  NaN  NaN
#
#        Letzter_Nachweis    Quelle
# count                32        32
# unique               20        20
# top            vor 1950  CHRYFAUN
# freq                  9         6
# mean                NaN       NaN
# std                 NaN       NaN
# min                 NaN       NaN
# 25%                 NaN       NaN
# 50%                 NaN       NaN
# 75%                 NaN       NaN
# max                 NaN       NaN

# %%
df.RF.isna().sum()
# Out:
# 32

# %%
# Dropping RF Column
df.drop(columns = "RF", inplace = True)

# %%
df.head()
# Out:
#                                       Species  BE Bestand   BB  D  \
# 0            Donacia brevicornis AHRENS, 1810   0      ex  NaN  2
# 1                 Donacia dentata HOPPE, 1795   0      ex    2  2
# 2             Donacia obscura GYLLENHAL, 1813   0      ex    2  1
# 3  Donacia thalassina thalassina GERMAR, 1811   0      ex    p  V
# 4              Donacia tomentosa AHRENS, 1810   0      ex    0  1
#
#                  GfU Letzter_Nachweis          Quelle
# 0   1c, 2d, 3b, 11c,         vor 1907  REINECK (1907)
# 1  1c, 11c, 14a, 14g             1937        CHRYFAUN
# 2   1c, 2d, 8b, 11c,         vor 1907  REINECK (1907)
# 3  1c, 2d, 11c, 14a,         vor 1950     MOHR (1985)
# 4  1c, 2d, 11c, 14a,             1943        CHRYFAUN

# %%
df
# Out:
#                                             Species  BE Bestand   BB  D  \
# 0                  Donacia brevicornis AHRENS, 1810   0      ex  NaN  2
# 1                       Donacia dentata HOPPE, 1795   0      ex    2  2
# 2                   Donacia obscura GYLLENHAL, 1813   0      ex    2  1
# 3        Donacia thalassina thalassina GERMAR, 1811   0      ex    p  V
# 4                    Donacia tomentosa AHRENS, 1810   0      ex    0  1
# 5            Macroplea appendiculata (PANZER, 1794)   0      ex  NaN  1
# 6                Lilioceris merdigera (LINNÉ, 1758)   0      ex  NaN  *
# 7    Labidostomis humeralis (D. H. SCHNEIDER, 1792)   0      ex  NaN  2
# 8             Labidostomis tridentata (LINNÉ, 1758)   0      ex    3  3
# 9          Cryptocephalus bipunctatus (LINNÉ, 1758)   0      ex  NaN  *
# 10            Cryptocephalus chrysopus GMELIN, 1788   0      ex  NaN  3
# 11              Cryptocephalus coryli (LINNÉ, 1758)   0      ex    3  3
# 12      Cryptocephalus decemmaculatus (LINNÉ, 1758)   0      ex  NaN  3
# 13       Cryptocephalus hypochaeridis (LINNÉ, 1758)   0      ex  NaN  *
# 14            Cryptocephalus janthinus GERMAR, 1824   0      ex    0  1
# 15            Cryptocephalus laetus FABRICIUS, 1792   0      ex    0  0
# 16     Cryptocephalus octopunctatus (SCOPOLI, 1763)   0      ex    2  2
# 17                Cryptocephalus pini (LINNÉ, 1758)   0      ex    1  *
# 18       Cryptocephalus quadripustulatus GYLLENHAL,   0      ex    1  D
# 19           Cryptocephalus querceti SUFFRIAN, 1848   0      ex    1  2
# 20  Pachybrachis hieroglyphicus (LAICHARTING, 1781)   0      ex    0  3
# 21                 Oomorphus concolor (STURM, 1807)   0      ex    0  *
# 22                Chrysolina cerealis (LINNÉ, 1767)   0      ex    0  3
# 23                Prasocuris glabra (HERBST, 1783)*   0      ex    2  *
# 24        Prasocuris hannoveriana (FABRICIUS, 1775)   0      ex    3  3
# 25               Galeruca melanocephala PONZA, 1805   0      ex  NaN  1
# 26             Chaetocnema confusa (BOHEMANN, 1851)   0      ex  NaN  3
# 27                 Dibolia schillingi LETZNER, 1846   0      ex  NaN  3
# 28        Longitarsus nigerrimus (GYLLENHAL, 1827)*   0      ex  NaN  1
# 29              Bruchidius cisti (FABRICIUS, 1775)*   0      ex  NaN  3
# 30                    Bruchus pisorum (LINNÉ, 1758)   0      ex  NaN  1
# 31                 Bruchus rufimanus BOHEMANN, 1833   0      ex  NaN  *
#
#                   GfU Letzter_Nachweis                         Quelle
# 0    1c, 2d, 3b, 11c,         vor 1907                 REINECK (1907)
# 1   1c, 11c, 14a, 14g             1937                       CHRYFAUN
# 2    1c, 2d, 8b, 11c,         vor 1907                 REINECK (1907)
# 3   1c, 2d, 11c, 14a,         vor 1950                    MOHR (1985)
# 4   1c, 2d, 11c, 14a,             1943                       CHRYFAUN
# 5    1c, 3b, 11c, 14a         vor 1907                 REINECK (1907)
# 6                  1a         vor 1913                 REINECK (1913)
# 7            12b, 14a             1897                SCHILSKY (1897)
# 8             9d, 14a             1949      coll. G. Lauterbach in FU
# 9             1a, 14a         vor 1950                    MOHR (1977)
# 10            1a, 14a         vor 1950               coll. P. Delahon
# 11                14a             1906                 DELAHON (1927)
# 12        2d, 8b, 14a             1948                       CHRYFAUN
# 13            8a, 14a             1946                       CHRYFAUN
# 14             6a, 8c             2008                             JE
# 15        2a, 8a, 14a         vor 1900                   WEISE (1872)
# 16        1a, 2d, 14a         vor 1950     coll. J. Neresheimer, MOHR
# 17                 9d         vor 1950                    MOHR (1977)
# 18             9a, 4c         vor 1950  coll. G. Reineck in coll. SMF
# 19                14a             1885                   WEISE (1885)
# 20            5b, 14a             1885                   WEISE (1885)
# 21                14a         vor 1920   coll. G. Kraatz (SDEI), Mohr
# 22        1a, 7a, 14a         vor 1950                    MOHR (1977)
# 23    1c, 2d, 6a, 14a             1960                       CHRYFAUN
# 24   2d, 5b, 6a, 14a,         vor 1918           NERESHEIMER & WAGNER
# 25        2d, 5b, 14a             1928                       CHRYFAUN
# 26       2d, 8b,  14a             1907                 REINECK (1907)
# 27        1a, 7a, 14a             1942                coll. M. Döberl
# 28  2d, 8b, 11c, 14a,             1958                   KORGE (1963)
# 29        1a, 7a, 14g         vor 1950                   WENDT (1986)
# 30            4c, 14e             1949        WENDT (1986), CHRYFAUN,
# 31                  ?         vor 1950                   WENDT (1986)

# %%
# Editing species column based on binomial nomenclature

df1 = df.Species.str.split(pat=" ", n = 3, expand = True)
df.Species = df1[0].str.cat(df1[1], sep = " ")

# %%
df
# Out:
#                             Species  BE Bestand   BB  D                GfU  \
# 0               Donacia brevicornis   0      ex  NaN  2   1c, 2d, 3b, 11c,
# 1                   Donacia dentata   0      ex    2  2  1c, 11c, 14a, 14g
# 2                   Donacia obscura   0      ex    2  1   1c, 2d, 8b, 11c,
# 3                Donacia thalassina   0      ex    p  V  1c, 2d, 11c, 14a,
# 4                 Donacia tomentosa   0      ex    0  1  1c, 2d, 11c, 14a,
# 5           Macroplea appendiculata   0      ex  NaN  1   1c, 3b, 11c, 14a
# 6              Lilioceris merdigera   0      ex  NaN  *                 1a
# 7            Labidostomis humeralis   0      ex  NaN  2           12b, 14a
# 8           Labidostomis tridentata   0      ex    3  3            9d, 14a
# 9        Cryptocephalus bipunctatus   0      ex  NaN  *            1a, 14a
# 10         Cryptocephalus chrysopus   0      ex  NaN  3            1a, 14a
# 11            Cryptocephalus coryli   0      ex    3  3                14a
# 12    Cryptocephalus decemmaculatus   0      ex  NaN  3        2d, 8b, 14a
# 13     Cryptocephalus hypochaeridis   0      ex  NaN  *            8a, 14a
# 14         Cryptocephalus janthinus   0      ex    0  1             6a, 8c
# 15            Cryptocephalus laetus   0      ex    0  0        2a, 8a, 14a
# 16     Cryptocephalus octopunctatus   0      ex    2  2        1a, 2d, 14a
# 17              Cryptocephalus pini   0      ex    1  *                 9d
# 18  Cryptocephalus quadripustulatus   0      ex    1  D             9a, 4c
# 19          Cryptocephalus querceti   0      ex    1  2                14a
# 20      Pachybrachis hieroglyphicus   0      ex    0  3            5b, 14a
# 21               Oomorphus concolor   0      ex    0  *                14a
# 22              Chrysolina cerealis   0      ex    0  3        1a, 7a, 14a
# 23                Prasocuris glabra   0      ex    2  *    1c, 2d, 6a, 14a
# 24          Prasocuris hannoveriana   0      ex    3  3   2d, 5b, 6a, 14a,
# 25           Galeruca melanocephala   0      ex  NaN  1        2d, 5b, 14a
# 26              Chaetocnema confusa   0      ex  NaN  3       2d, 8b,  14a
# 27               Dibolia schillingi   0      ex  NaN  3        1a, 7a, 14a
# 28           Longitarsus nigerrimus   0      ex  NaN  1  2d, 8b, 11c, 14a,
# 29                 Bruchidius cisti   0      ex  NaN  3        1a, 7a, 14g
# 30                  Bruchus pisorum   0      ex  NaN  1            4c, 14e
# 31                Bruchus rufimanus   0      ex  NaN  *                  ?
#
#    Letzter_Nachweis                         Quelle
# 0          vor 1907                 REINECK (1907)
# 1              1937                       CHRYFAUN
# 2          vor 1907                 REINECK (1907)
# 3          vor 1950                    MOHR (1985)
# 4              1943                       CHRYFAUN
# 5          vor 1907                 REINECK (1907)
# 6          vor 1913                 REINECK (1913)
# 7              1897                SCHILSKY (1897)
# 8              1949      coll. G. Lauterbach in FU
# 9          vor 1950                    MOHR (1977)
# 10         vor 1950               coll. P. Delahon
# 11             1906                 DELAHON (1927)
# 12             1948                       CHRYFAUN
# 13             1946                       CHRYFAUN
# 14             2008                             JE
# 15         vor 1900                   WEISE (1872)
# 16         vor 1950     coll. J. Neresheimer, MOHR
# 17         vor 1950                    MOHR (1977)
# 18         vor 1950  coll. G. Reineck in coll. SMF
# 19             1885                   WEISE (1885)
# 20             1885                   WEISE (1885)
# 21         vor 1920   coll. G. Kraatz (SDEI), Mohr
# 22         vor 1950                    MOHR (1977)
# 23             1960                       CHRYFAUN
# 24         vor 1918           NERESHEIMER & WAGNER
# 25             1928                       CHRYFAUN
# 26             1907                 REINECK (1907)
# 27             1942                coll. M. Döberl
# 28             1958                   KORGE (1963)
# 29         vor 1950                   WENDT (1986)
# 30             1949        WENDT (1986), CHRYFAUN,
# 31         vor 1950                   WENDT (1986)

# %%
# Manually editing cells that were extracted incorrectly/partially
df.at[0,"GfU"]= "1c, 2d, 3b, 11c, 14a, 14g"
df.head()
# Out:
#                Species  BE Bestand   BB  D                        GfU  \
# 0  Donacia brevicornis   0      ex  NaN  2  1c, 2d, 3b, 11c, 14a, 14g
# 1      Donacia dentata   0      ex    2  2          1c, 11c, 14a, 14g
# 2      Donacia obscura   0      ex    2  1           1c, 2d, 8b, 11c,
# 3   Donacia thalassina   0      ex    p  V          1c, 2d, 11c, 14a,
# 4    Donacia tomentosa   0      ex    0  1          1c, 2d, 11c, 14a,
#
#   Letzter_Nachweis          Quelle
# 0         vor 1907  REINECK (1907)
# 1             1937        CHRYFAUN
# 2         vor 1907  REINECK (1907)
# 3         vor 1950     MOHR (1985)
# 4             1943        CHRYFAUN

# %%
df.at[2,"GfU"]= "1c, 2d, 8b, 11c, 14a"
df.at[3,"GfU"]= "1c, 2d, 11c, 14a, 14g"
df.at[4,"GfU"]= "1c, 2d, 11c, 14a, 14g"
df
# Out:
#                             Species  BE Bestand   BB  D  \
# 0               Donacia brevicornis   0      ex  NaN  2
# 1                   Donacia dentata   0      ex    2  2
# 2                   Donacia obscura   0      ex    2  1
# 3                Donacia thalassina   0      ex    p  V
# 4                 Donacia tomentosa   0      ex    0  1
# 5           Macroplea appendiculata   0      ex  NaN  1
# 6              Lilioceris merdigera   0      ex  NaN  *
# 7            Labidostomis humeralis   0      ex  NaN  2
# 8           Labidostomis tridentata   0      ex    3  3
# 9        Cryptocephalus bipunctatus   0      ex  NaN  *
# 10         Cryptocephalus chrysopus   0      ex  NaN  3
# 11            Cryptocephalus coryli   0      ex    3  3
# 12    Cryptocephalus decemmaculatus   0      ex  NaN  3
# 13     Cryptocephalus hypochaeridis   0      ex  NaN  *
# 14         Cryptocephalus janthinus   0      ex    0  1
# 15            Cryptocephalus laetus   0      ex    0  0
# 16     Cryptocephalus octopunctatus   0      ex    2  2
# 17              Cryptocephalus pini   0      ex    1  *
# 18  Cryptocephalus quadripustulatus   0      ex    1  D
# 19          Cryptocephalus querceti   0      ex    1  2
# 20      Pachybrachis hieroglyphicus   0      ex    0  3
# 21               Oomorphus concolor   0      ex    0  *
# 22              Chrysolina cerealis   0      ex    0  3
# 23                Prasocuris glabra   0      ex    2  *
# 24          Prasocuris hannoveriana   0      ex    3  3
# 25           Galeruca melanocephala   0      ex  NaN  1
# 26              Chaetocnema confusa   0      ex  NaN  3
# 27               Dibolia schillingi   0      ex  NaN  3
# 28           Longitarsus nigerrimus   0      ex  NaN  1
# 29                 Bruchidius cisti   0      ex  NaN  3
# 30                  Bruchus pisorum   0      ex  NaN  1
# 31                Bruchus rufimanus   0      ex  NaN  *
#
#                           GfU Letzter_Nachweis                         Quelle
# 0   1c, 2d, 3b, 11c, 14a, 14g         vor 1907                 REINECK (1907)
# 1           1c, 11c, 14a, 14g             1937                       CHRYFAUN
# 2        1c, 2d, 8b, 11c, 14a         vor 1907                 REINECK (1907)
# 3       1c, 2d, 11c, 14a, 14g         vor 1950                    MOHR (1985)
# 4       1c, 2d, 11c, 14a, 14g             1943                       CHRYFAUN
# 5            1c, 3b, 11c, 14a         vor 1907                 REINECK (1907)
# 6                          1a         vor 1913                 REINECK (1913)
# 7                    12b, 14a             1897                SCHILSKY (1897)
# 8                     9d, 14a             1949      coll. G. Lauterbach in FU
# 9                     1a, 14a         vor 1950                    MOHR (1977)
# 10                    1a, 14a         vor 1950               coll. P. Delahon
# 11                        14a             1906                 DELAHON (1927)
# 12                2d, 8b, 14a             1948                       CHRYFAUN
# 13                    8a, 14a             1946                       CHRYFAUN
# 14                     6a, 8c             2008                             JE
# 15                2a, 8a, 14a         vor 1900                   WEISE (1872)
# 16                1a, 2d, 14a         vor 1950     coll. J. Neresheimer, MOHR
# 17                         9d         vor 1950                    MOHR (1977)
# 18                     9a, 4c         vor 1950  coll. G. Reineck in coll. SMF
# 19                        14a             1885                   WEISE (1885)
# 20                    5b, 14a             1885                   WEISE (1885)
# 21                        14a         vor 1920   coll. G. Kraatz (SDEI), Mohr
# 22                1a, 7a, 14a         vor 1950                    MOHR (1977)
# 23            1c, 2d, 6a, 14a             1960                       CHRYFAUN
# 24           2d, 5b, 6a, 14a,         vor 1918           NERESHEIMER & WAGNER
# 25                2d, 5b, 14a             1928                       CHRYFAUN
# 26               2d, 8b,  14a             1907                 REINECK (1907)
# 27                1a, 7a, 14a             1942                coll. M. Döberl
# 28          2d, 8b, 11c, 14a,             1958                   KORGE (1963)
# 29                1a, 7a, 14g         vor 1950                   WENDT (1986)
# 30                    4c, 14e             1949        WENDT (1986), CHRYFAUN,
# 31                          ?         vor 1950                   WENDT (1986)

# %%
df.at[24,"GfU"]= "2d, 5b, 6a, 14a, 14g"
df.at[28,"GfU"]= "2d, 8b, 11c, 14a, 14g"

# %%
df.at[8,"Quelle"]= "coll. G. Lauterbach in FU Berlin"
df.at[16,"Quelle"]= "coll. J. Neresheimer, MOHR (1977)"
df.at[21,"Quelle"]= "coll. G. Kraatz (SDEI), Mohr & Arnold in litteris"
df.at[24,"Quelle"]= "NERESHEIMER & WAGNER (1917)"
df.at[30,"Quelle"]= "WENDT (1986), CHRYFAUN, SMF"

# %%
df
# Out:
#                             Species  BE Bestand   BB  D  \
# 0               Donacia brevicornis   0      ex  NaN  2
# 1                   Donacia dentata   0      ex    2  2
# 2                   Donacia obscura   0      ex    2  1
# 3                Donacia thalassina   0      ex    p  V
# 4                 Donacia tomentosa   0      ex    0  1
# 5           Macroplea appendiculata   0      ex  NaN  1
# 6              Lilioceris merdigera   0      ex  NaN  *
# 7            Labidostomis humeralis   0      ex  NaN  2
# 8           Labidostomis tridentata   0      ex    3  3
# 9        Cryptocephalus bipunctatus   0      ex  NaN  *
# 10         Cryptocephalus chrysopus   0      ex  NaN  3
# 11            Cryptocephalus coryli   0      ex    3  3
# 12    Cryptocephalus decemmaculatus   0      ex  NaN  3
# 13     Cryptocephalus hypochaeridis   0      ex  NaN  *
# 14         Cryptocephalus janthinus   0      ex    0  1
# 15            Cryptocephalus laetus   0      ex    0  0
# 16     Cryptocephalus octopunctatus   0      ex    2  2
# 17              Cryptocephalus pini   0      ex    1  *
# 18  Cryptocephalus quadripustulatus   0      ex    1  D
# 19          Cryptocephalus querceti   0      ex    1  2
# 20      Pachybrachis hieroglyphicus   0      ex    0  3
# 21               Oomorphus concolor   0      ex    0  *
# 22              Chrysolina cerealis   0      ex    0  3
# 23                Prasocuris glabra   0      ex    2  *
# 24          Prasocuris hannoveriana   0      ex    3  3
# 25           Galeruca melanocephala   0      ex  NaN  1
# 26              Chaetocnema confusa   0      ex  NaN  3
# 27               Dibolia schillingi   0      ex  NaN  3
# 28           Longitarsus nigerrimus   0      ex  NaN  1
# 29                 Bruchidius cisti   0      ex  NaN  3
# 30                  Bruchus pisorum   0      ex  NaN  1
# 31                Bruchus rufimanus   0      ex  NaN  *
#
#                           GfU Letzter_Nachweis  \
# 0   1c, 2d, 3b, 11c, 14a, 14g         vor 1907
# 1           1c, 11c, 14a, 14g             1937
# 2        1c, 2d, 8b, 11c, 14a         vor 1907
# 3       1c, 2d, 11c, 14a, 14g         vor 1950
# 4       1c, 2d, 11c, 14a, 14g             1943
# 5            1c, 3b, 11c, 14a         vor 1907
# 6                          1a         vor 1913
# 7                    12b, 14a             1897
# 8                     9d, 14a             1949
# 9                     1a, 14a         vor 1950
# 10                    1a, 14a         vor 1950
# 11                        14a             1906
# 12                2d, 8b, 14a             1948
# 13                    8a, 14a             1946
# 14                     6a, 8c             2008
# 15                2a, 8a, 14a         vor 1900
# 16                1a, 2d, 14a         vor 1950
# 17                         9d         vor 1950
# 18                     9a, 4c         vor 1950
# 19                        14a             1885
# 20                    5b, 14a             1885
# 21                        14a         vor 1920
# 22                1a, 7a, 14a         vor 1950
# 23            1c, 2d, 6a, 14a             1960
# 24       2d, 5b, 6a, 14a, 14g         vor 1918
# 25                2d, 5b, 14a             1928
# 26               2d, 8b,  14a             1907
# 27                1a, 7a, 14a             1942
# 28      2d, 8b, 11c, 14a, 14g             1958
# 29                1a, 7a, 14g         vor 1950
# 30                    4c, 14e             1949
# 31                          ?         vor 1950
#
#                                                Quelle
# 0                                      REINECK (1907)
# 1                                            CHRYFAUN
# 2                                      REINECK (1907)
# 3                                         MOHR (1985)
# 4                                            CHRYFAUN
# 5                                      REINECK (1907)
# 6                                      REINECK (1913)
# 7                                     SCHILSKY (1897)
# 8                    coll. G. Lauterbach in FU Berlin
# 9                                         MOHR (1977)
# 10                                   coll. P. Delahon
# 11                                     DELAHON (1927)
# 12                                           CHRYFAUN
# 13                                           CHRYFAUN
# 14                                                 JE
# 15                                       WEISE (1872)
# 16                  coll. J. Neresheimer, MOHR (1977)
# 17                                        MOHR (1977)
# 18                      coll. G. Reineck in coll. SMF
# 19                                       WEISE (1885)
# 20                                       WEISE (1885)
# 21  coll. G. Kraatz (SDEI), Mohr & Arnold in litteris
# 22                                        MOHR (1977)
# 23                                           CHRYFAUN
# 24                        NERESHEIMER & WAGNER (1917)
# 25                                           CHRYFAUN
# 26                                     REINECK (1907)
# 27                                    coll. M. Döberl
# 28                                       KORGE (1963)
# 29                                       WENDT (1986)
# 30                        WENDT (1986), CHRYFAUN, SMF
# 31                                       WENDT (1986)

# %%
# Adding aditional information columns from the source

# %%
# Adding the Family and SubFamily columns

# %%
#df = df.reindex(columns = ["Family", "Sub_family"] + df.columns.tolist())

# %%
i = 0;
while i < 32:
    df.at[i,"Family"] = "Chrysomelidae"
    if i < 6:
        df.at[i,"Sub_family"] = "Donaciinae"
    elif i == 6:
        df.at[i,"Sub_family"] = "Criocerinae"
    elif (i == 7) | (i == 8):
        df.at[i,"Sub_family"] = "Cryptocephalinae – Clytrini" 
    elif ((i > 8) & (i < 21)):
        df.at[i,"Sub_family"] = "Cryptocephalinae – Cryptocephalini"
    elif (i == 21):
        df.at[i,"Sub_family"] = "Lamprosomatinae"
    elif ((i > 21) & (i < 25)):
        df.at[i,"Sub_family"] = "Chrysomelinae"
    elif (i == 25):
        df.at[i,"Sub_family"] = "Galerucinae – Galerucini"
    elif ((i > 25) & (i < 28)):
        df.at[i,"Sub_family"] = "Galerucinae – Alticini"
    elif ((i > 27)):
        df.at[i,"Sub_family"] = "Bruchinae"
    i = i + 1
df
# Out:
#                             Species  BE Bestand   BB  D  \
# 0               Donacia brevicornis   0      ex  NaN  2
# 1                   Donacia dentata   0      ex    2  2
# 2                   Donacia obscura   0      ex    2  1
# 3                Donacia thalassina   0      ex    p  V
# 4                 Donacia tomentosa   0      ex    0  1
# 5           Macroplea appendiculata   0      ex  NaN  1
# 6              Lilioceris merdigera   0      ex  NaN  *
# 7            Labidostomis humeralis   0      ex  NaN  2
# 8           Labidostomis tridentata   0      ex    3  3
# 9        Cryptocephalus bipunctatus   0      ex  NaN  *
# 10         Cryptocephalus chrysopus   0      ex  NaN  3
# 11            Cryptocephalus coryli   0      ex    3  3
# 12    Cryptocephalus decemmaculatus   0      ex  NaN  3
# 13     Cryptocephalus hypochaeridis   0      ex  NaN  *
# 14         Cryptocephalus janthinus   0      ex    0  1
# 15            Cryptocephalus laetus   0      ex    0  0
# 16     Cryptocephalus octopunctatus   0      ex    2  2
# 17              Cryptocephalus pini   0      ex    1  *
# 18  Cryptocephalus quadripustulatus   0      ex    1  D
# 19          Cryptocephalus querceti   0      ex    1  2
# 20      Pachybrachis hieroglyphicus   0      ex    0  3
# 21               Oomorphus concolor   0      ex    0  *
# 22              Chrysolina cerealis   0      ex    0  3
# 23                Prasocuris glabra   0      ex    2  *
# 24          Prasocuris hannoveriana   0      ex    3  3
# 25           Galeruca melanocephala   0      ex  NaN  1
# 26              Chaetocnema confusa   0      ex  NaN  3
# 27               Dibolia schillingi   0      ex  NaN  3
# 28           Longitarsus nigerrimus   0      ex  NaN  1
# 29                 Bruchidius cisti   0      ex  NaN  3
# 30                  Bruchus pisorum   0      ex  NaN  1
# 31                Bruchus rufimanus   0      ex  NaN  *
#
#                           GfU Letzter_Nachweis  \
# 0   1c, 2d, 3b, 11c, 14a, 14g         vor 1907
# 1           1c, 11c, 14a, 14g             1937
# 2        1c, 2d, 8b, 11c, 14a         vor 1907
# 3       1c, 2d, 11c, 14a, 14g         vor 1950
# 4       1c, 2d, 11c, 14a, 14g             1943
# 5            1c, 3b, 11c, 14a         vor 1907
# 6                          1a         vor 1913
# 7                    12b, 14a             1897
# 8                     9d, 14a             1949
# 9                     1a, 14a         vor 1950
# 10                    1a, 14a         vor 1950
# 11                        14a             1906
# 12                2d, 8b, 14a             1948
# 13                    8a, 14a             1946
# 14                     6a, 8c             2008
# 15                2a, 8a, 14a         vor 1900
# 16                1a, 2d, 14a         vor 1950
# 17                         9d         vor 1950
# 18                     9a, 4c         vor 1950
# 19                        14a             1885
# 20                    5b, 14a             1885
# 21                        14a         vor 1920
# 22                1a, 7a, 14a         vor 1950
# 23            1c, 2d, 6a, 14a             1960
# 24       2d, 5b, 6a, 14a, 14g         vor 1918
# 25                2d, 5b, 14a             1928
# 26               2d, 8b,  14a             1907
# 27                1a, 7a, 14a             1942
# 28      2d, 8b, 11c, 14a, 14g             1958
# 29                1a, 7a, 14g         vor 1950
# 30                    4c, 14e             1949
# 31                          ?         vor 1950
#
#                                                Quelle         Family  \
# 0                                      REINECK (1907)  Chrysomelidae
# 1                                            CHRYFAUN  Chrysomelidae
# 2                                      REINECK (1907)  Chrysomelidae
# 3                                         MOHR (1985)  Chrysomelidae
# 4                                            CHRYFAUN  Chrysomelidae
# 5                                      REINECK (1907)  Chrysomelidae
# 6                                      REINECK (1913)  Chrysomelidae
# 7                                     SCHILSKY (1897)  Chrysomelidae
# 8                    coll. G. Lauterbach in FU Berlin  Chrysomelidae
# 9                                         MOHR (1977)  Chrysomelidae
# 10                                   coll. P. Delahon  Chrysomelidae
# 11                                     DELAHON (1927)  Chrysomelidae
# 12                                           CHRYFAUN  Chrysomelidae
# 13                                           CHRYFAUN  Chrysomelidae
# 14                                                 JE  Chrysomelidae
# 15                                       WEISE (1872)  Chrysomelidae
# 16                  coll. J. Neresheimer, MOHR (1977)  Chrysomelidae
# 17                                        MOHR (1977)  Chrysomelidae
# 18                      coll. G. Reineck in coll. SMF  Chrysomelidae
# 19                                       WEISE (1885)  Chrysomelidae
# 20                                       WEISE (1885)  Chrysomelidae
# 21  coll. G. Kraatz (SDEI), Mohr & Arnold in litteris  Chrysomelidae
# 22                                        MOHR (1977)  Chrysomelidae
# 23                                           CHRYFAUN  Chrysomelidae
# 24                        NERESHEIMER & WAGNER (1917)  Chrysomelidae
# 25                                           CHRYFAUN  Chrysomelidae
# 26                                     REINECK (1907)  Chrysomelidae
# 27                                    coll. M. Döberl  Chrysomelidae
# 28                                       KORGE (1963)  Chrysomelidae
# 29                                       WENDT (1986)  Chrysomelidae
# 30                        WENDT (1986), CHRYFAUN, SMF  Chrysomelidae
# 31                                       WENDT (1986)  Chrysomelidae
#
#                             Sub_family
# 0                           Donaciinae
# 1                           Donaciinae
# 2                           Donaciinae
# 3                           Donaciinae
# 4                           Donaciinae
# 5                           Donaciinae
# 6                          Criocerinae
# 7          Cryptocephalinae – Clytrini
# 8          Cryptocephalinae – Clytrini
# 9   Cryptocephalinae – Cryptocephalini
# 10  Cryptocephalinae – Cryptocephalini
# 11  Cryptocephalinae – Cryptocephalini
# 12  Cryptocephalinae – Cryptocephalini
# 13  Cryptocephalinae – Cryptocephalini
# 14  Cryptocephalinae – Cryptocephalini
# 15  Cryptocephalinae – Cryptocephalini
# 16  Cryptocephalinae – Cryptocephalini
# 17  Cryptocephalinae – Cryptocephalini
# 18  Cryptocephalinae – Cryptocephalini
# 19  Cryptocephalinae – Cryptocephalini
# 20  Cryptocephalinae – Cryptocephalini
# 21                     Lamprosomatinae
# 22                       Chrysomelinae
# 23                       Chrysomelinae
# 24                       Chrysomelinae
# 25            Galerucinae – Galerucini
# 26              Galerucinae – Alticini
# 27              Galerucinae – Alticini
# 28                           Bruchinae
# 29                           Bruchinae
# 30                           Bruchinae
# 31                           Bruchinae

# %%
df.columns
# Out:
# Index(['Species', 'BE', 'Bestand', 'BB', 'D', 'GfU', 'Letzter_Nachweis',
#        'Quelle', 'Family', 'Sub_family'],
#       dtype='object')

# %%
df = df.reindex(columns=['Family',
                         'Sub_family',
                         'Species', 
                         'BE', 
                         'Bestand', 
                         'BB', 
                         'D', 
                         'GfU', 
                         'Letzter_Nachweis', 
                         'Quelle'])
df
# Out:
#            Family                          Sub_family  \
# 0   Chrysomelidae                          Donaciinae
# 1   Chrysomelidae                          Donaciinae
# 2   Chrysomelidae                          Donaciinae
# 3   Chrysomelidae                          Donaciinae
# 4   Chrysomelidae                          Donaciinae
# 5   Chrysomelidae                          Donaciinae
# 6   Chrysomelidae                         Criocerinae
# 7   Chrysomelidae         Cryptocephalinae – Clytrini
# 8   Chrysomelidae         Cryptocephalinae – Clytrini
# 9   Chrysomelidae  Cryptocephalinae – Cryptocephalini
# 10  Chrysomelidae  Cryptocephalinae – Cryptocephalini
# 11  Chrysomelidae  Cryptocephalinae – Cryptocephalini
# 12  Chrysomelidae  Cryptocephalinae – Cryptocephalini
# 13  Chrysomelidae  Cryptocephalinae – Cryptocephalini
# 14  Chrysomelidae  Cryptocephalinae – Cryptocephalini
# 15  Chrysomelidae  Cryptocephalinae – Cryptocephalini
# 16  Chrysomelidae  Cryptocephalinae – Cryptocephalini
# 17  Chrysomelidae  Cryptocephalinae – Cryptocephalini
# 18  Chrysomelidae  Cryptocephalinae – Cryptocephalini
# 19  Chrysomelidae  Cryptocephalinae – Cryptocephalini
# 20  Chrysomelidae  Cryptocephalinae – Cryptocephalini
# 21  Chrysomelidae                     Lamprosomatinae
# 22  Chrysomelidae                       Chrysomelinae
# 23  Chrysomelidae                       Chrysomelinae
# 24  Chrysomelidae                       Chrysomelinae
# 25  Chrysomelidae            Galerucinae – Galerucini
# 26  Chrysomelidae              Galerucinae – Alticini
# 27  Chrysomelidae              Galerucinae – Alticini
# 28  Chrysomelidae                           Bruchinae
# 29  Chrysomelidae                           Bruchinae
# 30  Chrysomelidae                           Bruchinae
# 31  Chrysomelidae                           Bruchinae
#
#                             Species  BE Bestand   BB  D  \
# 0               Donacia brevicornis   0      ex  NaN  2
# 1                   Donacia dentata   0      ex    2  2
# 2                   Donacia obscura   0      ex    2  1
# 3                Donacia thalassina   0      ex    p  V
# 4                 Donacia tomentosa   0      ex    0  1
# 5           Macroplea appendiculata   0      ex  NaN  1
# 6              Lilioceris merdigera   0      ex  NaN  *
# 7            Labidostomis humeralis   0      ex  NaN  2
# 8           Labidostomis tridentata   0      ex    3  3
# 9        Cryptocephalus bipunctatus   0      ex  NaN  *
# 10         Cryptocephalus chrysopus   0      ex  NaN  3
# 11            Cryptocephalus coryli   0      ex    3  3
# 12    Cryptocephalus decemmaculatus   0      ex  NaN  3
# 13     Cryptocephalus hypochaeridis   0      ex  NaN  *
# 14         Cryptocephalus janthinus   0      ex    0  1
# 15            Cryptocephalus laetus   0      ex    0  0
# 16     Cryptocephalus octopunctatus   0      ex    2  2
# 17              Cryptocephalus pini   0      ex    1  *
# 18  Cryptocephalus quadripustulatus   0      ex    1  D
# 19          Cryptocephalus querceti   0      ex    1  2
# 20      Pachybrachis hieroglyphicus   0      ex    0  3
# 21               Oomorphus concolor   0      ex    0  *
# 22              Chrysolina cerealis   0      ex    0  3
# 23                Prasocuris glabra   0      ex    2  *
# 24          Prasocuris hannoveriana   0      ex    3  3
# 25           Galeruca melanocephala   0      ex  NaN  1
# 26              Chaetocnema confusa   0      ex  NaN  3
# 27               Dibolia schillingi   0      ex  NaN  3
# 28           Longitarsus nigerrimus   0      ex  NaN  1
# 29                 Bruchidius cisti   0      ex  NaN  3
# 30                  Bruchus pisorum   0      ex  NaN  1
# 31                Bruchus rufimanus   0      ex  NaN  *
#
#                           GfU Letzter_Nachweis  \
# 0   1c, 2d, 3b, 11c, 14a, 14g         vor 1907
# 1           1c, 11c, 14a, 14g             1937
# 2        1c, 2d, 8b, 11c, 14a         vor 1907
# 3       1c, 2d, 11c, 14a, 14g         vor 1950
# 4       1c, 2d, 11c, 14a, 14g             1943
# 5            1c, 3b, 11c, 14a         vor 1907
# 6                          1a         vor 1913
# 7                    12b, 14a             1897
# 8                     9d, 14a             1949
# 9                     1a, 14a         vor 1950
# 10                    1a, 14a         vor 1950
# 11                        14a             1906
# 12                2d, 8b, 14a             1948
# 13                    8a, 14a             1946
# 14                     6a, 8c             2008
# 15                2a, 8a, 14a         vor 1900
# 16                1a, 2d, 14a         vor 1950
# 17                         9d         vor 1950
# 18                     9a, 4c         vor 1950
# 19                        14a             1885
# 20                    5b, 14a             1885
# 21                        14a         vor 1920
# 22                1a, 7a, 14a         vor 1950
# 23            1c, 2d, 6a, 14a             1960
# 24       2d, 5b, 6a, 14a, 14g         vor 1918
# 25                2d, 5b, 14a             1928
# 26               2d, 8b,  14a             1907
# 27                1a, 7a, 14a             1942
# 28      2d, 8b, 11c, 14a, 14g             1958
# 29                1a, 7a, 14g         vor 1950
# 30                    4c, 14e             1949
# 31                          ?         vor 1950
#
#                                                Quelle
# 0                                      REINECK (1907)
# 1                                            CHRYFAUN
# 2                                      REINECK (1907)
# 3                                         MOHR (1985)
# 4                                            CHRYFAUN
# 5                                      REINECK (1907)
# 6                                      REINECK (1913)
# 7                                     SCHILSKY (1897)
# 8                    coll. G. Lauterbach in FU Berlin
# 9                                         MOHR (1977)
# 10                                   coll. P. Delahon
# 11                                     DELAHON (1927)
# 12                                           CHRYFAUN
# 13                                           CHRYFAUN
# 14                                                 JE
# 15                                       WEISE (1872)
# 16                  coll. J. Neresheimer, MOHR (1977)
# 17                                        MOHR (1977)
# 18                      coll. G. Reineck in coll. SMF
# 19                                       WEISE (1885)
# 20                                       WEISE (1885)
# 21  coll. G. Kraatz (SDEI), Mohr & Arnold in litteris
# 22                                        MOHR (1977)
# 23                                           CHRYFAUN
# 24                        NERESHEIMER & WAGNER (1917)
# 25                                           CHRYFAUN
# 26                                     REINECK (1907)
# 27                                    coll. M. Döberl
# 28                                       KORGE (1963)
# 29                                       WENDT (1986)
# 30                        WENDT (1986), CHRYFAUN, SMF
# 31                                       WENDT (1986)

# %%
# Removing column Quelle, GfU, BB, D
df.drop(columns = ["Quelle", "GfU", "BB", "D", "Bestand"], inplace = True)

# %%
df
# Out:
#            Family                          Sub_family  \
# 0   Chrysomelidae                          Donaciinae
# 1   Chrysomelidae                          Donaciinae
# 2   Chrysomelidae                          Donaciinae
# 3   Chrysomelidae                          Donaciinae
# 4   Chrysomelidae                          Donaciinae
# 5   Chrysomelidae                          Donaciinae
# 6   Chrysomelidae                         Criocerinae
# 7   Chrysomelidae         Cryptocephalinae – Clytrini
# 8   Chrysomelidae         Cryptocephalinae – Clytrini
# 9   Chrysomelidae  Cryptocephalinae – Cryptocephalini
# 10  Chrysomelidae  Cryptocephalinae – Cryptocephalini
# 11  Chrysomelidae  Cryptocephalinae – Cryptocephalini
# 12  Chrysomelidae  Cryptocephalinae – Cryptocephalini
# 13  Chrysomelidae  Cryptocephalinae – Cryptocephalini
# 14  Chrysomelidae  Cryptocephalinae – Cryptocephalini
# 15  Chrysomelidae  Cryptocephalinae – Cryptocephalini
# 16  Chrysomelidae  Cryptocephalinae – Cryptocephalini
# 17  Chrysomelidae  Cryptocephalinae – Cryptocephalini
# 18  Chrysomelidae  Cryptocephalinae – Cryptocephalini
# 19  Chrysomelidae  Cryptocephalinae – Cryptocephalini
# 20  Chrysomelidae  Cryptocephalinae – Cryptocephalini
# 21  Chrysomelidae                     Lamprosomatinae
# 22  Chrysomelidae                       Chrysomelinae
# 23  Chrysomelidae                       Chrysomelinae
# 24  Chrysomelidae                       Chrysomelinae
# 25  Chrysomelidae            Galerucinae – Galerucini
# 26  Chrysomelidae              Galerucinae – Alticini
# 27  Chrysomelidae              Galerucinae – Alticini
# 28  Chrysomelidae                           Bruchinae
# 29  Chrysomelidae                           Bruchinae
# 30  Chrysomelidae                           Bruchinae
# 31  Chrysomelidae                           Bruchinae
#
#                             Species  BE Letzter_Nachweis
# 0               Donacia brevicornis   0         vor 1907
# 1                   Donacia dentata   0             1937
# 2                   Donacia obscura   0         vor 1907
# 3                Donacia thalassina   0         vor 1950
# 4                 Donacia tomentosa   0             1943
# 5           Macroplea appendiculata   0         vor 1907
# 6              Lilioceris merdigera   0         vor 1913
# 7            Labidostomis humeralis   0             1897
# 8           Labidostomis tridentata   0             1949
# 9        Cryptocephalus bipunctatus   0         vor 1950
# 10         Cryptocephalus chrysopus   0         vor 1950
# 11            Cryptocephalus coryli   0             1906
# 12    Cryptocephalus decemmaculatus   0             1948
# 13     Cryptocephalus hypochaeridis   0             1946
# 14         Cryptocephalus janthinus   0             2008
# 15            Cryptocephalus laetus   0         vor 1900
# 16     Cryptocephalus octopunctatus   0         vor 1950
# 17              Cryptocephalus pini   0         vor 1950
# 18  Cryptocephalus quadripustulatus   0         vor 1950
# 19          Cryptocephalus querceti   0             1885
# 20      Pachybrachis hieroglyphicus   0             1885
# 21               Oomorphus concolor   0         vor 1920
# 22              Chrysolina cerealis   0         vor 1950
# 23                Prasocuris glabra   0             1960
# 24          Prasocuris hannoveriana   0         vor 1918
# 25           Galeruca melanocephala   0             1928
# 26              Chaetocnema confusa   0             1907
# 27               Dibolia schillingi   0             1942
# 28           Longitarsus nigerrimus   0             1958
# 29                 Bruchidius cisti   0         vor 1950
# 30                  Bruchus pisorum   0             1949
# 31                Bruchus rufimanus   0         vor 1950

# %%
# Saving the extracted csv to the "Data_cleaning_step1" directory
# export the dataframe as CSV

df.to_csv('../../Transformation/Data_cleaning_step1/Chrysomelidae_ Megalopodidae_Blattkäfer.csv', index=False)

# %% [markdown]
# # 02. Coleoptera Scarabaeoidea Blatthornkäfer.csv

# %%
# Read file into dataframe

df = pd.read_csv('Coleoptera Scarabaeoidea Blatthornkäfer.csv')
df.head()
# Out:
#                                    Species  BE Bestand  Trend_lang  \
# 0     Aphodius conspurcatus (LINNÉ, 1758)*   0      ex         NaN
# 1        Aphodius foetidus (HERBST, 1783)*   0      ex         NaN
# 2  Aphodius lividus (A. G. OLIVIER, 1789)*   0      ex         NaN
# 3           Aphodius niger (ILLIGER, 1797)   0      ex         NaN
# 4      Aphodius obliteratus (STURM, 1823)*   0      ex         NaN
#
#    Trend_kurz  RF   BB    D   GS GfU Common_name
# 0         NaN NaN  2.0  2.0  NaN   6         NaN
# 1         NaN NaN  NaN  NaN  NaN   6         NaN
# 2         NaN NaN  1.0  0.0  NaN   6         NaN
# 3         NaN NaN  1.0  3.0  NaN   6         NaN
# 4         NaN NaN  1.0  3.0  NaN   6         NaN

# %%
df.Trend_lang.isna().sum()
# Out:
# 22

# %%
df.Trend_kurz.isna().sum()
# Out:
# 22

# %%
df.RF.isna().sum()
# Out:
# 22

# %%
df.GS.isna().sum()
# Out:
# 20

# %%
df.Common_name.isna().sum()
# Out:
# 19

# %%
# dropping Trend_kurz and Trend_lang, RF columns

df.drop(columns = ["Trend_kurz", "Trend_lang", "RF"], inplace = True)

# %%
df.head()
# Out:
#                                    Species  BE Bestand   BB    D   GS GfU  \
# 0     Aphodius conspurcatus (LINNÉ, 1758)*   0      ex  2.0  2.0  NaN   6
# 1        Aphodius foetidus (HERBST, 1783)*   0      ex  NaN  NaN  NaN   6
# 2  Aphodius lividus (A. G. OLIVIER, 1789)*   0      ex  1.0  0.0  NaN   6
# 3           Aphodius niger (ILLIGER, 1797)   0      ex  1.0  3.0  NaN   6
# 4      Aphodius obliteratus (STURM, 1823)*   0      ex  1.0  3.0  NaN   6
#
#   Common_name
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
# Editing species column based on binomial nomenclature

df1 = df.Species.str.split(pat=" ", n = 3, expand = True)
df1
df.Species = df1[0].str.cat(df1[1], sep = " ")

# %%
df
# Out:
#                       Species  BE Bestand   BB    D   GS         GfU  \
# 0       Aphodius conspurcatus   0      ex  2.0  2.0  NaN           6
# 1           Aphodius foetidus   0      ex  NaN  NaN  NaN           6
# 2            Aphodius lividus   0      ex  1.0  0.0  NaN           6
# 3              Aphodius niger   0      ex  1.0  3.0  NaN           6
# 4        Aphodius obliteratus   0      ex  1.0  3.0  NaN           6
# 5           Aphodius paykulli   0      ex  NaN  NaN  NaN           6
# 6             Aphodius pictus   0      ex  1.0  3.0  NaN           6
# 7         Caccobius schreberi   0      ex  1.0  2.0  NaN           6
# 8              Copris lunaris   0      ex  2.0  2.0    §           6
# 9           Euheptaulacus sus   0      ex  NaN  2.0  NaN      7a, 8a
# 10     Euheptaulacus villosus   0      ex  NaN  2.0  NaN      7a, 8a
# 11           Gnorimus nobilis   0      ex  4.0  3.0  NaN     2a, 14a
# 12  Heptaulacus testudinarius   0      ex  1.0  2.0  NaN      7a, 8a
# 13   Ochodaeus chrysomeloides   0      ex  1.0  1.0  NaN      7a, 8a
# 14      Onthophagus illyricus   0      ex  NaN  3.0  NaN         NaN
# 15         Onthophagus taurus   0      ex  1.0  3.0  NaN           6
# 16          Protaetia fieberi   0      ex  1.0  2.0    §     2a, 14a
# 17          Rhysothorax rufus   0      ex  NaN  NaN  NaN      5a, 5b
# 18            Tropinota hirta   0      ex  3.0  3.0  NaN           ?
# 19           Trox cadaverinus   0      ex  2.0  2.0  NaN  6d, 7a, 8a
# 20              Trox hispidus   0      ex  3.0  NaN  NaN  6d, 7a, 8a
# 21             Trox sabulosus   0      ex  NaN  NaN  NaN  6d, 7a, 8a
#
#             Common_name
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# 5                   NaN
# 6                   NaN
# 7                   NaN
# 8         Mondhornkäfer
# 9                   NaN
# 10                  NaN
# 11      Edelscharrkäfer
# 12                  NaN
# 13                  NaN
# 14                  NaN
# 15                  NaN
# 16                  NaN
# 17                  NaN
# 18  Zottiger Rosenkäfer
# 19                  NaN
# 20                  NaN
# 21                  NaN

# %%
# Adding Family: Scarabaeoidea to all rows

i = 0;
while i < 22:
    df.at[i,"Family"] = "Scarabaeoidea"
    i = i + 1

df
# Out:
#                       Species  BE Bestand   BB    D   GS         GfU  \
# 0       Aphodius conspurcatus   0      ex  2.0  2.0  NaN           6
# 1           Aphodius foetidus   0      ex  NaN  NaN  NaN           6
# 2            Aphodius lividus   0      ex  1.0  0.0  NaN           6
# 3              Aphodius niger   0      ex  1.0  3.0  NaN           6
# 4        Aphodius obliteratus   0      ex  1.0  3.0  NaN           6
# 5           Aphodius paykulli   0      ex  NaN  NaN  NaN           6
# 6             Aphodius pictus   0      ex  1.0  3.0  NaN           6
# 7         Caccobius schreberi   0      ex  1.0  2.0  NaN           6
# 8              Copris lunaris   0      ex  2.0  2.0    §           6
# 9           Euheptaulacus sus   0      ex  NaN  2.0  NaN      7a, 8a
# 10     Euheptaulacus villosus   0      ex  NaN  2.0  NaN      7a, 8a
# 11           Gnorimus nobilis   0      ex  4.0  3.0  NaN     2a, 14a
# 12  Heptaulacus testudinarius   0      ex  1.0  2.0  NaN      7a, 8a
# 13   Ochodaeus chrysomeloides   0      ex  1.0  1.0  NaN      7a, 8a
# 14      Onthophagus illyricus   0      ex  NaN  3.0  NaN         NaN
# 15         Onthophagus taurus   0      ex  1.0  3.0  NaN           6
# 16          Protaetia fieberi   0      ex  1.0  2.0    §     2a, 14a
# 17          Rhysothorax rufus   0      ex  NaN  NaN  NaN      5a, 5b
# 18            Tropinota hirta   0      ex  3.0  3.0  NaN           ?
# 19           Trox cadaverinus   0      ex  2.0  2.0  NaN  6d, 7a, 8a
# 20              Trox hispidus   0      ex  3.0  NaN  NaN  6d, 7a, 8a
# 21             Trox sabulosus   0      ex  NaN  NaN  NaN  6d, 7a, 8a
#
#             Common_name         Family
# 0                   NaN  Scarabaeoidea
# 1                   NaN  Scarabaeoidea
# 2                   NaN  Scarabaeoidea
# 3                   NaN  Scarabaeoidea
# 4                   NaN  Scarabaeoidea
# 5                   NaN  Scarabaeoidea
# 6                   NaN  Scarabaeoidea
# 7                   NaN  Scarabaeoidea
# 8         Mondhornkäfer  Scarabaeoidea
# 9                   NaN  Scarabaeoidea
# 10                  NaN  Scarabaeoidea
# 11      Edelscharrkäfer  Scarabaeoidea
# 12                  NaN  Scarabaeoidea
# 13                  NaN  Scarabaeoidea
# 14                  NaN  Scarabaeoidea
# 15                  NaN  Scarabaeoidea
# 16                  NaN  Scarabaeoidea
# 17                  NaN  Scarabaeoidea
# 18  Zottiger Rosenkäfer  Scarabaeoidea
# 19                  NaN  Scarabaeoidea
# 20                  NaN  Scarabaeoidea
# 21                  NaN  Scarabaeoidea

# %%
df.columns
# Out:
# Index(['Species', 'BE', 'Bestand', 'BB', 'D', 'GS', 'GfU', 'Common_name',
#        'Family'],
#       dtype='object')

# %%
df = df.reindex(columns=['Family',
                         'Species', 
                         'BE', 
                         'Bestand', 
                         'BB', 
                         'D', 
                         'GS', 
                         'GfU', 
                         'Common_name'])
df
# Out:
#            Family                    Species  BE Bestand   BB    D   GS  \
# 0   Scarabaeoidea      Aphodius conspurcatus   0      ex  2.0  2.0  NaN
# 1   Scarabaeoidea          Aphodius foetidus   0      ex  NaN  NaN  NaN
# 2   Scarabaeoidea           Aphodius lividus   0      ex  1.0  0.0  NaN
# 3   Scarabaeoidea             Aphodius niger   0      ex  1.0  3.0  NaN
# 4   Scarabaeoidea       Aphodius obliteratus   0      ex  1.0  3.0  NaN
# 5   Scarabaeoidea          Aphodius paykulli   0      ex  NaN  NaN  NaN
# 6   Scarabaeoidea            Aphodius pictus   0      ex  1.0  3.0  NaN
# 7   Scarabaeoidea        Caccobius schreberi   0      ex  1.0  2.0  NaN
# 8   Scarabaeoidea             Copris lunaris   0      ex  2.0  2.0    §
# 9   Scarabaeoidea          Euheptaulacus sus   0      ex  NaN  2.0  NaN
# 10  Scarabaeoidea     Euheptaulacus villosus   0      ex  NaN  2.0  NaN
# 11  Scarabaeoidea           Gnorimus nobilis   0      ex  4.0  3.0  NaN
# 12  Scarabaeoidea  Heptaulacus testudinarius   0      ex  1.0  2.0  NaN
# 13  Scarabaeoidea   Ochodaeus chrysomeloides   0      ex  1.0  1.0  NaN
# 14  Scarabaeoidea      Onthophagus illyricus   0      ex  NaN  3.0  NaN
# 15  Scarabaeoidea         Onthophagus taurus   0      ex  1.0  3.0  NaN
# 16  Scarabaeoidea          Protaetia fieberi   0      ex  1.0  2.0    §
# 17  Scarabaeoidea          Rhysothorax rufus   0      ex  NaN  NaN  NaN
# 18  Scarabaeoidea            Tropinota hirta   0      ex  3.0  3.0  NaN
# 19  Scarabaeoidea           Trox cadaverinus   0      ex  2.0  2.0  NaN
# 20  Scarabaeoidea              Trox hispidus   0      ex  3.0  NaN  NaN
# 21  Scarabaeoidea             Trox sabulosus   0      ex  NaN  NaN  NaN
#
#            GfU          Common_name
# 0            6                  NaN
# 1            6                  NaN
# 2            6                  NaN
# 3            6                  NaN
# 4            6                  NaN
# 5            6                  NaN
# 6            6                  NaN
# 7            6                  NaN
# 8            6        Mondhornkäfer
# 9       7a, 8a                  NaN
# 10      7a, 8a                  NaN
# 11     2a, 14a      Edelscharrkäfer
# 12      7a, 8a                  NaN
# 13      7a, 8a                  NaN
# 14         NaN                  NaN
# 15           6                  NaN
# 16     2a, 14a                  NaN
# 17      5a, 5b                  NaN
# 18           ?  Zottiger Rosenkäfer
# 19  6d, 7a, 8a                  NaN
# 20  6d, 7a, 8a                  NaN
# 21  6d, 7a, 8a                  NaN

# %%
# Removing columns BB, D, GS, GfU
df.drop(columns = ["BB", "D", "GS", "GfU", "Bestand"], inplace = True)
df
# Out:
#            Family                    Species  BE          Common_name
# 0   Scarabaeoidea      Aphodius conspurcatus   0                  NaN
# 1   Scarabaeoidea          Aphodius foetidus   0                  NaN
# 2   Scarabaeoidea           Aphodius lividus   0                  NaN
# 3   Scarabaeoidea             Aphodius niger   0                  NaN
# 4   Scarabaeoidea       Aphodius obliteratus   0                  NaN
# 5   Scarabaeoidea          Aphodius paykulli   0                  NaN
# 6   Scarabaeoidea            Aphodius pictus   0                  NaN
# 7   Scarabaeoidea        Caccobius schreberi   0                  NaN
# 8   Scarabaeoidea             Copris lunaris   0        Mondhornkäfer
# 9   Scarabaeoidea          Euheptaulacus sus   0                  NaN
# 10  Scarabaeoidea     Euheptaulacus villosus   0                  NaN
# 11  Scarabaeoidea           Gnorimus nobilis   0      Edelscharrkäfer
# 12  Scarabaeoidea  Heptaulacus testudinarius   0                  NaN
# 13  Scarabaeoidea   Ochodaeus chrysomeloides   0                  NaN
# 14  Scarabaeoidea      Onthophagus illyricus   0                  NaN
# 15  Scarabaeoidea         Onthophagus taurus   0                  NaN
# 16  Scarabaeoidea          Protaetia fieberi   0                  NaN
# 17  Scarabaeoidea          Rhysothorax rufus   0                  NaN
# 18  Scarabaeoidea            Tropinota hirta   0  Zottiger Rosenkäfer
# 19  Scarabaeoidea           Trox cadaverinus   0                  NaN
# 20  Scarabaeoidea              Trox hispidus   0                  NaN
# 21  Scarabaeoidea             Trox sabulosus   0                  NaN

# %%
# Saving the extracted csv to the "Data_cleaning_step1" directory
# export the dataframe as CSV

df.to_csv('../../Transformation/Data_cleaning_step1/Coleoptera Scarabaeoidea Blatthornkäfer.csv', 
          index=False)

# %% [markdown]
# # 03.  Coleoptera_Wasserkäfer.csv

# %%
# Read file into dataframe

df = pd.read_csv('Coleoptera_Wasserkäfer.csv')
df.head()
# Out:
#              Species  RL Gefährdungsursachen  \
# 0  Hygrobia hermanni   0                   ?
# 1  Brychius elevatus   0                  5b
# 2  Agabus biguttatus   0             5b, 11c
# 3   Agabus clypealis   0             2d, 11c
# 4    Agabus guttatus   0             5b, 11c
#
#                   Letzter Nachweis in Berlin
# 0   Weißensee, ca. 1900, HORION (1941) (ZMB)
# 1      Tempelhof, ca. 1900, coll. Weiß (ZMB)
# 2  Frohnau, Bieselfließ, 1996, Hendrich leg.
# 3     Dahlem, NSG Langes Luch, 1987, BH leg.
# 4  Frohnau, Bieselfließ, 1996, Hendrich leg.

# %%
df
# Out:
#                      Species  RL Gefährdungsursachen  \
# 0          Hygrobia hermanni   0                   ?
# 1          Brychius elevatus   0                  5b
# 2          Agabus biguttatus   0             5b, 11c
# 3           Agabus clypealis   0             2d, 11c
# 4            Agabus guttatus   0             5b, 11c
# 5            Agabus labiatus   0              1a, 5b
# 6          Agabus striolatus   0             2d, 11c
# 7        Dytiscus latissimus   0                 11c
# 8      Dytiscus semisulcatus   0              1a, 5b
# 9     Graphoderus bilineatus   0        5b, 11c, 12c
# 10       Graphoderus zonatus   0        5b, 11c, 12c
# 11    Hydroporus elongatulus   0        2d, 11c, 12c
# 12  Hydroporus glabriusculus   0             2d, 11c
# 13    Hydroporus gyllenhalii   0                  1a
# 14        Hydroporus notatus   0                  1a
# 15      Hydroporus rufifrons   0        2d, 11c, 12c
# 16         Ilybius aenescens   0             2d, 11c
# 17           Ilybius similis   0             2d, 11c
# 18      Rhantus notaticollis   0                 12c
# 19        Rhantus suturellus   0             2d, 11c
# 20      Suphrodytes dorsalis   0             2d, 11c
# 21        Gyrinus distinctus   0          3b, 5, 11c
# 22           Gyrinus marinus   0          3b, 5, 11c
# 23           Gyrinus minutus   0             2d, 11c
# 24           Gyrinus natator   0             2d, 11c
# 25     Hydrochus megaphallus   0                   ?
# 26   Helophorus tuberculatus   0          Ausbleiben
# 27    Stenelmis canaliculata   0             5a, 11c
# 28            Dryops griseus   0             2d, 11c
# 29          Dryops nitidulus   0                   ?
# 30          Dryops similaris   0                  1a
#
#                           Letzter Nachweis in Berlin
# 0           Weißensee, ca. 1900, HORION (1941) (ZMB)
# 1              Tempelhof, ca. 1900, coll. Weiß (ZMB)
# 2          Frohnau, Bieselfließ, 1996, Hendrich leg.
# 3             Dahlem, NSG Langes Luch, 1987, BH leg.
# 4          Frohnau, Bieselfließ, 1996, Hendrich leg.
# 5     Tegel, Jungfernheide, ca. 1900, coll. Schilsky
# 6     Reinickendorf, ehem. Hermsdorfer See, 1994, BH
# 7            Tegel, Tegeler See, 1949, Weinhold leg.
# 8                      Pankow, Buch, 1926, Beck leg.
# 9        Berlin 10.1.1905, Sammlung Zimmermann (ZSM)
# 10      Zehlendorf, Buschgraben, 2001, Hendrich leg.
# 11     Köpenick, Gosener Wiesen, 1996, Hendrich leg.
# 12   Spandau, NSG Großer u. Kleiner Rohrpfuhl, 1993,
# 13     Spandau, ca. 1920, Schöppa leg. (HORION 1941)
# 14             Karlshorst, 1913, Ahlwarth leg. (ZMB)
# 15             Wannsee, NSG Bäkewiese, 1995, BH leg.
# 16       Spandau, NSG Teufelsbruch, 1987, Schlarbaum
# 17      Grunewald, NSG Hundekehlefenn, 1990, BH leg.
# 18             Karlshorst, 1913, Ahlwarth leg. (ZMB)
# 19       Schmöckwitz, ND Langes Luch, 1995, Hendrich
# 20    Spandau, NSG Teufelsbruch, 1986, Hendrich leg.
# 21          Havelufer, Großes Fenster, 1989, BH leg.
# 22         Buch, Karower Teiche, 1996, Hendrich leg.
# 23       Reinickendorf, Tegeler Fließ, 1989, BH leg.
# 24  Grunewald, NSG Teufelsfenn, 1959, Fery leg. (CF)
# 25        Tegel, Jungfernheide, ca. 1920, Zumpt leg.
# 26                  Tiergarten, 1889, Habelmann leg.
# 27   Berlin, 10.8.1900, 2 Exemplare, Maas leg. (MNG)
# 28  Spandau, NSG Teufelsbruch, 1973, Korge leg. (CK)
# 29   Lichterfelde, US-Truppenübungsplatz, 1983, Hen-
# 30             Spandau, Elsgraben, 1921, leg. ? (CK)

# %%
# Adding family

i = 0;
while i < 31:
    if i == 0:
        df.at[i,"Family"] = "Hygrobiidae"
    elif i == 1:
        df.at[i,"Family"] = "Haliplidae"
    elif ((i > 1) & (i < 21)):
        df.at[i,"Family"] = "Dytiscidae" 
    elif ((i > 20) & (i < 25)):
        df.at[i,"Family"] = "Gyrinidae"
    elif (i == 25):
        df.at[i,"Family"] = "Hydrochidae"
    elif (i == 26):
        df.at[i,"Family"] = "Helophoridae"
    elif (i == 27):
        df.at[i,"Family"] = "Elmidae"
    else:
        df.at[i,"Family"] = "Dryopidae"
    i = i + 1

df
# Out:
#                      Species  RL Gefährdungsursachen  \
# 0          Hygrobia hermanni   0                   ?
# 1          Brychius elevatus   0                  5b
# 2          Agabus biguttatus   0             5b, 11c
# 3           Agabus clypealis   0             2d, 11c
# 4            Agabus guttatus   0             5b, 11c
# 5            Agabus labiatus   0              1a, 5b
# 6          Agabus striolatus   0             2d, 11c
# 7        Dytiscus latissimus   0                 11c
# 8      Dytiscus semisulcatus   0              1a, 5b
# 9     Graphoderus bilineatus   0        5b, 11c, 12c
# 10       Graphoderus zonatus   0        5b, 11c, 12c
# 11    Hydroporus elongatulus   0        2d, 11c, 12c
# 12  Hydroporus glabriusculus   0             2d, 11c
# 13    Hydroporus gyllenhalii   0                  1a
# 14        Hydroporus notatus   0                  1a
# 15      Hydroporus rufifrons   0        2d, 11c, 12c
# 16         Ilybius aenescens   0             2d, 11c
# 17           Ilybius similis   0             2d, 11c
# 18      Rhantus notaticollis   0                 12c
# 19        Rhantus suturellus   0             2d, 11c
# 20      Suphrodytes dorsalis   0             2d, 11c
# 21        Gyrinus distinctus   0          3b, 5, 11c
# 22           Gyrinus marinus   0          3b, 5, 11c
# 23           Gyrinus minutus   0             2d, 11c
# 24           Gyrinus natator   0             2d, 11c
# 25     Hydrochus megaphallus   0                   ?
# 26   Helophorus tuberculatus   0          Ausbleiben
# 27    Stenelmis canaliculata   0             5a, 11c
# 28            Dryops griseus   0             2d, 11c
# 29          Dryops nitidulus   0                   ?
# 30          Dryops similaris   0                  1a
#
#                           Letzter Nachweis in Berlin        Family
# 0           Weißensee, ca. 1900, HORION (1941) (ZMB)   Hygrobiidae
# 1              Tempelhof, ca. 1900, coll. Weiß (ZMB)    Haliplidae
# 2          Frohnau, Bieselfließ, 1996, Hendrich leg.    Dytiscidae
# 3             Dahlem, NSG Langes Luch, 1987, BH leg.    Dytiscidae
# 4          Frohnau, Bieselfließ, 1996, Hendrich leg.    Dytiscidae
# 5     Tegel, Jungfernheide, ca. 1900, coll. Schilsky    Dytiscidae
# 6     Reinickendorf, ehem. Hermsdorfer See, 1994, BH    Dytiscidae
# 7            Tegel, Tegeler See, 1949, Weinhold leg.    Dytiscidae
# 8                      Pankow, Buch, 1926, Beck leg.    Dytiscidae
# 9        Berlin 10.1.1905, Sammlung Zimmermann (ZSM)    Dytiscidae
# 10      Zehlendorf, Buschgraben, 2001, Hendrich leg.    Dytiscidae
# 11     Köpenick, Gosener Wiesen, 1996, Hendrich leg.    Dytiscidae
# 12   Spandau, NSG Großer u. Kleiner Rohrpfuhl, 1993,    Dytiscidae
# 13     Spandau, ca. 1920, Schöppa leg. (HORION 1941)    Dytiscidae
# 14             Karlshorst, 1913, Ahlwarth leg. (ZMB)    Dytiscidae
# 15             Wannsee, NSG Bäkewiese, 1995, BH leg.    Dytiscidae
# 16       Spandau, NSG Teufelsbruch, 1987, Schlarbaum    Dytiscidae
# 17      Grunewald, NSG Hundekehlefenn, 1990, BH leg.    Dytiscidae
# 18             Karlshorst, 1913, Ahlwarth leg. (ZMB)    Dytiscidae
# 19       Schmöckwitz, ND Langes Luch, 1995, Hendrich    Dytiscidae
# 20    Spandau, NSG Teufelsbruch, 1986, Hendrich leg.    Dytiscidae
# 21          Havelufer, Großes Fenster, 1989, BH leg.     Gyrinidae
# 22         Buch, Karower Teiche, 1996, Hendrich leg.     Gyrinidae
# 23       Reinickendorf, Tegeler Fließ, 1989, BH leg.     Gyrinidae
# 24  Grunewald, NSG Teufelsfenn, 1959, Fery leg. (CF)     Gyrinidae
# 25        Tegel, Jungfernheide, ca. 1920, Zumpt leg.   Hydrochidae
# 26                  Tiergarten, 1889, Habelmann leg.  Helophoridae
# 27   Berlin, 10.8.1900, 2 Exemplare, Maas leg. (MNG)       Elmidae
# 28  Spandau, NSG Teufelsbruch, 1973, Korge leg. (CK)     Dryopidae
# 29   Lichterfelde, US-Truppenübungsplatz, 1983, Hen-     Dryopidae
# 30             Spandau, Elsgraben, 1921, leg. ? (CK)     Dryopidae

# %%
df = df.reindex(columns=['Family',
                         'Species', 
                         'RL', 
                         'Letzter Nachweis in Berlin'])
df
# Out:
#           Family                   Species  RL  \
# 0    Hygrobiidae         Hygrobia hermanni   0
# 1     Haliplidae         Brychius elevatus   0
# 2     Dytiscidae         Agabus biguttatus   0
# 3     Dytiscidae          Agabus clypealis   0
# 4     Dytiscidae           Agabus guttatus   0
# 5     Dytiscidae           Agabus labiatus   0
# 6     Dytiscidae         Agabus striolatus   0
# 7     Dytiscidae       Dytiscus latissimus   0
# 8     Dytiscidae     Dytiscus semisulcatus   0
# 9     Dytiscidae    Graphoderus bilineatus   0
# 10    Dytiscidae       Graphoderus zonatus   0
# 11    Dytiscidae    Hydroporus elongatulus   0
# 12    Dytiscidae  Hydroporus glabriusculus   0
# 13    Dytiscidae    Hydroporus gyllenhalii   0
# 14    Dytiscidae        Hydroporus notatus   0
# 15    Dytiscidae      Hydroporus rufifrons   0
# 16    Dytiscidae         Ilybius aenescens   0
# 17    Dytiscidae           Ilybius similis   0
# 18    Dytiscidae      Rhantus notaticollis   0
# 19    Dytiscidae        Rhantus suturellus   0
# 20    Dytiscidae      Suphrodytes dorsalis   0
# 21     Gyrinidae        Gyrinus distinctus   0
# 22     Gyrinidae           Gyrinus marinus   0
# 23     Gyrinidae           Gyrinus minutus   0
# 24     Gyrinidae           Gyrinus natator   0
# 25   Hydrochidae     Hydrochus megaphallus   0
# 26  Helophoridae   Helophorus tuberculatus   0
# 27       Elmidae    Stenelmis canaliculata   0
# 28     Dryopidae            Dryops griseus   0
# 29     Dryopidae          Dryops nitidulus   0
# 30     Dryopidae          Dryops similaris   0
#
#                           Letzter Nachweis in Berlin
# 0           Weißensee, ca. 1900, HORION (1941) (ZMB)
# 1              Tempelhof, ca. 1900, coll. Weiß (ZMB)
# 2          Frohnau, Bieselfließ, 1996, Hendrich leg.
# 3             Dahlem, NSG Langes Luch, 1987, BH leg.
# 4          Frohnau, Bieselfließ, 1996, Hendrich leg.
# 5     Tegel, Jungfernheide, ca. 1900, coll. Schilsky
# 6     Reinickendorf, ehem. Hermsdorfer See, 1994, BH
# 7            Tegel, Tegeler See, 1949, Weinhold leg.
# 8                      Pankow, Buch, 1926, Beck leg.
# 9        Berlin 10.1.1905, Sammlung Zimmermann (ZSM)
# 10      Zehlendorf, Buschgraben, 2001, Hendrich leg.
# 11     Köpenick, Gosener Wiesen, 1996, Hendrich leg.
# 12   Spandau, NSG Großer u. Kleiner Rohrpfuhl, 1993,
# 13     Spandau, ca. 1920, Schöppa leg. (HORION 1941)
# 14             Karlshorst, 1913, Ahlwarth leg. (ZMB)
# 15             Wannsee, NSG Bäkewiese, 1995, BH leg.
# 16       Spandau, NSG Teufelsbruch, 1987, Schlarbaum
# 17      Grunewald, NSG Hundekehlefenn, 1990, BH leg.
# 18             Karlshorst, 1913, Ahlwarth leg. (ZMB)
# 19       Schmöckwitz, ND Langes Luch, 1995, Hendrich
# 20    Spandau, NSG Teufelsbruch, 1986, Hendrich leg.
# 21          Havelufer, Großes Fenster, 1989, BH leg.
# 22         Buch, Karower Teiche, 1996, Hendrich leg.
# 23       Reinickendorf, Tegeler Fließ, 1989, BH leg.
# 24  Grunewald, NSG Teufelsfenn, 1959, Fery leg. (CF)
# 25        Tegel, Jungfernheide, ca. 1920, Zumpt leg.
# 26                  Tiergarten, 1889, Habelmann leg.
# 27   Berlin, 10.8.1900, 2 Exemplare, Maas leg. (MNG)
# 28  Spandau, NSG Teufelsbruch, 1973, Korge leg. (CK)
# 29   Lichterfelde, US-Truppenübungsplatz, 1983, Hen-
# 30             Spandau, Elsgraben, 1921, leg. ? (CK)

# %%
df.rename({
    "RL": "BE",
    "Letzter Nachweis in Berlin": "Letzter Nachweis"
}, 
    axis='columns',
    inplace = True
)

# %%
df.head()
# Out:
#         Family            Species  BE  \
# 0  Hygrobiidae  Hygrobia hermanni   0
# 1   Haliplidae  Brychius elevatus   0
# 2   Dytiscidae  Agabus biguttatus   0
# 3   Dytiscidae   Agabus clypealis   0
# 4   Dytiscidae    Agabus guttatus   0
#
#                             Letzter Nachweis
# 0   Weißensee, ca. 1900, HORION (1941) (ZMB)
# 1      Tempelhof, ca. 1900, coll. Weiß (ZMB)
# 2  Frohnau, Bieselfließ, 1996, Hendrich leg.
# 3     Dahlem, NSG Langes Luch, 1987, BH leg.
# 4  Frohnau, Bieselfließ, 1996, Hendrich leg.

# %%
# Saving the extracted csv to the "Data_cleaning_step1" directory
# export the dataframe as CSV

df.to_csv('../../Transformation/Data_cleaning_step1/Coleoptera_Wasserkäfer.csv', 
          index=False)

# %% [markdown]
# # 04.Coleoptera_Bostrichoidea_Cleroidea_Cucujoidea_Elateroidea_Lymexyloidea_Tenebrioidea.csv

# %%
# Read file into dataframe

df = pd.read_csv('Coleoptera_Bostrichoidea_Cleroidea_Cucujoidea_Elateroidea_Lymexyloidea_Tenebrioidea.csv')
df.head()
# Out:
#                                   Species  BE Bestand  Trend_lang  Trend_kurz  \
# 0    Lichenophanes varius (ILLIGER, 1801)   0      ex         NaN         NaN
# 1  Endecatomus reticulatus (HERBST, 1793)   0      ex         NaN         NaN
# 2    Anobium emarginatum DUFTSCHMID, 1825   0      ex         NaN         NaN
# 3    Ernobius mulsanti KIESENWETTER, 1877   0      ex         NaN         NaN
# 4  Xyletinus pectinatus (FABRICIUS, 1792)   0      ex         NaN         NaN
#
#    RF  BB    D  GS  Neobiota Letzter_Nachweis
# 0 NaN NaN  2.0 NaN       NaN         vor 1900
# 1 NaN NaN  0.0 NaN       NaN         vor 1900
# 2 NaN NaN  3.0 NaN       NaN         vor 1900
# 3 NaN NaN  0.0 NaN       NaN         vor 1900
# 4 NaN NaN  NaN NaN       NaN         vor 1900

# %%
df.describe()
# Out:
#          BE  Trend_lang  Trend_kurz   RF   BB          D   GS  Neobiota
# count  40.0         0.0         0.0  0.0  0.0  23.000000  0.0       0.0
# mean    0.0         NaN         NaN  NaN  NaN   1.739130  NaN       NaN
# std     0.0         NaN         NaN  NaN  NaN   0.915393  NaN       NaN
# min     0.0         NaN         NaN  NaN  NaN   0.000000  NaN       NaN
# 25%     0.0         NaN         NaN  NaN  NaN   1.000000  NaN       NaN
# 50%     0.0         NaN         NaN  NaN  NaN   2.000000  NaN       NaN
# 75%     0.0         NaN         NaN  NaN  NaN   2.000000  NaN       NaN
# max     0.0         NaN         NaN  NaN  NaN   3.000000  NaN       NaN

# %%
# Removing columns Trend_lang, Trend_kurz, RF, BB, D, GS, Neobiota
df.drop(columns = ["Trend_lang", "Trend_kurz", "RF", "BB", "D", "GS", "Neobiota", "Bestand"], inplace = True)
df
# Out:
#                                           Species  BE Letzter_Nachweis
# 0            Lichenophanes varius (ILLIGER, 1801)   0         vor 1900
# 1          Endecatomus reticulatus (HERBST, 1793)   0         vor 1900
# 2            Anobium emarginatum DUFTSCHMID, 1825   0         vor 1900
# 3            Ernobius mulsanti KIESENWETTER, 1877   0         vor 1900
# 4          Xyletinus pectinatus (FABRICIUS, 1792)   0         vor 1900
# 5   Dermestoides sanguinicollis (FABRICIUS, 1787)   0         vor 1900
# 6                Korynetes ruficornis STURM, 1837   0         vor 1900
# 7                  Opilo domesticus (STURM, 1837)   0         vor 1900
# 8                Trichodes apiarius (LINNÉ, 1758)   0         vor 1900
# 9            Trichoceble floralis (OLIVIER, 1790)   0         vor 1900
# 10          Phloiophilus edwardsii STEPHENS, 1830   0         vor 1900
# 11            Temnoscheila caerulea OLIVIER, 1790   0         vor 1900
# 12                  Atomaria badia ERICHSON, 1846   0         vor 1900
# 13                  Atomaria munda ERICHSON, 1846   0         vor 1900
# 14                  Atomaria peltata KRAATZ, 1853   0         vor 1900
# 15              Atomaria procerula ERICHSON, 1846   0         vor 1900
# 16                Atomaria pulchra ERICHSON, 1846   0         vor 1900
# 17           Cryptophagus subfumatus KRAATZ, 1856   0         vor 1900
# 18        Pediacus dermestoides (FABRICIUS, 1792)   0         vor 1900
# 19             Triplax lepida (FALDERMANN, 1835)*   0         vor 1900
# 20           Triplax scutellaris CARPENTIER, 1825   0         vor 1900
# 21            Cryptolestes weisei (REITTER, 1879)   0         vor 1900
# 22        Notolaemus unifasciatus (PAYKULL, 1801)   0         vor 1900
# 23            Monotoma quadrifoveolata AUBÉ, 1837   0         vor 1900
# 24                 Nitidula rufipes (LINNÉ, 1767)   0         vor 1900
# 25            Ampedus praeustus (FABRICIUS, 1792)   0         vor 1900
# 26            Ampedus rufipennis (STEPHENS, 1830)   0         vor 1900
# 27        Megapenthes lugens (REDTENBACHER, 1842)   0         vor 1900
# 28        Melanotus crassicollis (ERICHSON, 1841)   0         vor 1900
# 29               Trixagus obtusus (CURTIS, 1827)*   0         vor 1900
# 30             Aglenus brunneus (GYLLENHAL, 1813)   0         vor 1900
# 31            Osphya bipunctata (FABRICIUS, 1775)   0         vor 1900
# 32             Xylita laevigata (HELLENIUS, 1786)   0         vor 1900
# 33           Anogcodes ferruginea (SCHRANK, 1776)   0         vor 1900
# 34               Salpingus aeneus (OLIVIER, 1790)   0         vor 1900
# 35                  Corticeus suberis LUCAS, 1846   0         vor 1900
# 36          Menephilus cylindricus (HERBST, 1784)   0         vor 1900
# 37         Mycetochara flavipes (FABRICIUS, 1792)   0         vor 1900
# 38       Mycetochara pygmaea (REDTENBACHER, 1874)   0         vor 1900
# 39                Omophlus betulae (HERBST, 1783)   0         vor 1900

# %%
# Editing species column based on binomial nomenclature

df1 = df.Species.str.split(pat=" ", n = 3, expand = True)
df1
df.Species = df1[0].str.cat(df1[1], sep = " ")

# %%
df.head()
# Out:
#                    Species  BE Letzter_Nachweis
# 0     Lichenophanes varius   0         vor 1900
# 1  Endecatomus reticulatus   0         vor 1900
# 2      Anobium emarginatum   0         vor 1900
# 3        Ernobius mulsanti   0         vor 1900
# 4     Xyletinus pectinatus   0         vor 1900

# %%
# Adding family

i = 0;
while i < 40:
    if (i >= 0) & (i <= 4):
        df.at[i,"Superfamily"] = "Bostrichoidea"
        
        if i == 0:
            df.at[i,"Family"] = "Bostrichidae"
        elif i == 1:
            df.at[i,"Family"] = "Endecatomidae"
        elif ((i > 1) & (i <= 4)):
            df.at[i,"Family"] = "Ptinidae" 
    elif (i > 4) & (i <= 11):
        df.at[i,"Superfamily"] = "Cleroidea"
        
        if ((i > 4) & (i <= 8)):
            df.at[i,"Family"] = "Cleridae"
        elif (i == 9):
            df.at[i,"Family"] = "Dasytidae"
        elif (i == 10):
            df.at[i,"Family"] = "Phloiophilidae"
        elif (i == 11):
            df.at[i,"Family"] = "Trogossitidae"
            
    elif (i > 11) & (i <= 24):
        df.at[i,"Superfamily"] = "Cucujoidea"
        
        if ((i > 11) & (i <= 17)):
            df.at[i,"Family"] = "Cleridae"
        elif (i == 18):
            df.at[i,"Family"] = "Cucujidae"
        elif ((i > 18) & (i <= 20)):
            df.at[i,"Family"] = "Erotylidae"
        elif ((i > 20) & (i <= 22)):
            df.at[i,"Family"] = "Laemophloeidae"
        elif (i == 23):
            df.at[i,"Family"] = "Monotomidae"
        elif (i == 24):
            df.at[i,"Family"] = "Nitidulidae"
            
    elif (i > 24) & (i <= 29):
        df.at[i,"Superfamily"] = "Elateroidea"

        if ((i > 24) & (i <= 28)):
            df.at[i,"Family"] = "Elateridae"
        elif (i == 29):
            df.at[i,"Family"] = "Throscidae"           
            
    elif (i > 29):
        df.at[i,"Superfamily"] = "Tenebrioidea"
        
        if (i == 30):
            df.at[i,"Family"] = "Colydiidae"
        elif ((i > 30) & (i <= 32)):
            df.at[i,"Family"] = "Melandryidae"
        elif (i == 33):
            df.at[i,"Family"] = "Oedemeridae"
        elif (i == 34):
            df.at[i,"Family"] = "Salpingidae"
        else:
            df.at[i,"Family"] = "Tenebrionidae"
                
    i = i + 1

df
# Out:
#                         Species  BE Letzter_Nachweis    Superfamily  \
# 0          Lichenophanes varius   0         vor 1900  Bostrichoidea
# 1       Endecatomus reticulatus   0         vor 1900  Bostrichoidea
# 2           Anobium emarginatum   0         vor 1900  Bostrichoidea
# 3             Ernobius mulsanti   0         vor 1900  Bostrichoidea
# 4          Xyletinus pectinatus   0         vor 1900  Bostrichoidea
# 5   Dermestoides sanguinicollis   0         vor 1900      Cleroidea
# 6          Korynetes ruficornis   0         vor 1900      Cleroidea
# 7              Opilo domesticus   0         vor 1900      Cleroidea
# 8            Trichodes apiarius   0         vor 1900      Cleroidea
# 9          Trichoceble floralis   0         vor 1900      Cleroidea
# 10       Phloiophilus edwardsii   0         vor 1900      Cleroidea
# 11        Temnoscheila caerulea   0         vor 1900      Cleroidea
# 12               Atomaria badia   0         vor 1900     Cucujoidea
# 13               Atomaria munda   0         vor 1900     Cucujoidea
# 14             Atomaria peltata   0         vor 1900     Cucujoidea
# 15           Atomaria procerula   0         vor 1900     Cucujoidea
# 16             Atomaria pulchra   0         vor 1900     Cucujoidea
# 17      Cryptophagus subfumatus   0         vor 1900     Cucujoidea
# 18        Pediacus dermestoides   0         vor 1900     Cucujoidea
# 19               Triplax lepida   0         vor 1900     Cucujoidea
# 20          Triplax scutellaris   0         vor 1900     Cucujoidea
# 21          Cryptolestes weisei   0         vor 1900     Cucujoidea
# 22      Notolaemus unifasciatus   0         vor 1900     Cucujoidea
# 23     Monotoma quadrifoveolata   0         vor 1900     Cucujoidea
# 24             Nitidula rufipes   0         vor 1900     Cucujoidea
# 25            Ampedus praeustus   0         vor 1900    Elateroidea
# 26           Ampedus rufipennis   0         vor 1900    Elateroidea
# 27           Megapenthes lugens   0         vor 1900    Elateroidea
# 28       Melanotus crassicollis   0         vor 1900    Elateroidea
# 29             Trixagus obtusus   0         vor 1900    Elateroidea
# 30             Aglenus brunneus   0         vor 1900   Tenebrioidea
# 31            Osphya bipunctata   0         vor 1900   Tenebrioidea
# 32             Xylita laevigata   0         vor 1900   Tenebrioidea
# 33         Anogcodes ferruginea   0         vor 1900   Tenebrioidea
# 34             Salpingus aeneus   0         vor 1900   Tenebrioidea
# 35            Corticeus suberis   0         vor 1900   Tenebrioidea
# 36       Menephilus cylindricus   0         vor 1900   Tenebrioidea
# 37         Mycetochara flavipes   0         vor 1900   Tenebrioidea
# 38          Mycetochara pygmaea   0         vor 1900   Tenebrioidea
# 39             Omophlus betulae   0         vor 1900   Tenebrioidea
#
#             Family
# 0     Bostrichidae
# 1    Endecatomidae
# 2         Ptinidae
# 3         Ptinidae
# 4         Ptinidae
# 5         Cleridae
# 6         Cleridae
# 7         Cleridae
# 8         Cleridae
# 9        Dasytidae
# 10  Phloiophilidae
# 11   Trogossitidae
# 12        Cleridae
# 13        Cleridae
# 14        Cleridae
# 15        Cleridae
# 16        Cleridae
# 17        Cleridae
# 18       Cucujidae
# 19      Erotylidae
# 20      Erotylidae
# 21  Laemophloeidae
# 22  Laemophloeidae
# 23     Monotomidae
# 24     Nitidulidae
# 25      Elateridae
# 26      Elateridae
# 27      Elateridae
# 28      Elateridae
# 29      Throscidae
# 30      Colydiidae
# 31    Melandryidae
# 32    Melandryidae
# 33     Oedemeridae
# 34     Salpingidae
# 35   Tenebrionidae
# 36   Tenebrionidae
# 37   Tenebrionidae
# 38   Tenebrionidae
# 39   Tenebrionidae

# %%
# Saving the extracted csv to the "Data_cleaning_step1" directory
# export the dataframe as CSV

df.to_csv('../../Transformation/Data_cleaning_step1/Coleoptera_Bostrichoidea_Cleroidea_Cucujoidea_Elateroidea_Lymexyloidea_Tenebrioidea.csv', 
          index=False)

# %% [markdown]
# # 05. Coleoptera_Buprestidae_Prachtkäfer.csv

# %%
# Read file into dataframe

df = pd.read_csv('Coleoptera_Buprestidae_Prachtkäfer.csv')
df.head()
# Out:
#                                      Species  BE Bestand  Trend_lang  \
# 0       Dicerca berolinensis (HERBST, 1779)*   0      ex         NaN
# 1  Dicerca alni (FISCHER VON WALDHEIM, 1824)   0      ex         NaN
# 2    Buprestis haemorrhoidalis HERBST, 1780*   0      ex         NaN
# 3      Melanophila acuminata (DEGEER, 1774)*   0      ex         NaN
# 4         Anthaxia senicula (SCHRANK, 1789)*   0      ex         NaN
#
#    Trend_kurz  RF   BB    D   GS                Gfu Vorzugs-habitat  \
# 0         NaN NaN  1.0    2    §  9, 12b, 14a, 14f?              WB
# 1         NaN NaN  1.0    2    §        9, 12b, 14a              WM
# 2         NaN NaN  0.0    2    §               14a?          WK, WN
# 3         NaN NaN  NaN    2    §           12b, 14a          WK, WN
# 4         NaN NaN  NaN  NaN  NaN    2a, 9, 12b, 14a              WH
#
#   Letzter Nachweis
# 0         vor 1907
# 1         vor 1900
# 2             1937
# 3             1970
# 4         vor 1900

# %%
df.describe(include= 'all')
# Out:
#                                      Species   BE Bestand  Trend_lang  \
# count                                      7  7.0       7         0.0
# unique                                     7  NaN       1         NaN
# top     Dicerca berolinensis (HERBST, 1779)*  NaN      ex         NaN
# freq                                       1  NaN       7         NaN
# mean                                     NaN  0.0     NaN         NaN
# std                                      NaN  0.0     NaN         NaN
# min                                      NaN  0.0     NaN         NaN
# 25%                                      NaN  0.0     NaN         NaN
# 50%                                      NaN  0.0     NaN         NaN
# 75%                                      NaN  0.0     NaN         NaN
# max                                      NaN  0.0     NaN         NaN
#
#         Trend_kurz   RF        BB    D   GS                Gfu  \
# count          0.0  0.0  5.000000    6    6                  7
# unique         NaN  NaN       NaN    3    1                  7
# top            NaN  NaN       NaN    2    §  9, 12b, 14a, 14f?
# freq           NaN  NaN       NaN    4    6                  1
# mean           NaN  NaN  0.800000  NaN  NaN                NaN
# std            NaN  NaN  0.447214  NaN  NaN                NaN
# min            NaN  NaN  0.000000  NaN  NaN                NaN
# 25%            NaN  NaN  1.000000  NaN  NaN                NaN
# 50%            NaN  NaN  1.000000  NaN  NaN                NaN
# 75%            NaN  NaN  1.000000  NaN  NaN                NaN
# max            NaN  NaN  1.000000  NaN  NaN                NaN
#
#        Vorzugs-habitat Letzter Nachweis
# count                7                7
# unique               6                5
# top             WK, WN         vor 1900
# freq                 2                2
# mean               NaN              NaN
# std                NaN              NaN
# min                NaN              NaN
# 25%                NaN              NaN
# 50%                NaN              NaN
# 75%                NaN              NaN
# max                NaN              NaN

# %%
# Removing columns Trend_lang, Trend_kurz, RF, BB, D, GS, Gfu, Vorzugs-habitat, Bestand
df.drop(columns = ["Trend_lang", 
                   "Trend_kurz", 
                   "RF", 
                   "BB", 
                   "D", 
                   "GS", 
                   "Gfu", 
                   "Vorzugs-habitat",
                   "Bestand"], inplace = True)
df
# Out:
#                                      Species  BE Letzter Nachweis
# 0       Dicerca berolinensis (HERBST, 1779)*   0         vor 1907
# 1  Dicerca alni (FISCHER VON WALDHEIM, 1824)   0         vor 1900
# 2    Buprestis haemorrhoidalis HERBST, 1780*   0             1937
# 3      Melanophila acuminata (DEGEER, 1774)*   0             1970
# 4         Anthaxia senicula (SCHRANK, 1789)*   0         vor 1900
# 5   Aphanisticus emarginatus (OLIVIER, 1790)   0         vor 1919
# 6      Aphanisticus pusillus (OLIVIER, 1790)   0             1970

# %%
# Editing species column based on binomial nomenclature

df1 = df.Species.str.split(pat=" ", n = 3, expand = True)
df1
df.Species = df1[0].str.cat(df1[1], sep = " ")

# %%
df.head()
# Out:
#                      Species  BE Letzter Nachweis
# 0       Dicerca berolinensis   0         vor 1907
# 1               Dicerca alni   0         vor 1900
# 2  Buprestis haemorrhoidalis   0             1937
# 3      Melanophila acuminata   0             1970
# 4          Anthaxia senicula   0         vor 1900

# %%
df["Family"] = "Buprestidae"
df.head()
# Out:
#                      Species  BE Letzter Nachweis       Family
# 0       Dicerca berolinensis   0         vor 1907  Buprestidae
# 1               Dicerca alni   0         vor 1900  Buprestidae
# 2  Buprestis haemorrhoidalis   0             1937  Buprestidae
# 3      Melanophila acuminata   0             1970  Buprestidae
# 4          Anthaxia senicula   0         vor 1900  Buprestidae

# %%
df.at[0,"Subfamily"] = "Chrysochroinae"
df.head()
# Out:
#                      Species  BE Letzter Nachweis       Family       Subfamily
# 0       Dicerca berolinensis   0         vor 1907  Buprestidae  Chrysochroinae
# 1               Dicerca alni   0         vor 1900  Buprestidae             NaN
# 2  Buprestis haemorrhoidalis   0             1937  Buprestidae             NaN
# 3      Melanophila acuminata   0             1970  Buprestidae             NaN
# 4          Anthaxia senicula   0         vor 1900  Buprestidae             NaN

# %%
df.at[1,"Subfamily"] = "Chrysochroinae"
df.head()
# Out:
#                      Species  BE Letzter Nachweis       Family       Subfamily
# 0       Dicerca berolinensis   0         vor 1907  Buprestidae  Chrysochroinae
# 1               Dicerca alni   0         vor 1900  Buprestidae  Chrysochroinae
# 2  Buprestis haemorrhoidalis   0             1937  Buprestidae             NaN
# 3      Melanophila acuminata   0             1970  Buprestidae             NaN
# 4          Anthaxia senicula   0         vor 1900  Buprestidae             NaN

# %%
df.at[2,"Subfamily"] = "Buprestinae"
df.head()
# Out:
#                      Species  BE Letzter Nachweis       Family       Subfamily
# 0       Dicerca berolinensis   0         vor 1907  Buprestidae  Chrysochroinae
# 1               Dicerca alni   0         vor 1900  Buprestidae  Chrysochroinae
# 2  Buprestis haemorrhoidalis   0             1937  Buprestidae     Buprestinae
# 3      Melanophila acuminata   0             1970  Buprestidae             NaN
# 4          Anthaxia senicula   0         vor 1900  Buprestidae             NaN

# %%
df.at[3,"Subfamily"] = "Buprestinae"
df.head()
# Out:
#                      Species  BE Letzter Nachweis       Family       Subfamily
# 0       Dicerca berolinensis   0         vor 1907  Buprestidae  Chrysochroinae
# 1               Dicerca alni   0         vor 1900  Buprestidae  Chrysochroinae
# 2  Buprestis haemorrhoidalis   0             1937  Buprestidae     Buprestinae
# 3      Melanophila acuminata   0             1970  Buprestidae     Buprestinae
# 4          Anthaxia senicula   0         vor 1900  Buprestidae             NaN

# %%
df.at[4,"Subfamily"] = "Buprestinae"
df.head()
# Out:
#                      Species  BE Letzter Nachweis       Family       Subfamily
# 0       Dicerca berolinensis   0         vor 1907  Buprestidae  Chrysochroinae
# 1               Dicerca alni   0         vor 1900  Buprestidae  Chrysochroinae
# 2  Buprestis haemorrhoidalis   0             1937  Buprestidae     Buprestinae
# 3      Melanophila acuminata   0             1970  Buprestidae     Buprestinae
# 4          Anthaxia senicula   0         vor 1900  Buprestidae     Buprestinae

# %%
df
# Out:
#                      Species  BE Letzter Nachweis       Family       Subfamily
# 0       Dicerca berolinensis   0         vor 1907  Buprestidae  Chrysochroinae
# 1               Dicerca alni   0         vor 1900  Buprestidae  Chrysochroinae
# 2  Buprestis haemorrhoidalis   0             1937  Buprestidae     Buprestinae
# 3      Melanophila acuminata   0             1970  Buprestidae     Buprestinae
# 4          Anthaxia senicula   0         vor 1900  Buprestidae     Buprestinae
# 5   Aphanisticus emarginatus   0         vor 1919  Buprestidae             NaN
# 6      Aphanisticus pusillus   0             1970  Buprestidae             NaN

# %%
df.at[5,"Subfamily"] = "Agrilinae"
df
# Out:
#                      Species  BE Letzter Nachweis       Family       Subfamily
# 0       Dicerca berolinensis   0         vor 1907  Buprestidae  Chrysochroinae
# 1               Dicerca alni   0         vor 1900  Buprestidae  Chrysochroinae
# 2  Buprestis haemorrhoidalis   0             1937  Buprestidae     Buprestinae
# 3      Melanophila acuminata   0             1970  Buprestidae     Buprestinae
# 4          Anthaxia senicula   0         vor 1900  Buprestidae     Buprestinae
# 5   Aphanisticus emarginatus   0         vor 1919  Buprestidae       Agrilinae
# 6      Aphanisticus pusillus   0             1970  Buprestidae             NaN

# %%
df.at[6,"Subfamily"] = "Agrilinae"
df
# Out:
#                      Species  BE Letzter Nachweis       Family       Subfamily
# 0       Dicerca berolinensis   0         vor 1907  Buprestidae  Chrysochroinae
# 1               Dicerca alni   0         vor 1900  Buprestidae  Chrysochroinae
# 2  Buprestis haemorrhoidalis   0             1937  Buprestidae     Buprestinae
# 3      Melanophila acuminata   0             1970  Buprestidae     Buprestinae
# 4          Anthaxia senicula   0         vor 1900  Buprestidae     Buprestinae
# 5   Aphanisticus emarginatus   0         vor 1919  Buprestidae       Agrilinae
# 6      Aphanisticus pusillus   0             1970  Buprestidae       Agrilinae

# %%
# Saving the extracted csv to the "Data_cleaning_step1" directory
# export the dataframe as CSV

df.to_csv('../../Transformation/Data_cleaning_step1/Coleoptera_Buprestidae_Prachtkäfer.csv', 
          index=False)

# %% [markdown]
# # 06. Coleoptera_Carabidae_Laufkäfer.csv

# %%
# Read file into dataframe

df = pd.read_csv('Coleoptera_Carabidae_Laufkäfer.csv')
df.head()
# Out:
#                            Species  BE BB DE   GS Häufigkeit Vorzugshabitate  \
# 0    Acupalpus maculatus (SCHAUM)*   0  2  3  NaN         ex            (1)?
# 1  Agonum gracilipes (DUFTSCHMID)*   0  1  D  NaN         ex             (7)
# 2    Agonum hypocrita (APFELBECK)*   0  1  1  NaN         ex               2
# 3       Agonum impressum (PANZER)*   0  1  1  NaN         ex               1
# 4       Amara famelica ZIMMERMANN*   0  R  2  NaN         ex           (14)?
#
#   Gefährdungsursachen
# 0             1c, 12a
# 1                   ?
# 2             2d, 11c
# 3         3a, 5a, 12c
# 4                   ?

# %%
df.describe(include = "all")
# Out:
#                               Species    BE   BB   DE   GS Häufigkeit  \
# count                              34  34.0   34   34    9         34
# unique                             34   NaN    4    7    2          1
# top     Acupalpus maculatus (SCHAUM)*   NaN    1    2    §         ex
# freq                                1   NaN   11   11    7         34
# mean                              NaN   0.0  NaN  NaN  NaN        NaN
# std                               NaN   0.0  NaN  NaN  NaN        NaN
# min                               NaN   0.0  NaN  NaN  NaN        NaN
# 25%                               NaN   0.0  NaN  NaN  NaN        NaN
# 50%                               NaN   0.0  NaN  NaN  NaN        NaN
# 75%                               NaN   0.0  NaN  NaN  NaN        NaN
# max                               NaN   0.0  NaN  NaN  NaN        NaN
#
#        Vorzugshabitate Gefährdungsursachen
# count               34                  34
# unique              18                  17
# top                  1                   ?
# freq                 9                   7
# mean               NaN                 NaN
# std                NaN                 NaN
# min                NaN                 NaN
# 25%                NaN                 NaN
# 50%                NaN                 NaN
# 75%                NaN                 NaN
# max                NaN                 NaN

# %%
# Removing columns Trend_lang, Trend_kurz, RF, BB, D, GS, Gfu, Vorzugs-habitat, Bestand
df.drop(columns = ["BB", 
                   "DE", 
                   "GS", 
                   "Häufigkeit", 
                   "Vorzugshabitate", 
                   "Gefährdungsursachen"], inplace = True)
df
# Out:
#                                       Species  BE
# 0               Acupalpus maculatus (SCHAUM)*   0
# 1             Agonum gracilipes (DUFTSCHMID)*   0
# 2               Agonum hypocrita (APFELBECK)*   0
# 3                  Agonum impressum (PANZER)*   0
# 4                  Amara famelica ZIMMERMANN*   0
# 5     Anisodactylus nemorivagus (DUFTSCHMID)*   0
# 6                   Bembidion humerale STURM*   0
# 7              Bembidion punctulatum DRAPIEZ*   0
# 8          Bembidion semipunctatum (DONOVAN)*   0
# 9             Bembidion striatum (FABRICIUS)*   0
# 10                Bembidion velox (LINNAEUS)*   0
# 11      Callisthenes reticulatus (FABRICIUS)*   0
# 12            Calosoma sycophanta (LINNAEUS)*   0
# 13               Carabus cancellatus ILLIGER*   0
# 14                Carabus clatratus LINNAEUS*   0
# 15                 Carabus glabratus PAYKULL*   0
# 16               Carabus intricatus LINNAEUS*   0
# 17                   Carabus nitens LINNAEUS*   0
# 18              Carabus problematicus HERBST*   0
# 19        Chlaenius costulatus (MOTSCHULSKY)*   0
# 20             Chlaenius nitidulus (SCHRANK)*   0
# 21           Chlaenius sulcicollis (PAYKULL)*   0
# 22   Cylindera arenaria viennensis (SCHRANK)*   0
# 23              Dolichus halensis (SCHALLER)*   0
# 24              Dyschirius chalceus ERICHSON*   0
# 25            Dyschirius neresheimeri WAGNER*   0
# 26               Dyschirius nitidus (DEJEAN)*   0
# 27           Dyschirius obscurus (GYLLENHAL)*   0
# 28              Elaphropus parvulus (DEJEAN)*   0
# 29      Limodromus longiventris (MANNERHEIM)*   0
# 30  Paratachys micros (FISCHER VON WALDHEIM)*   0
# 31             Pterostichus ovoideus (STURM)*   0
# 32              Pterostichus taksonyis CSIKI*   0
# 33        Sphodrus leucophthalmus (LINNAEUS)*   0

# %%
# Editing species column based on binomial nomenclature

df1 = df.Species.str.split(pat=" ", n = 3, expand = True)
df1
df.Species = df1[0].str.cat(df1[1], sep = " ")
df
# Out:
#                       Species  BE
# 0         Acupalpus maculatus   0
# 1           Agonum gracilipes   0
# 2            Agonum hypocrita   0
# 3            Agonum impressum   0
# 4              Amara famelica   0
# 5   Anisodactylus nemorivagus   0
# 6          Bembidion humerale   0
# 7       Bembidion punctulatum   0
# 8     Bembidion semipunctatum   0
# 9          Bembidion striatum   0
# 10            Bembidion velox   0
# 11   Callisthenes reticulatus   0
# 12        Calosoma sycophanta   0
# 13        Carabus cancellatus   0
# 14          Carabus clatratus   0
# 15          Carabus glabratus   0
# 16         Carabus intricatus   0
# 17             Carabus nitens   0
# 18      Carabus problematicus   0
# 19       Chlaenius costulatus   0
# 20        Chlaenius nitidulus   0
# 21      Chlaenius sulcicollis   0
# 22         Cylindera arenaria   0
# 23          Dolichus halensis   0
# 24        Dyschirius chalceus   0
# 25    Dyschirius neresheimeri   0
# 26         Dyschirius nitidus   0
# 27        Dyschirius obscurus   0
# 28        Elaphropus parvulus   0
# 29    Limodromus longiventris   0
# 30          Paratachys micros   0
# 31      Pterostichus ovoideus   0
# 32     Pterostichus taksonyis   0
# 33    Sphodrus leucophthalmus   0

# %%
df["Family"] = "Carabidae"
df
# Out:
#                       Species  BE     Family
# 0         Acupalpus maculatus   0  Carabidae
# 1           Agonum gracilipes   0  Carabidae
# 2            Agonum hypocrita   0  Carabidae
# 3            Agonum impressum   0  Carabidae
# 4              Amara famelica   0  Carabidae
# 5   Anisodactylus nemorivagus   0  Carabidae
# 6          Bembidion humerale   0  Carabidae
# 7       Bembidion punctulatum   0  Carabidae
# 8     Bembidion semipunctatum   0  Carabidae
# 9          Bembidion striatum   0  Carabidae
# 10            Bembidion velox   0  Carabidae
# 11   Callisthenes reticulatus   0  Carabidae
# 12        Calosoma sycophanta   0  Carabidae
# 13        Carabus cancellatus   0  Carabidae
# 14          Carabus clatratus   0  Carabidae
# 15          Carabus glabratus   0  Carabidae
# 16         Carabus intricatus   0  Carabidae
# 17             Carabus nitens   0  Carabidae
# 18      Carabus problematicus   0  Carabidae
# 19       Chlaenius costulatus   0  Carabidae
# 20        Chlaenius nitidulus   0  Carabidae
# 21      Chlaenius sulcicollis   0  Carabidae
# 22         Cylindera arenaria   0  Carabidae
# 23          Dolichus halensis   0  Carabidae
# 24        Dyschirius chalceus   0  Carabidae
# 25    Dyschirius neresheimeri   0  Carabidae
# 26         Dyschirius nitidus   0  Carabidae
# 27        Dyschirius obscurus   0  Carabidae
# 28        Elaphropus parvulus   0  Carabidae
# 29    Limodromus longiventris   0  Carabidae
# 30          Paratachys micros   0  Carabidae
# 31      Pterostichus ovoideus   0  Carabidae
# 32     Pterostichus taksonyis   0  Carabidae
# 33    Sphodrus leucophthalmus   0  Carabidae

# %%
# Saving the extracted csv to the "Data_cleaning_step1" directory
# export the dataframe as CSV

df.to_csv('../../Transformation/Data_cleaning_step1/Coleoptera_Carabidae_Laufkäfer.csv', 
          index=False)

# %% [markdown]
# # 07. Coleoptera_Cerambycidae_Bockkäfer.csv

# %%
# Read file into dataframe

df = pd.read_csv('Coleoptera_Cerambycidae_Bockkäfer.csv')
df.head()
# Out:
#                                      Species  BE Bestand  Trend_lang  \
# 0           Callidium aeneum (DEGEER, 1775)*   0      ex         NaN
# 1           Cerambyx scopolii FÜESSLY, 1775*   0      ex         NaN
# 2  Chlorophorus varius (O. F. MÜLLER, 1766)*   0      ex         NaN
# 3                Lamia textor (LINNÉ, 1758)*   0      ex         NaN
# 4       Leiopus punctulatus (PAYKULL, 1800)*   0      ex         NaN
#
#    Trend_kurz  RF   BB    D GS                          GfU  \
# 0         NaN NaN  2.0  NaN  §                          NaN
# 1         NaN NaN  1.0  3.0  §                      2a, 14a
# 2         NaN NaN  NaN  1.0  §                      2a, 14a
# 3         NaN NaN  1.0  2.0  §  5a, 5b, 14a  Weberbockkäfer
# 4         NaN NaN  0.0  1.0  §                      2a, 14a
#
#             Deutscher_Name
# 0                      NaN
# 1  Kleiner Eichenbockkäfer
# 2                      NaN
# 3                      NaN
# 4                      NaN

# %%
# Removing columns "Bestand","Trend_lang","Trend_kurz", "RF", "BB", "D", "GS", "GfU"
df.drop(columns = ["Bestand",
                   "Trend_lang",
                   "Trend_kurz",
                   "RF",
                   "BB", 
                   "D", 
                   "GS", 
                   "GfU"
                  ], inplace = True)
df
# Out:
#                                      Species  BE           Deutscher_Name
# 0           Callidium aeneum (DEGEER, 1775)*   0                      NaN
# 1           Cerambyx scopolii FÜESSLY, 1775*   0  Kleiner Eichenbockkäfer
# 2  Chlorophorus varius (O. F. MÜLLER, 1766)*   0                      NaN
# 3                Lamia textor (LINNÉ, 1758)*   0                      NaN
# 4       Leiopus punctulatus (PAYKULL, 1800)*   0                      NaN
# 5            Necydalis ulmi CHEVROLAT, 1838*   0                      NaN
# 6  Phymatodes glabratus (CHARPENTIER, 1825)*   0                      NaN
# 7       Phytoecia molybdaena (DALMAN, 1817)*   0                      NaN

# %%
# Editing species column based on binomial nomenclature

df1 = df.Species.str.split(pat=" ", n = 3, expand = True)
df1
df.Species = df1[0].str.cat(df1[1], sep = " ")
df
# Out:
#                 Species  BE           Deutscher_Name
# 0      Callidium aeneum   0                      NaN
# 1     Cerambyx scopolii   0  Kleiner Eichenbockkäfer
# 2   Chlorophorus varius   0                      NaN
# 3          Lamia textor   0                      NaN
# 4   Leiopus punctulatus   0                      NaN
# 5        Necydalis ulmi   0                      NaN
# 6  Phymatodes glabratus   0                      NaN
# 7  Phytoecia molybdaena   0                      NaN

# %%
df["Family"] = "Cerambycidae"
df
# Out:
#                 Species  BE           Deutscher_Name        Family
# 0      Callidium aeneum   0                      NaN  Cerambycidae
# 1     Cerambyx scopolii   0  Kleiner Eichenbockkäfer  Cerambycidae
# 2   Chlorophorus varius   0                      NaN  Cerambycidae
# 3          Lamia textor   0                      NaN  Cerambycidae
# 4   Leiopus punctulatus   0                      NaN  Cerambycidae
# 5        Necydalis ulmi   0                      NaN  Cerambycidae
# 6  Phymatodes glabratus   0                      NaN  Cerambycidae
# 7  Phytoecia molybdaena   0                      NaN  Cerambycidae

# %%
# Add Deutschename of Lamia textor at  3 Weberbockkäfer
df.at[3,"Deutscher_Name"] = "Weberbockkäfer"
df
# Out:
#                 Species  BE           Deutscher_Name        Family
# 0      Callidium aeneum   0                      NaN  Cerambycidae
# 1     Cerambyx scopolii   0  Kleiner Eichenbockkäfer  Cerambycidae
# 2   Chlorophorus varius   0                      NaN  Cerambycidae
# 3          Lamia textor   0           Weberbockkäfer  Cerambycidae
# 4   Leiopus punctulatus   0                      NaN  Cerambycidae
# 5        Necydalis ulmi   0                      NaN  Cerambycidae
# 6  Phymatodes glabratus   0                      NaN  Cerambycidae
# 7  Phytoecia molybdaena   0                      NaN  Cerambycidae

# %%
# Saving the extracted csv to the "Data_cleaning_step1" directory
# export the dataframe as CSV

df.to_csv('../../Transformation/Data_cleaning_step1/Coleoptera_Cerambycidae_Bockkäfer.csv', 
          index=False)

# %% [markdown]
# # 08. Coleoptera_Staphylinoidea_Histeridae_Stutzkäfer.csv

# %%
# Read file into dataframe

df = pd.read_csv('Coleoptera_Staphylinoidea_Histeridae_Stutzkäfer.csv')
df.head()
# Out:
#                                   Species  BE Bestand  Trend_lang  Trend_kurz  \
# 0   Chetabraeus globulus (CREUTZER, 1799)   0      ex         NaN         NaN
# 1   Hypocacculus rufipes (KUGELANN, 1792)   0      ex         NaN         NaN
# 2     Platysoma angustum (HOFFMANN, 1803)   0      ex         NaN         NaN
# 3  Platysoma deplanatum (GYLLENHAL, 1808)   0      ex         NaN         NaN
# 4      Plegaderus discisus ERICHSON, 1839   0      ex         NaN         NaN
#
#    RF  BB                 GfU  Neobiota Letzter_Nachweis
# 0 NaN  kN  6d, 7a, 8a, 8d, 8e       NaN         vor 1839
# 1 NaN  kN  6d, 7a, 8a, 8d, 8e       NaN         vor 1860
# 2 NaN  kN             2a, 14a       NaN         vor 1950
# 3 NaN  kN             2a, 14a       NaN             1914
# 4 NaN  kN             2a, 14a       NaN         vor 1839

# %%
# Removing columns "Bestand","Trend_lang","Trend_kurz", "RF", "BB", "D", "GS", "GfU"
df.drop(columns = ["Bestand",
                   "Trend_lang",
                   "Trend_kurz",
                   "RF",
                   "BB", 
                   "GfU", 
                   "Neobiota"
                  ], inplace = True)
df
# Out:
#                                     Species  BE Letzter_Nachweis
# 0     Chetabraeus globulus (CREUTZER, 1799)   0         vor 1839
# 1     Hypocacculus rufipes (KUGELANN, 1792)   0         vor 1860
# 2       Platysoma angustum (HOFFMANN, 1803)   0         vor 1950
# 3    Platysoma deplanatum (GYLLENHAL, 1808)   0             1914
# 4        Plegaderus discisus ERICHSON, 1839   0         vor 1839
# ..                                      ...  ..              ...
# 111     Philonthus rufipes (STEPHENS, 1832)   0         vor 1950
# 112      Quedius fulgidus (FABRICIUS, 1793)   0     KORGE (2005)
# 113         Rabigus pullus (NORDMANN, 1837)   0         vor 1950
# 114  Staphylinus caesareus CEDERHJELM, 1798   0     KORGE (2005)
# 115     Tasgius pedator (GRAVENHORST, 1802)   0     KORGE (2005)
#
# [116 rows x 3 columns]

# %%
# Editing species column based on binomial nomenclature

df1 = df.Species.str.split(pat=" ", n = 3, expand = True)
df1
df.Species = df1[0].str.cat(df1[1], sep = " ")
df
# Out:
#                    Species  BE Letzter_Nachweis
# 0     Chetabraeus globulus   0         vor 1839
# 1     Hypocacculus rufipes   0         vor 1860
# 2       Platysoma angustum   0         vor 1950
# 3     Platysoma deplanatum   0             1914
# 4      Plegaderus discisus   0         vor 1839
# ..                     ...  ..              ...
# 111     Philonthus rufipes   0         vor 1950
# 112       Quedius fulgidus   0     KORGE (2005)
# 113         Rabigus pullus   0         vor 1950
# 114  Staphylinus caesareus   0     KORGE (2005)
# 115        Tasgius pedator   0     KORGE (2005)
#
# [116 rows x 3 columns]

# %%
df.head(20)
# Out:
#                  Species  BE Letzter_Nachweis
# 0   Chetabraeus globulus   0         vor 1839
# 1   Hypocacculus rufipes   0         vor 1860
# 2     Platysoma angustum   0         vor 1950
# 3   Platysoma deplanatum   0             1914
# 4    Plegaderus discisus   0         vor 1839
# 5       Saprinus politus   0         vor 1851
# 6     Anemadus strigosus   0         vor 1946
# 7   Nargus anisotomoides   0         vor 1950
# 8           Colon affine   0         vor 1909
# 9          Colon armipes   0         vor 1854
# 10      Colon calcaratum   0         vor 1837
# 11      Colon clavigerum   0         vor 1884
# 12     Colon puncticolle   0         vor 1850
# 13       Colon rufescens   0         vor 1850
# 14     Agyrtes castaneus   0         vor 1856
# 15   Agathidium nigrinum   0         vor 1866
# 16       Leiodes brunnea   0         vor 1909
# 17    Leiodes flavescens   0         vor 1845
# 18         Leiodes furva   0         vor 1845
# 19       Leiodes hybrida   0         vor 1845

# %%
# Too long to manually add the subfamily and family
# Can use GBIF or NCBI

# %%
# GBIF 
#rename Species column to upload to GBIF
# df.rename(columns={"Species": "scientificName"}, inplace = True)

#df.to_csv('Coleoptera_Staphylinoidea_Histeridae_Stutzkäfer_GBIF_in.csv', 
#          index=False)

# Upload to https://www.gbif.org/tools/data-validator

# %%
#df_gbif = pd.read_csv('~/Downloads/Normalized.csv')
#df_gbif.head()

# %%
#df["Family"] = df_gbif.family

# %%
#df

# %% [raw]
# # NCBI - Toooooo slow. Needs to download the taxonomy tree locally
#
# !pip install taxonomy_ranks
#
# from taxonomy_ranks import TaxonomyRanks
#
# taxa_name = 'homo sapiens'
#
# rank_taxon = TaxonomyRanks(taxa_name)
#
# rank_taxon.get_lineage_taxids_and_taxanames()
#
# ranks = ('user_taxa', 'taxa_searched', 'superfamily', 'family', 'subfamily', 'genus', 'species')
#
# # If you don't want the results of so many ranks, just simplify the 'ranks' tupe, e.g.
# # ranks = ('user_taxa', 'taxa_searched',  'superkingdom', 'kingdom', 'phylum', 'class', 'order', 'family', 'genus', 'species')
# # The rank without a value found in the database will have the default vale 'NA'.
#
# for potential_taxid in rank_taxon.lineages:
#      for rank in ranks:
#          if rank in ('user_taxa', 'taxa_searched'):
#              taxon = rank_taxon.lineages[potential_taxid][rank]
#              print(potential_taxid, rank, taxon, sep='\t')
#          else:
#              taxon, taxid_of_taxon = rank_taxon.lineages[potential_taxid][rank]
#              print(potential_taxid, rank, taxon, taxid_of_taxon, sep='\t')

# %%
# !pip install pygbif
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pygbif in /Users/shenya/Library/Python/3.8/lib/python/site-packages (0.6.2)
# Requirement already satisfied: requests>2.7 in /Users/shenya/Library/Python/3.8/lib/python/site-packages (from pygbif) (2.28.1)
# Requirement already satisfied: requests-cache in /Users/shenya/Library/Python/3.8/lib/python/site-packages (from pygbif) (1.0.1)
# Requirement already satisfied: geojson-rewind in /Users/shenya/Library/Python/3.8/lib/python/site-packages (from pygbif) (1.0.3)
# Requirement already satisfied: geomet in /Users/shenya/Library/Python/3.8/lib/python/site-packages (from pygbif) (1.0.0)
# Requirement already satisfied: appdirs>=1.4.3 in /Users/shenya/Library/Python/3.8/lib/python/site-packages (from pygbif) (1.4.4)
# Requirement already satisfied: matplotlib in /Users/shenya/Library/Python/3.8/lib/python/site-packages (from pygbif) (3.6.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/shenya/Library/Python/3.8/lib/python/site-packages (from requests>2.7->pygbif) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/shenya/Library/Python/3.8/lib/python/site-packages (from requests>2.7->pygbif) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/shenya/Library/Python/3.8/lib/python/site-packages (from requests>2.7->pygbif) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/shenya/Library/Python/3.8/lib/python/site-packages (from requests>2.7->pygbif) (2021.10.8)
# Requirement already satisfied: click in /Users/shenya/Library/Python/3.8/lib/python/site-packages (from geomet->pygbif) (8.1.3)
# Requirement already satisfied: six in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/site-packages (from geomet->pygbif) (1.15.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/shenya/Library/Python/3.8/lib/python/site-packages (from matplotlib->pygbif) (1.0.6)
# Requirement already satisfied: cycler>=0.10 in /Users/shenya/Library/Python/3.8/lib/python/site-packages (from matplotlib->pygbif) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/shenya/Library/Python/3.8/lib/python/site-packages (from matplotlib->pygbif) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/shenya/Library/Python/3.8/lib/python/site-packages (from matplotlib->pygbif) (1.4.4)
# Requirement already satisfied: numpy>=1.19 in /Users/shenya/Library/Python/3.8/lib/python/site-packages (from matplotlib->pygbif) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /Users/shenya/Library/Python/3.8/lib/python/site-packages (from matplotlib->pygbif) (22.0)
# Requirement already satisfied: pillow>=6.2.0 in /Users/shenya/Library/Python/3.8/lib/python/site-packages (from matplotlib->pygbif) (9.3.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/shenya/Library/Python/3.8/lib/python/site-packages (from matplotlib->pygbif) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/shenya/Library/Python/3.8/lib/python/site-packages (from matplotlib->pygbif) (2.8.2)
# Requirement already satisfied: attrs>=21.2 in /Users/shenya/Library/Python/3.8/lib/python/site-packages (from requests-cache->pygbif) (22.1.0)
# Requirement already satisfied: cattrs>=22.2 in /Users/shenya/Library/Python/3.8/lib/python/site-packages (from requests-cache->pygbif) (22.2.0)
# Requirement already satisfied: platformdirs>=2.5 in /Users/shenya/Library/Python/3.8/lib/python/site-packages (from requests-cache->pygbif) (2.5.2)
# Requirement already satisfied: url-normalize>=1.4 in /Users/shenya/Library/Python/3.8/lib/python/site-packages (from requests-cache->pygbif) (1.4.3)
# Requirement already satisfied: exceptiongroup in /Users/shenya/Library/Python/3.8/lib/python/site-packages (from cattrs>=22.2->requests-cache->pygbif) (1.1.1)

# %%
from pygbif import species

# %%
df.head()
# Out:
#                 Species  BE Letzter_Nachweis
# 0  Chetabraeus globulus   0         vor 1839
# 1  Hypocacculus rufipes   0         vor 1860
# 2    Platysoma angustum   0         vor 1950
# 3  Platysoma deplanatum   0             1914
# 4   Plegaderus discisus   0         vor 1839

# %%
'''
for key in d2:
    df = pd.concat([df, d2[key]], axis = 0)
df
'''

# %%
# Creating a dictionary
d = {}

for i in df.Species:     
   d[i] = species.name_backbone(name=str(i), kingdom='animals')

# %%
gbif_data = pd.DataFrame.from_dict(d, orient = "index")

# %%
gbif_data.head()
# Out:
#                       usageKey  acceptedUsageKey  \
# Chetabraeus globulus   4769559         1044920.0
# Hypocacculus rufipes   4432875         8483966.0
# Platysoma angustum     5996117               NaN
# Platysoma deplanatum   5744987               NaN
# Plegaderus discisus    4433579               NaN
#
#                                               scientificName  \
# Chetabraeus globulus              Chetabraeus Portevin, 1929
# Hypocacculus rufipes   Hypocacculus rufipes (Kugelann, 1792)
# Platysoma angustum     Platysoma angustatum (Hoffmann, 1803)
# Platysoma deplanatum  Platysoma deplanatum (Gyllenhal, 1808)
# Plegaderus discisus       Plegaderus discisus Erichson, 1839
#
#                              canonicalName     rank    status  confidence  \
# Chetabraeus globulus           Chetabraeus    GENUS   SYNONYM          96
# Hypocacculus rufipes  Hypocacculus rufipes  SPECIES   SYNONYM         100
# Platysoma angustum    Platysoma angustatum  SPECIES  ACCEPTED          95
# Platysoma deplanatum  Platysoma deplanatum  SPECIES  ACCEPTED         100
# Plegaderus discisus    Plegaderus discisus  SPECIES  ACCEPTED         100
#
#                        matchType   kingdom      phylum  ... kingdomKey  \
# Chetabraeus globulus  HIGHERRANK  Animalia  Arthropoda  ...          1
# Hypocacculus rufipes       EXACT  Animalia  Arthropoda  ...          1
# Platysoma angustum         FUZZY  Animalia  Arthropoda  ...          1
# Platysoma deplanatum       EXACT  Animalia  Arthropoda  ...          1
# Plegaderus discisus        EXACT  Animalia  Arthropoda  ...          1
#
#                      phylumKey classKey  orderKey  familyKey  genusKey  \
# Chetabraeus globulus        54      216      1470       4733   1044920
# Hypocacculus rufipes        54      216      1470       4733   1044724
# Platysoma angustum          54      216      1470       4733   1044816
# Platysoma deplanatum        54      216      1470       4733   1044816
# Plegaderus discisus         54      216      1470       4733   1044747
#
#                       synonym    class               species  speciesKey
# Chetabraeus globulus     True  Insecta                   NaN         NaN
# Hypocacculus rufipes     True  Insecta    Hypocaccus rufipes   8483966.0
# Platysoma angustum      False  Insecta  Platysoma angustatum   5996117.0
# Platysoma deplanatum    False  Insecta  Platysoma deplanatum   5744987.0
# Plegaderus discisus     False  Insecta   Plegaderus discisus   4433579.0
#
# [5 rows x 23 columns]

# %%
gbif_data.reset_index(inplace = True)

# %%
gbif_data.head()
# Out:
#                   index  usageKey  acceptedUsageKey  \
# 0  Chetabraeus globulus   4769559         1044920.0
# 1  Hypocacculus rufipes   4432875         8483966.0
# 2    Platysoma angustum   5996117               NaN
# 3  Platysoma deplanatum   5744987               NaN
# 4   Plegaderus discisus   4433579               NaN
#
#                            scientificName         canonicalName     rank  \
# 0              Chetabraeus Portevin, 1929           Chetabraeus    GENUS
# 1   Hypocacculus rufipes (Kugelann, 1792)  Hypocacculus rufipes  SPECIES
# 2   Platysoma angustatum (Hoffmann, 1803)  Platysoma angustatum  SPECIES
# 3  Platysoma deplanatum (Gyllenhal, 1808)  Platysoma deplanatum  SPECIES
# 4      Plegaderus discisus Erichson, 1839   Plegaderus discisus  SPECIES
#
#      status  confidence   matchType   kingdom  ... kingdomKey phylumKey  \
# 0   SYNONYM          96  HIGHERRANK  Animalia  ...          1        54
# 1   SYNONYM         100       EXACT  Animalia  ...          1        54
# 2  ACCEPTED          95       FUZZY  Animalia  ...          1        54
# 3  ACCEPTED         100       EXACT  Animalia  ...          1        54
# 4  ACCEPTED         100       EXACT  Animalia  ...          1        54
#
#   classKey orderKey  familyKey  genusKey  synonym    class  \
# 0      216     1470       4733   1044920     True  Insecta
# 1      216     1470       4733   1044724     True  Insecta
# 2      216     1470       4733   1044816    False  Insecta
# 3      216     1470       4733   1044816    False  Insecta
# 4      216     1470       4733   1044747    False  Insecta
#
#                 species  speciesKey
# 0                   NaN         NaN
# 1    Hypocaccus rufipes   8483966.0
# 2  Platysoma angustatum   5996117.0
# 3  Platysoma deplanatum   5744987.0
# 4   Plegaderus discisus   4433579.0
#
# [5 rows x 24 columns]

# %%
gbif_data.columns
# Out:
# Index(['index', 'usageKey', 'acceptedUsageKey', 'scientificName',
#        'canonicalName', 'rank', 'status', 'confidence', 'matchType', 'kingdom',
#        'phylum', 'order', 'family', 'genus', 'kingdomKey', 'phylumKey',
#        'classKey', 'orderKey', 'familyKey', 'genusKey', 'synonym', 'class',
#        'species', 'speciesKey'],
#       dtype='object')

# %%
df["Family"] = gbif_data["family"]

# %%
df.tail()
# Out:
#                    Species  BE Letzter_Nachweis         Family
# 111     Philonthus rufipes   0         vor 1950  Staphylinidae
# 112       Quedius fulgidus   0     KORGE (2005)  Staphylinidae
# 113         Rabigus pullus   0         vor 1950  Staphylinidae
# 114  Staphylinus caesareus   0     KORGE (2005)  Staphylinidae
# 115        Tasgius pedator   0     KORGE (2005)  Staphylinidae

# %%
# Saving the extracted csv to the "Data_cleaning_step1" directory
# export the dataframe as CSV

df.to_csv('../../Transformation/Data_cleaning_step1/Coleoptera_Staphylinoidea_Histeridae_Stutzkäfer.csv', 
          index=False)

# %% [markdown]
# # 09. Curculionoidea_Rüsselkäfer.csv

# %%
# Read file into dataframe

df = pd.read_csv('Curculionoidea_Rüsselkäfer.csv')
df.head()
# Out:
#                           Species  BE BB DE Vorzugs_habitate  \
# 0  Acalyptus carpini (FABRICIUS)*   0  3  -           WM, WW
# 1         Aizobius sedi (GERMAR)*   0  3  -          RSA, GT
# 2      Bagous binodulus (HERBST)*   0  1  3       SFA, M, GF
# 3   Bagous collignensis (HERBST)*   0  2  2         S, M, GF
# 4       Bagous diglyptus BOHEMAN*   0  1  2          GT, RSA
#
#   Gefährdungsursachen
# 0          2d, 7b, 8b
# 1     1a, 7a, 8a, 13a
# 2      2d, 5, 6a, 12c
# 3      2d, 5, 6a, 12c
# 4     1a, 7a, 8a, 11a

# %%
# Removing columns "Bestand","Trend_lang","Trend_kurz", "RF", "BB", "D", "GS", "GfU"
df.drop(columns = ["BB",
                   "DE",
                   "Vorzugs_habitate",
                   "Gefährdungsursachen"
                  ], inplace = True)
df
# Out:
#                              Species  BE
# 0     Acalyptus carpini (FABRICIUS)*   0
# 1            Aizobius sedi (GERMAR)*   0
# 2         Bagous binodulus (HERBST)*   0
# 3      Bagous collignensis (HERBST)*   0
# 4          Bagous diglyptus BOHEMAN*   0
# ..                               ...  ..
# 80      Thryogenes nereis (PAYKULL)*   0
# 81  Trachyphloeus spinimanus GERMAR*   0
# 82      Tychius lineatulus STEPHENS*   0
# 83   Tychius medicaginis C. BRISOUT*   0
# 84        Tychius trivialis BOHEMAN*   0
#
# [85 rows x 2 columns]

# %%
# Editing species column based on binomial nomenclature

df1 = df.Species.str.split(pat=" ", n = 3, expand = True)
df1
df.Species = df1[0].str.cat(df1[1], sep = " ")
df
# Out:
#                      Species  BE
# 0          Acalyptus carpini   0
# 1              Aizobius sedi   0
# 2           Bagous binodulus   0
# 3        Bagous collignensis   0
# 4           Bagous diglyptus   0
# ..                       ...  ..
# 80         Thryogenes nereis   0
# 81  Trachyphloeus spinimanus   0
# 82        Tychius lineatulus   0
# 83       Tychius medicaginis   0
# 84         Tychius trivialis   0
#
# [85 rows x 2 columns]

# %%
# Creating a dictionary
d = {}

for i in df.Species:     
   d[i] = species.name_backbone(name=str(i), kingdom='animals')

# %%
gbif_data = pd.DataFrame.from_dict(d, orient = "index")
gbif_data.reset_index(inplace = True)
gbif_data.columns
# Out:
# Index(['index', 'usageKey', 'scientificName', 'canonicalName', 'rank',
#        'status', 'confidence', 'matchType', 'kingdom', 'phylum', 'order',
#        'family', 'genus', 'species', 'kingdomKey', 'phylumKey', 'classKey',
#        'orderKey', 'familyKey', 'genusKey', 'speciesKey', 'synonym', 'class',
#        'acceptedUsageKey'],
#       dtype='object')

# %%
df["Family"] = gbif_data["family"]

# %%
df.head()
# Out:
#                Species  BE         Family
# 0    Acalyptus carpini   0  Curculionidae
# 1        Aizobius sedi   0      Apionidae
# 2     Bagous binodulus   0  Curculionidae
# 3  Bagous collignensis   0  Curculionidae
# 4     Bagous diglyptus   0  Curculionidae

# %%
df.tail()
# Out:
#                      Species  BE         Family
# 80         Thryogenes nereis   0  Brachyceridae
# 81  Trachyphloeus spinimanus   0  Curculionidae
# 82        Tychius lineatulus   0  Curculionidae
# 83       Tychius medicaginis   0  Curculionidae
# 84         Tychius trivialis   0  Curculionidae

# %%
# Saving the extracted csv to the "Data_cleaning_step1" directory
# export the dataframe as CSV

df.to_csv('../../Transformation/Data_cleaning_step1/Curculionoidea_Rüsselkäfer.csv', 
          index=False)

# %% [markdown]
# # 10. Diptera_Asilidae_Raubfliegen.csv

# %%
# Read file into dataframe

df = pd.read_csv('Diptera_Asilidae_Raubfliegen.csv')
df.head()
# Out:
#                                 Species  BE Bestand  Trend_lang  Trend_kurz  \
# 0    Andrenosoma atrum (LINNAEUS, 1758)   0      ex         NaN         NaN
# 1  Asilus crabroniformis LINNAEUS, 1758   0      ex         NaN         NaN
# 2      Choerades gilva (LINNAEUS, 1758)   0      ex         NaN         NaN
# 3      Dioctria cothurnata MEIGEN, 1820   0      ex         NaN         NaN
# 4           Erax barbatus SCOPOLI, 1763   0      ex         NaN         NaN
#
#    RF  D  GfU Letzter_Nachweis
# 0 NaN  2  NaN             1904
# 1 NaN  2  NaN             1936
# 2 NaN  G  NaN             1958
# 3 NaN  *  NaN             1951
# 4 NaN  2  NaN         vor 1945

# %%
# Removing columns "Bestand","Trend_lang","Trend_kurz", "RF", "BB", "D", "GS", "GfU"
df.drop(columns = ["Bestand",
                   "Trend_lang",
                   "Trend_kurz",
                   "RF",
                   "D",
                   "GfU"
                  ], inplace = True)
df
# Out:
#                                    Species  BE Letzter_Nachweis
# 0       Andrenosoma atrum (LINNAEUS, 1758)   0             1904
# 1     Asilus crabroniformis LINNAEUS, 1758   0             1936
# 2         Choerades gilva (LINNAEUS, 1758)   0             1958
# 3         Dioctria cothurnata MEIGEN, 1820   0             1951
# 4              Erax barbatus SCOPOLI, 1763   0         vor 1945
# 5     Holopogon fumipennis (MEIGEN, 1820)*   0         vor 1945
# 6         Laphria gibbosa (LINNAEUS, 1758)   0             1965
# 7  Leptarthrus brevirostris (MEIGEN, 1804)   0             1932

# %%
# Editing species column based on binomial nomenclature

df1 = df.Species.str.split(pat=" ", n = 3, expand = True)
df1
df.Species = df1[0].str.cat(df1[1], sep = " ")
df
# Out:
#                     Species  BE Letzter_Nachweis
# 0         Andrenosoma atrum   0             1904
# 1     Asilus crabroniformis   0             1936
# 2           Choerades gilva   0             1958
# 3       Dioctria cothurnata   0             1951
# 4             Erax barbatus   0         vor 1945
# 5      Holopogon fumipennis   0         vor 1945
# 6           Laphria gibbosa   0             1965
# 7  Leptarthrus brevirostris   0             1932

# %%
# Creating a dictionary and extracting GBIF data
d = {}

for i in df.Species:     
   d[i] = species.name_backbone(name=str(i), kingdom='animals')

# %%
gbif_data = pd.DataFrame.from_dict(d, orient = "index")
gbif_data.reset_index(inplace = True)
gbif_data.columns
# Out:
# Index(['index', 'usageKey', 'scientificName', 'canonicalName', 'rank',
#        'status', 'confidence', 'matchType', 'kingdom', 'phylum', 'order',
#        'family', 'genus', 'species', 'kingdomKey', 'phylumKey', 'classKey',
#        'orderKey', 'familyKey', 'genusKey', 'speciesKey', 'synonym', 'class',
#        'acceptedUsageKey'],
#       dtype='object')

# %%
df["Family"] = gbif_data["family"]

# %%
df
# Out:
#                     Species  BE Letzter_Nachweis    Family
# 0         Andrenosoma atrum   0             1904  Asilidae
# 1     Asilus crabroniformis   0             1936  Asilidae
# 2           Choerades gilva   0             1958  Asilidae
# 3       Dioctria cothurnata   0             1951  Asilidae
# 4             Erax barbatus   0         vor 1945  Asilidae
# 5      Holopogon fumipennis   0         vor 1945  Asilidae
# 6           Laphria gibbosa   0             1965  Asilidae
# 7  Leptarthrus brevirostris   0             1932  Asilidae

# %%
# Saving the extracted csv to the "Data_cleaning_step1" directory
# export the dataframe as CSV

df.to_csv('../../Transformation/Data_cleaning_step1/Diptera_Asilidae_Raubfliegen.csv', 
          index=False)

# %% [markdown]
# ## 11. Diptera_Syrphidae_Schwebfliegen

# %%
# Read file into dataframe

df = pd.read_csv('Diptera_Syrphidae_Schwebfliegen.csv')
df.head()
# Out:
#                                    Species  BE Bestand  Trend_lang  \
# 0        Anasimyia lunulata (MEIGEN, 1822)   0      ex         NaN
# 1       Baccha obscuripennis MEIGEN, 1822*   0      ex         NaN
# 2    Chalcosyrphus piger (FABRICIUS, 1794)   0      ex         NaN
# 3      Chamaesyrphus lusitanicus MIK, 1898   0      ex         NaN
# 4  Chamaesyrphus scaevoides (FALLÉN, 1817)   0      ex         NaN
#
#    Trend_kurz  RF  D                     GfU  Vorzugshabitat  \
# 0         NaN NaN  1         2d, 6a, 8b, 11c               M
# 1         NaN NaN  *                 2a, 12b  W1, W2, PF, PK
# 2         NaN NaN  2              2a, 9, 12b              W2
# 3         NaN NaN  1  1a, 2a, 6d, 7d, 8, 14a       H, W2, AD
# 4         NaN NaN  2  1a, 2a, 6d, 7d, 8, 14a           H, W2
#
#   Ernährungs_typLarve
# 0                 asp
# 1                 zoo
# 2                 tsp
# 3                phy?
# 4                phy?

# %%
# Removing columns 
df.drop(columns = ["Bestand",
                   "Trend_lang",
                   "Trend_kurz",
                   "RF",
                   "D",
                   "GfU",
                   "Vorzugshabitat",
                   "Ernährungs_typLarve"
                  ], inplace = True)
df
# Out:
#                                         Species  BE
# 0             Anasimyia lunulata (MEIGEN, 1822)   0
# 1            Baccha obscuripennis MEIGEN, 1822*   0
# 2         Chalcosyrphus piger (FABRICIUS, 1794)   0
# 3           Chamaesyrphus lusitanicus MIK, 1898   0
# 4       Chamaesyrphus scaevoides (FALLÉN, 1817)   0
# 5                  Cheilosia barbata LOEW, 1857   0
# 6              Cheilosia pascuorum BECKER, 1894   0
# 7             Chrysogaster virescens LOEW, 1854   0
# 8        Chrysotoxum octomaculatum CURTIS, 1837   0
# 9               Eristalis alpina (PANZER, 1798)   0
# 10        Eristalis anthophorina (FALLÉN, 1817)   0
# 11        Eumerus flavitarsis ZETTERSTEDT, 1843   0
# 12             Eumerus sabulonum (FALLÉN, 1817)   0
# 13       Lejogaster metallina (FABRICIUS, 1777)   0
# 14         Mallota megilliformis (FALLÉN, 1817)   0
# 15       Megasyrphus erraticus (LINNAEUS, 1758)   0
# 16             Microdon devius (LINNAEUS, 1761)   0
# 17                Myolepta obscura BECHER, 1882   0
# 18                 Myolepta vara (PANZER, 1798)   0
# 19          Neocnemodon brevidens (EGGER, 1865)   0
# 20         Neocnemodon verrucula (COLLIN, 1931)   0
# 21          Orthonevra erythrogona (MALM, 1863)   0
# 22              Orthonevra incisa (LOEW, 1843)*   0
# 23       Orthonevra intermedia (LUNDBECK, 1916)   0
# 24            Orthonevra nobilis (FALLÉN, 1817)   0
# 25            Pelecocera tricincta MEIGEN, 1822   0
# 26  Sphaerophoria interrupta (FABRICIUS, 1805)*   0
# 27        Sphaerophoria loewi ZETTERSTEDT, 1843   0
# 28       Spilomyia diophthalma (LINNAEUS, 1758)   0
# 29     Trichopsomyia flavitarsis (MEIGEN, 1822)   0
# 30                    Xylota tarda MEIGEN, 1822   0

# %%
# Editing species column based on binomial nomenclature

df1 = df.Species.str.split(pat=" ", n = 3, expand = True)
df1
df.Species = df1[0].str.cat(df1[1], sep = " ")
df
# Out:
#                       Species  BE
# 0          Anasimyia lunulata   0
# 1        Baccha obscuripennis   0
# 2         Chalcosyrphus piger   0
# 3   Chamaesyrphus lusitanicus   0
# 4    Chamaesyrphus scaevoides   0
# 5           Cheilosia barbata   0
# 6         Cheilosia pascuorum   0
# 7      Chrysogaster virescens   0
# 8   Chrysotoxum octomaculatum   0
# 9            Eristalis alpina   0
# 10     Eristalis anthophorina   0
# 11        Eumerus flavitarsis   0
# 12          Eumerus sabulonum   0
# 13       Lejogaster metallina   0
# 14      Mallota megilliformis   0
# 15      Megasyrphus erraticus   0
# 16            Microdon devius   0
# 17           Myolepta obscura   0
# 18              Myolepta vara   0
# 19      Neocnemodon brevidens   0
# 20      Neocnemodon verrucula   0
# 21     Orthonevra erythrogona   0
# 22          Orthonevra incisa   0
# 23      Orthonevra intermedia   0
# 24         Orthonevra nobilis   0
# 25       Pelecocera tricincta   0
# 26   Sphaerophoria interrupta   0
# 27        Sphaerophoria loewi   0
# 28      Spilomyia diophthalma   0
# 29  Trichopsomyia flavitarsis   0
# 30               Xylota tarda   0

# %%
# Creating a dictionary and extracting GBIF data
d = {}

for i in df.Species:     
   d[i] = species.name_backbone(name=str(i), kingdom='animals')

# %%
gbif_data = pd.DataFrame.from_dict(d, orient = "index")
gbif_data.reset_index(inplace = True)
gbif_data.columns
# Out:
# Index(['index', 'usageKey', 'acceptedUsageKey', 'scientificName',
#        'canonicalName', 'rank', 'status', 'confidence', 'matchType', 'kingdom',
#        'phylum', 'order', 'family', 'genus', 'species', 'kingdomKey',
#        'phylumKey', 'classKey', 'orderKey', 'familyKey', 'genusKey',
#        'speciesKey', 'synonym', 'class'],
#       dtype='object')

# %%
df["Family"] = gbif_data["family"]
df
# Out:
#                       Species  BE     Family
# 0          Anasimyia lunulata   0  Syrphidae
# 1        Baccha obscuripennis   0  Syrphidae
# 2         Chalcosyrphus piger   0  Syrphidae
# 3   Chamaesyrphus lusitanicus   0  Syrphidae
# 4    Chamaesyrphus scaevoides   0  Syrphidae
# 5           Cheilosia barbata   0  Syrphidae
# 6         Cheilosia pascuorum   0  Syrphidae
# 7      Chrysogaster virescens   0  Syrphidae
# 8   Chrysotoxum octomaculatum   0  Syrphidae
# 9            Eristalis alpina   0  Syrphidae
# 10     Eristalis anthophorina   0  Syrphidae
# 11        Eumerus flavitarsis   0  Syrphidae
# 12          Eumerus sabulonum   0  Syrphidae
# 13       Lejogaster metallina   0  Syrphidae
# 14      Mallota megilliformis   0  Syrphidae
# 15      Megasyrphus erraticus   0  Syrphidae
# 16            Microdon devius   0  Syrphidae
# 17           Myolepta obscura   0  Syrphidae
# 18              Myolepta vara   0  Syrphidae
# 19      Neocnemodon brevidens   0  Syrphidae
# 20      Neocnemodon verrucula   0  Syrphidae
# 21     Orthonevra erythrogona   0  Syrphidae
# 22          Orthonevra incisa   0  Syrphidae
# 23      Orthonevra intermedia   0  Syrphidae
# 24         Orthonevra nobilis   0  Syrphidae
# 25       Pelecocera tricincta   0  Syrphidae
# 26   Sphaerophoria interrupta   0  Syrphidae
# 27        Sphaerophoria loewi   0  Syrphidae
# 28      Spilomyia diophthalma   0  Syrphidae
# 29  Trichopsomyia flavitarsis   0  Syrphidae
# 30               Xylota tarda   0  Syrphidae

# %%
# Saving the extracted csv to the "Data_cleaning_step1" directory
# export the dataframe as CSV

df.to_csv('../../Transformation/Data_cleaning_step1/Diptera_Syrphidae_Schwebfliegen.csv', 
          index=False)

# %% [markdown]
# ## 12. Grasshoppers_and_crickets

# %%
# Read file into dataframe

df = pd.read_csv('Grasshoppers_crickets.csv')
df.head()
# Out:
#                              Wissenschaftlicher_Name  BE  BB DE   GS  H  \
# 0  Arcyptera microptera (FISCHER \nVON WALDHEIM)*...   0   0  0   §§  -
# 1  Calliptamus italicus (LINNAEUS)* \nItalienisch...   0   1  1    §  -
# 2       Gampsocleis glabra (HERBST)* \nHeideschrecke   0   0  1   §§  -
# 3  Metrioptera brachyptera (LIN-\nNAEUS)* \nKurzf...   0   2  -  NaN  -
# 4  Platycleis montana (KOLLAR)* \nSteppen-Beißsch...   0   1  1   §§  -
#
#   Vorzugs-habitate  Biol_ökol_Typ Gefährdungsursachen
# 0             GT, H           xer                 NaN
# 1        GT, H, LBS           xer                 NaN
# 2             GT, H           xer                 NaN
# 3             M, GF           hyg                 NaN
# 4             GT, H           xer                 NaN

# %%
df.columns
# Out:
# Index(['Wissenschaftlicher_Name', 'BE', 'BB', 'DE', 'GS', 'H',
#        'Vorzugs-habitate ', 'Biol_ökol_Typ', 'Gefährdungsursachen'],
#       dtype='object')

# %%
# Removing columns 
df.drop(columns = ["BB",
                   "DE",
                   "GS",
                   "H",
                   "Vorzugs-habitate ",
                   "Biol_ökol_Typ",
                   "Gefährdungsursachen"
                  ], inplace = True)
df
# Out:
#                              Wissenschaftlicher_Name  BE
# 0  Arcyptera microptera (FISCHER \nVON WALDHEIM)*...   0
# 1  Calliptamus italicus (LINNAEUS)* \nItalienisch...   0
# 2       Gampsocleis glabra (HERBST)* \nHeideschrecke   0
# 3  Metrioptera brachyptera (LIN-\nNAEUS)* \nKurzf...   0
# 4  Platycleis montana (KOLLAR)* \nSteppen-Beißsch...   0
# 5  Psophus stridulus (LINNAEUS)* \nRotflüglige Sc...   0
# 6  Stauroderus scalaris (FISCHER \nVON WALDHEIM)*...   0
# 7  Stenobothrus nigromaculatus \n(HERRICH-SCHÄFFE...   0

# %%
# Editing species column based on binomial nomenclature

df1 = df.Wissenschaftlicher_Name.str.split(pat=" ", n = 3, expand = True)
df1
# Out:
#               0               1                      2  \
# 0     Arcyptera      microptera               (FISCHER
# 1   Calliptamus        italicus            (LINNAEUS)*
# 2   Gampsocleis          glabra              (HERBST)*
# 3   Metrioptera     brachyptera         (LIN-\nNAEUS)*
# 4    Platycleis         montana              (KOLLAR)*
# 5       Psophus       stridulus            (LINNAEUS)*
# 6   Stauroderus        scalaris               (FISCHER
# 7  Stenobothrus  nigromaculatus  \n(HERRICH-SCHÄFFER)*
#
#                                           3
# 0  \nVON WALDHEIM)* \nKleine Höckerschrecke
# 1              \nItalienische Schönschrecke
# 2                           \nHeideschrecke
# 3               \nKurzflüglige Beißschrecke
# 4                    \nSteppen-Beißschrecke
# 5             \nRotflüglige Schnarrschrecke
# 6      \nVON WALDHEIM)* \nGebirgsgrashüpfer
# 7     \nSchwarzfleckiger Heidegrashüp-\nfer

# %%
df.Wissenschaftlicher_Name = df1[0].str.cat(df1[1], sep = " ")
df
# Out:
#        Wissenschaftlicher_Name  BE
# 0         Arcyptera microptera   0
# 1         Calliptamus italicus   0
# 2           Gampsocleis glabra   0
# 3      Metrioptera brachyptera   0
# 4           Platycleis montana   0
# 5            Psophus stridulus   0
# 6         Stauroderus scalaris   0
# 7  Stenobothrus nigromaculatus   0

# %%
# Get the deutschename to the table too

# %%
# Creating a dictionary and extracting GBIF data
d = {}

for i in df.Species:     
   d[i] = species.name_backbone(name=str(i), kingdom='animals')
print("Complete")
# Out:
# Complete

# %%
gbif_data = pd.DataFrame.from_dict(d, orient = "index")
gbif_data.reset_index(inplace = True)
gbif_data.columns
# Out:
# Index(['index', 'usageKey', 'scientificName', 'canonicalName', 'rank',
#        'status', 'confidence', 'matchType', 'kingdom', 'phylum', 'order',
#        'family', 'genus', 'species', 'kingdomKey', 'phylumKey', 'classKey',
#        'orderKey', 'familyKey', 'genusKey', 'speciesKey', 'synonym', 'class',
#        'acceptedUsageKey', 'note'],
#       dtype='object')

# %%
df["Family"] = gbif_data["family"]
df
# Out:
#        Wissenschaftlicher_Name  BE         Family
# 0         Arcyptera microptera   0      Acrididae
# 1         Calliptamus italicus   0      Acrididae
# 2           Gampsocleis glabra   0  Tettigoniidae
# 3      Metrioptera brachyptera   0  Tettigoniidae
# 4           Platycleis montana   0  Tettigoniidae
# 5            Psophus stridulus   0      Acrididae
# 6         Stauroderus scalaris   0      Acrididae
# 7  Stenobothrus nigromaculatus   0      Acrididae

# %%
# Saving the extracted csv to the "Data_cleaning_step1" directory
# export the dataframe as CSV

df.to_csv('../../Transformation/Data_cleaning_step1/Grasshoppers_and_crickets.csv', 
          index=False)

# %% [markdown]
# ## 13. Zikaden.csv

# %%
# Read file into dataframe

df = pd.read_csv('Zikaden.csv')
df.head()
# Out:
#                 Wissenschaftlicher_Name  BE Bestand  Trend_lang  Trend_kurz  \
# 0  Adarrus multinotatus (BOHEMAN, 1847)   0      ex         NaN         NaN
# 1        Allygus maculatus RIBAUT, 1952   0      ex         NaN         NaN
# 2  Anoscopus albifrons (LINNAEUS, 1758)   0      ex         NaN         NaN
# 3      Arocephalus punctum (FLOR, 1861)   0      ex         NaN         NaN
# 4       Athysanus quadrum BOHEMAN, 1845   0      ex         NaN         NaN
#
#    RF  D      GfU letzter_Nachweis        Deutscher Name
# 0 NaN  *     1, 7         vor 1912  Gemeine Zwenkenzirpe
# 1 NaN  3  1, 2, 7             1902      Fleckenbaumzirpe
# 2 NaN  *        ?         vor 1912      Braune Erdzikade
# 3 NaN  3     1, 7             1889           Widderzirpe
# 4 NaN  2     2, 6             1919            Sumpfzirpe

# %%
# Removing columns 
df.drop(columns = ["Bestand",
                   "Trend_lang",
                   "Trend_kurz",
                   "RF",
                   "D",
                   "GfU"
                  ], inplace = True)
df
# Out:
#                         Wissenschaftlicher_Name  BE letzter_Nachweis  \
# 0          Adarrus multinotatus (BOHEMAN, 1847)   0         vor 1912
# 1                Allygus maculatus RIBAUT, 1952   0             1902
# 2          Anoscopus albifrons (LINNAEUS, 1758)   0         vor 1912
# 3              Arocephalus punctum (FLOR, 1861)   0             1889
# 4               Athysanus quadrum BOHEMAN, 1845   0             1919
# 5             Cicadula saturata (EDWARDS, 1915)   0             1889
# 6        Coryphaelus gyllenhalii (FALLÉN, 1826)   0             1919
# 7              Cosmotettix panzeri (FLOR, 1861)   0             1952
# 8      Criomorphus borealis (J. SAHLBERG, 1871)   0         vor 1960
# 9           Criomorphus moestus (BOHEMAN, 1847)   0             1952
# 10        Delphacinus mesomelas (BOHEMAN, 1850)   0         vor 1912
# 11          Delphax crassicornis (PANZER, 1796)   0         vor 1880
# 12    Doliotettix lunulatus (ZETTERSTEDT, 1840)   0             1928
# 13                  Empoasca affinis NAST, 1937   0         vor 1960
# 14              Erotettix cyane (BOHEMAN, 1845)   0             1889
# 15        Eurhadina kirschbaumi W. WAGNER, 1937   0             1889
# 16          Euscelis venosus (KIRSCHBAUM, 1868)   0             1889
# 17     Hephathus nanus (HERRICH-SCHÄFFER, 1835)   0             1921
# 18        Jassargus pseudocellaris (FLOR, 1861)   0         vor 1912
# 19              Kelisia ribauti W. WAGNER, 1938   0             1952
# 20      Kelisia vittipennis (J. SAHLBERG, 1868)   0             1952
# 21      Limotettix atricapillus (BOHEMAN, 1845)   0             1952
# 22             Macropsis impura (BOHEMAN, 1847)   0             1919
# 23          Metalimnus formosus (BOHEMAN, 1845)   0             1952
# 24       Nothodelphax albocarinata (STÅL, 1858)   0         vor 1960
# 25          Nothodelphax distincta (FLOR, 1861)   0             1952
# 26          Oncodelphax pullula (BOHEMAN, 1852)   0             1952
# 27       Oncopsis appendiculata W. WAGNER, 1944   0             1910
# 28              Ophiola russeola (FALLÉN, 1826)   0             1952
# 29   Paraliburnia clypealis (J. SAHLBERG, 1871)   0             1951
# 30        Parapotes reticulatus (HORVÁTH, 1897)   0             1919
# 31    Planaphrodes trifasciata (GEOFFROY, 1785)   0         vor 1912
# 32           Populicerus laminatus (FLOR, 1861)   0             1921
# 33  Stiroma bicarinata (HERRICH-SCHÄFFER, 1835)   0         vor 1912
# 34    Stroggylocephalus agrestis (FALLÉN, 1806)   0             1932
# 35    Tettigometra leucophaea (PREYSSLER, 1792)   0             1905
# 36           Ulopa reticulata (FABRICIUS, 1794)   0             1921
# 37       Verdanus abdominalis (FABRICIUS, 1803)   0         vor 1912
# 38              Zygina nigritarsis REMANE, 1994   0             1889
#
#                Deutscher Name
# 0        Gemeine Zwenkenzirpe
# 1            Fleckenbaumzirpe
# 2            Braune Erdzikade
# 3                 Widderzirpe
# 4                  Sumpfzirpe
# 5            Braunseggenzirpe
# 6           Bunte Simsenzirpe
# 7         Baltische Moorzirpe
# 8            Taigaspornzikade
# 9     Schwedische Spornzikade
# 10      Elfenbein-Spornzikade
# 11    Bunte Schilfspornzikade
# 12         Frühlingsgraszirpe
# 13         Strauchblattzikade
# 14              Seerosenzirpe
# 15  Traubeneichen-Elfenzikade
# 16              Eberwurzzirpe
# 17          Zwergmaskenzikade
# 18      Wiesen-Spitzkopfzirpe
# 19  Schwarzlippen-Spornzikade
# 20       Wollgras-Spornzikade
# 21          Schnabelriedzirpe
# 22        Kleine Maskenzikade
# 23         Schöne Marmorzirpe
# 24       Schlenkenspornzikade
# 25       Hochmoor-Spornzikade
# 26          Klauenspornzikade
# 27          Hakenmaskenzikade
# 28            Zwergheidezirpe
# 29         Braune Spornzikade
# 30               Scherenzirpe
# 31             Heideerdzikade
# 32    Große Espenwinkerzikade
# 33            Waldspornzikade
# 34             Sumpferdzikade
# 35   Punktierte Ameisenzikade
# 36           Heidekrautzikade
# 37     Schwarzgrüne Graszirpe
# 38          Ringelfeuerzikade

# %%
# Editing species column based on binomial nomenclature

df1 = df.Wissenschaftlicher_Name.str.split(pat=" ", n = 3, expand = True)
df1
df.Wissenschaftlicher_Name = df1[0].str.cat(df1[1], sep = " ")
df
# Out:
#        Wissenschaftlicher_Name  BE letzter_Nachweis             Deutscher Name
# 0         Adarrus multinotatus   0         vor 1912       Gemeine Zwenkenzirpe
# 1            Allygus maculatus   0             1902           Fleckenbaumzirpe
# 2          Anoscopus albifrons   0         vor 1912           Braune Erdzikade
# 3          Arocephalus punctum   0             1889                Widderzirpe
# 4            Athysanus quadrum   0             1919                 Sumpfzirpe
# 5            Cicadula saturata   0             1889           Braunseggenzirpe
# 6      Coryphaelus gyllenhalii   0             1919          Bunte Simsenzirpe
# 7          Cosmotettix panzeri   0             1952        Baltische Moorzirpe
# 8         Criomorphus borealis   0         vor 1960           Taigaspornzikade
# 9          Criomorphus moestus   0             1952    Schwedische Spornzikade
# 10       Delphacinus mesomelas   0         vor 1912      Elfenbein-Spornzikade
# 11        Delphax crassicornis   0         vor 1880    Bunte Schilfspornzikade
# 12       Doliotettix lunulatus   0             1928         Frühlingsgraszirpe
# 13            Empoasca affinis   0         vor 1960         Strauchblattzikade
# 14             Erotettix cyane   0             1889              Seerosenzirpe
# 15       Eurhadina kirschbaumi   0             1889  Traubeneichen-Elfenzikade
# 16            Euscelis venosus   0             1889              Eberwurzzirpe
# 17             Hephathus nanus   0             1921          Zwergmaskenzikade
# 18    Jassargus pseudocellaris   0         vor 1912      Wiesen-Spitzkopfzirpe
# 19             Kelisia ribauti   0             1952  Schwarzlippen-Spornzikade
# 20         Kelisia vittipennis   0             1952       Wollgras-Spornzikade
# 21     Limotettix atricapillus   0             1952          Schnabelriedzirpe
# 22            Macropsis impura   0             1919        Kleine Maskenzikade
# 23         Metalimnus formosus   0             1952         Schöne Marmorzirpe
# 24   Nothodelphax albocarinata   0         vor 1960       Schlenkenspornzikade
# 25      Nothodelphax distincta   0             1952       Hochmoor-Spornzikade
# 26         Oncodelphax pullula   0             1952          Klauenspornzikade
# 27      Oncopsis appendiculata   0             1910          Hakenmaskenzikade
# 28            Ophiola russeola   0             1952            Zwergheidezirpe
# 29      Paraliburnia clypealis   0             1951         Braune Spornzikade
# 30       Parapotes reticulatus   0             1919               Scherenzirpe
# 31    Planaphrodes trifasciata   0         vor 1912             Heideerdzikade
# 32       Populicerus laminatus   0             1921    Große Espenwinkerzikade
# 33          Stiroma bicarinata   0         vor 1912            Waldspornzikade
# 34  Stroggylocephalus agrestis   0             1932             Sumpferdzikade
# 35     Tettigometra leucophaea   0             1905   Punktierte Ameisenzikade
# 36            Ulopa reticulata   0             1921           Heidekrautzikade
# 37        Verdanus abdominalis   0         vor 1912     Schwarzgrüne Graszirpe
# 38          Zygina nigritarsis   0             1889          Ringelfeuerzikade

# %%
# Rename column names
df.rename(columns={
    "Wissenschaftlicher_Name": "Species",
    "Deutscher Name":"Deutscher_Name"
}, inplace = True
         )

# %%
# Creating a dictionary and extracting GBIF data
d = {}

for i in df.Species:     
   d[i] = species.name_backbone(name=str(i), kingdom='animals')
print("Complete")
# Out:
# Complete

# %%
gbif_data = pd.DataFrame.from_dict(d, orient = "index")
gbif_data.reset_index(inplace = True)
gbif_data.columns
# Out:
# Index(['index', 'usageKey', 'scientificName', 'canonicalName', 'rank',
#        'status', 'confidence', 'matchType', 'kingdom', 'phylum', 'order',
#        'family', 'genus', 'species', 'kingdomKey', 'phylumKey', 'classKey',
#        'orderKey', 'familyKey', 'genusKey', 'speciesKey', 'synonym', 'class',
#        'acceptedUsageKey'],
#       dtype='object')

# %%
df["Family"] = gbif_data["family"]
df
# Out:
#                        Species  BE letzter_Nachweis  \
# 0         Adarrus multinotatus   0         vor 1912
# 1            Allygus maculatus   0             1902
# 2          Anoscopus albifrons   0         vor 1912
# 3          Arocephalus punctum   0             1889
# 4            Athysanus quadrum   0             1919
# 5            Cicadula saturata   0             1889
# 6      Coryphaelus gyllenhalii   0             1919
# 7          Cosmotettix panzeri   0             1952
# 8         Criomorphus borealis   0         vor 1960
# 9          Criomorphus moestus   0             1952
# 10       Delphacinus mesomelas   0         vor 1912
# 11        Delphax crassicornis   0         vor 1880
# 12       Doliotettix lunulatus   0             1928
# 13            Empoasca affinis   0         vor 1960
# 14             Erotettix cyane   0             1889
# 15       Eurhadina kirschbaumi   0             1889
# 16            Euscelis venosus   0             1889
# 17             Hephathus nanus   0             1921
# 18    Jassargus pseudocellaris   0         vor 1912
# 19             Kelisia ribauti   0             1952
# 20         Kelisia vittipennis   0             1952
# 21     Limotettix atricapillus   0             1952
# 22            Macropsis impura   0             1919
# 23         Metalimnus formosus   0             1952
# 24   Nothodelphax albocarinata   0         vor 1960
# 25      Nothodelphax distincta   0             1952
# 26         Oncodelphax pullula   0             1952
# 27      Oncopsis appendiculata   0             1910
# 28            Ophiola russeola   0             1952
# 29      Paraliburnia clypealis   0             1951
# 30       Parapotes reticulatus   0             1919
# 31    Planaphrodes trifasciata   0         vor 1912
# 32       Populicerus laminatus   0             1921
# 33          Stiroma bicarinata   0         vor 1912
# 34  Stroggylocephalus agrestis   0             1932
# 35     Tettigometra leucophaea   0             1905
# 36            Ulopa reticulata   0             1921
# 37        Verdanus abdominalis   0         vor 1912
# 38          Zygina nigritarsis   0             1889
#
#                Deutscher_Name           Family
# 0        Gemeine Zwenkenzirpe     Cicadellidae
# 1            Fleckenbaumzirpe     Cicadellidae
# 2            Braune Erdzikade     Cicadellidae
# 3                 Widderzirpe     Cicadellidae
# 4                  Sumpfzirpe     Cicadellidae
# 5            Braunseggenzirpe     Cicadellidae
# 6           Bunte Simsenzirpe     Cicadellidae
# 7         Baltische Moorzirpe     Cicadellidae
# 8            Taigaspornzikade      Delphacidae
# 9     Schwedische Spornzikade      Delphacidae
# 10      Elfenbein-Spornzikade      Delphacidae
# 11    Bunte Schilfspornzikade      Delphacidae
# 12         Frühlingsgraszirpe     Cicadellidae
# 13         Strauchblattzikade     Cicadellidae
# 14              Seerosenzirpe     Cicadellidae
# 15  Traubeneichen-Elfenzikade     Cicadellidae
# 16              Eberwurzzirpe     Cicadellidae
# 17          Zwergmaskenzikade     Cicadellidae
# 18      Wiesen-Spitzkopfzirpe     Cicadellidae
# 19  Schwarzlippen-Spornzikade      Delphacidae
# 20       Wollgras-Spornzikade      Delphacidae
# 21          Schnabelriedzirpe     Cicadellidae
# 22        Kleine Maskenzikade     Cicadellidae
# 23         Schöne Marmorzirpe     Cicadellidae
# 24       Schlenkenspornzikade      Delphacidae
# 25       Hochmoor-Spornzikade      Delphacidae
# 26          Klauenspornzikade      Delphacidae
# 27          Hakenmaskenzikade     Cicadellidae
# 28            Zwergheidezirpe     Cicadellidae
# 29         Braune Spornzikade      Delphacidae
# 30               Scherenzirpe     Cicadellidae
# 31             Heideerdzikade     Cicadellidae
# 32    Große Espenwinkerzikade     Cicadellidae
# 33            Waldspornzikade      Delphacidae
# 34             Sumpferdzikade     Cicadellidae
# 35   Punktierte Ameisenzikade  Tettigometridae
# 36           Heidekrautzikade     Cicadellidae
# 37     Schwarzgrüne Graszirpe     Cicadellidae
# 38          Ringelfeuerzikade     Cicadellidae

# %%
# Saving the extracted csv to the "Data_cleaning_step1" directory
# export the dataframe as CSV

df.to_csv('../../Transformation/Data_cleaning_step1/Zikaden.csv', 
          index=False)

# %% [markdown]
# ## 14. Heteroptera_Wanzen.csv

# %%
# Read file into dataframe

df = pd.read_csv('Heteroptera_Wanzen.csv')
df.head()
# Out:
#                                         Species  BE Bestand  Trend_lang  \
# 0  Cryptostemma alienum HERRICH-SCHAEFFER, 1835   0      ex         NaN
# 1                 Corixa dentipes THOMSON, 1869   0      ex         NaN
# 2    Cymatia bonsdorffii (C. R. Sahlberg, 1819)   0      ex         NaN
# 3            Cymatia rogenhoferi (FIEBER, 1864)   0      ex         NaN
# 4             Micronecta griseola HORVÁTH, 1899   0      ex         NaN
#
#    Trend_kurz  RF   BB    D     GfU Letzter_Nachweis  Neozoon
# 0         NaN NaN  0.0   nb  5a, 5b        1853–1860      NaN
# 1         NaN NaN  NaN  NaN     11c             1989      NaN
# 2         NaN NaN  2.0    3     11c             1989      NaN
# 3         NaN NaN  0.0    D     14a             1989      NaN
# 4         NaN NaN  2.0   nb     11c             1959      NaN

# %%
df.columns
# Out:
# Index(['Species', 'BE', 'Bestand', 'Trend_lang', 'Trend_kurz', 'RF', 'BB', 'D',
#        'GfU', 'Letzter_Nachweis', 'Neozoon'],
#       dtype='object')

# %%
# Removing columns 
df.drop(columns = ["Bestand",
                   "Trend_lang",
                   "Trend_kurz",
                   "RF",
                   "BB",
                   "D",
                   "GfU",
                   "Neozoon"
                  ], inplace = True)
df
# Out:
#                                          Species  BE Letzter_Nachweis
# 0   Cryptostemma alienum HERRICH-SCHAEFFER, 1835   0        1853–1860
# 1                  Corixa dentipes THOMSON, 1869   0             1989
# 2     Cymatia bonsdorffii (C. R. Sahlberg, 1819)   0             1989
# 3             Cymatia rogenhoferi (FIEBER, 1864)   0             1989
# 4              Micronecta griseola HORVÁTH, 1899   0             1959
# ..                                           ...  ..              ...
# 83      Eysarcoris venustissimus (SCHRANK, 1776)   0             1959
# 84                 Jalla dumosa (LINNAEUS, 1758)   0             1930
# 85             Palomena viridissima (PODA, 1761)   0             1954
# 86              Sciocoris umbrinus (WOLFF, 1804)   0        1971–1991
# 87             Zicrona caerulea (LINNAEUS, 1758)   0             1977
#
# [88 rows x 3 columns]

# %%
# Editing species column based on binomial nomenclature

df1 = df.Species.str.split(pat=" ", n = 3, expand = True)
df1
df.Species = df1[0].str.cat(df1[1], sep = " ")
df
# Out:
#                      Species  BE Letzter_Nachweis
# 0       Cryptostemma alienum   0        1853–1860
# 1            Corixa dentipes   0             1989
# 2        Cymatia bonsdorffii   0             1989
# 3        Cymatia rogenhoferi   0             1989
# 4        Micronecta griseola   0             1959
# ..                       ...  ..              ...
# 83  Eysarcoris venustissimus   0             1959
# 84              Jalla dumosa   0             1930
# 85      Palomena viridissima   0             1954
# 86        Sciocoris umbrinus   0        1971–1991
# 87          Zicrona caerulea   0             1977
#
# [88 rows x 3 columns]

# %%
# Creating a dictionary and extracting GBIF data
d = {}

for i in df.Species:     
   d[i] = species.name_backbone(name=str(i), kingdom='animals')
print("Complete")
# Out:
# Complete

# %%
gbif_data = pd.DataFrame.from_dict(d, orient = "index")
gbif_data.reset_index(inplace = True)
gbif_data.columns
# Out:
# Index(['index', 'usageKey', 'scientificName', 'canonicalName', 'rank',
#        'status', 'confidence', 'matchType', 'kingdom', 'phylum', 'order',
#        'family', 'genus', 'species', 'kingdomKey', 'phylumKey', 'classKey',
#        'orderKey', 'familyKey', 'genusKey', 'speciesKey', 'synonym', 'class',
#        'acceptedUsageKey'],
#       dtype='object')

# %%
df["Family"] = gbif_data["family"]
df
# Out:
#                      Species  BE Letzter_Nachweis         Family
# 0       Cryptostemma alienum   0        1853–1860   Dipsocoridae
# 1            Corixa dentipes   0             1989      Corixidae
# 2        Cymatia bonsdorffii   0             1989      Corixidae
# 3        Cymatia rogenhoferi   0             1989      Corixidae
# 4        Micronecta griseola   0             1959  Micronectidae
# ..                       ...  ..              ...            ...
# 83  Eysarcoris venustissimus   0             1959   Pentatomidae
# 84              Jalla dumosa   0             1930   Pentatomidae
# 85      Palomena viridissima   0             1954   Pentatomidae
# 86        Sciocoris umbrinus   0        1971–1991   Pentatomidae
# 87          Zicrona caerulea   0             1977   Pentatomidae
#
# [88 rows x 4 columns]

# %%
# Saving the extracted csv to the "Data_cleaning_step1" directory
# export the dataframe as CSV

df.to_csv('../../Transformation/Data_cleaning_step1/Heteroptera_Wanzen.csv', 
          index=False)

# %% [markdown]
# ## 15. Bienen_und_waspen

# %%
# Read file into dataframe

df = pd.read_csv('Bienen_und_waspen.csv')
df.head()
# Out:
#                Wissenschaftlicher Name  BE BB   DE   GS Vorzugshabitate  \
# 0  Pristaulacus gloriator (FABRICIUS)*   0  D  NaN  NaN        B, W, WG
# 1            Chrysis fasciata OLIVIER*   0  G    G  NaN    WM, WW, \nWG
# 2                  Chrysis iris CHRIST   0  1    2  NaN           B, WG
# 3         Chrysis mediata LINSENMAIER*   0  3    -  NaN          AT, AW
# 4             Chrysis ruddii SHUCKARD*   0  -    -  NaN       R, GS, AT
#
#   Ökol_Typ  Gefährdungsursachen
# 0      par           2a, 9, 12b
# 1      par         2a, 12b, 14g
# 2      par         2a, 12b, 14g
# 3      par  2a, 12a, 14a, \n14g
# 4      par              2a, 14g

# %%
df.columns
# Out:
# Index(['Wissenschaftlicher Name', 'BE', 'BB', 'DE', 'GS', 'Vorzugshabitate',
#        'Ökol_Typ', 'Gefährdungsursachen'],
#       dtype='object')

# %%
# Removing columns 
df.drop(columns = ["BB",
                   "DE",
                   "GS",
                   "Vorzugshabitate",
                   "Ökol_Typ",
                   "Gefährdungsursachen"
                  ], inplace = True)
df
# Out:
#                 Wissenschaftlicher Name  BE
# 0   Pristaulacus gloriator (FABRICIUS)*   0
# 1             Chrysis fasciata OLIVIER*   0
# 2                   Chrysis iris CHRIST   0
# 3          Chrysis mediata LINSENMAIER*   0
# 4              Chrysis ruddii SHUCKARD*   0
# ..                                  ...  ..
# 93           Nomada rhenana F. MORAWITZ   0
# 94            Osmia pilicornis F. SMITH   0
# 95           Stelis phaeoptera (KIRBY)*   0
# 96       Thyreus histrionicus (ILLIGER)   0
# 97         Xylocopa violacea (LINNAEUS)   0
#
# [98 rows x 2 columns]

# %%
# Rename column names
df.rename(columns={
    "Wissenschaftlicher Name": "Species"
}, inplace = True
         )

# %%
# Editing species column based on binomial nomenclature

df1 = df.Species.str.split(pat=" ", n = 3, expand = True)
df1
df.Species = df1[0].str.cat(df1[1], sep = " ")
df
# Out:
#                    Species  BE
# 0   Pristaulacus gloriator   0
# 1         Chrysis fasciata   0
# 2             Chrysis iris   0
# 3          Chrysis mediata   0
# 4           Chrysis ruddii   0
# ..                     ...  ..
# 93          Nomada rhenana   0
# 94        Osmia pilicornis   0
# 95       Stelis phaeoptera   0
# 96    Thyreus histrionicus   0
# 97       Xylocopa violacea   0
#
# [98 rows x 2 columns]

# %%
# Creating a dictionary and extracting GBIF data
d = {}

for i in df.Species:     
   d[i] = species.name_backbone(name=str(i), kingdom='animals')
print("Complete")
# Out:
# Complete

# %%
gbif_data = pd.DataFrame.from_dict(d, orient = "index")
gbif_data.reset_index(inplace = True)
gbif_data.columns
# Out:
# Index(['index', 'usageKey', 'scientificName', 'canonicalName', 'rank',
#        'status', 'confidence', 'matchType', 'kingdom', 'phylum', 'order',
#        'family', 'genus', 'species', 'kingdomKey', 'phylumKey', 'classKey',
#        'orderKey', 'familyKey', 'genusKey', 'speciesKey', 'synonym', 'class',
#        'acceptedUsageKey'],
#       dtype='object')

# %%
df["Family"] = gbif_data["family"]
df
# Out:
#                    Species  BE        Family
# 0   Pristaulacus gloriator   0     Aulacidae
# 1         Chrysis fasciata   0     Masaridae
# 2             Chrysis iris   0     Masaridae
# 3          Chrysis mediata   0     Masaridae
# 4           Chrysis ruddii   0     Masaridae
# ..                     ...  ..           ...
# 92          Nomada rhenana   0        Apidae
# 93        Osmia pilicornis   0  Megachilidae
# 94       Stelis phaeoptera   0  Megachilidae
# 95    Thyreus histrionicus   0        Apidae
# 96       Xylocopa violacea   0        Apidae
#
# [97 rows x 3 columns]

# %%
# Saving the extracted csv to the "Data_cleaning_step1" directory
# export the dataframe as CSV

df.to_csv('../../Transformation/Data_cleaning_step1/Bienen_und_waspen.csv', 
          index=False)

# %% [markdown]
# ## 16. Odonata

# %%
# Read file into dataframe

df = pd.read_csv('Odonata.csv')
df.head()
# Out:
#                       Wissenschaftlicher_Name  BE Bestand  Trend_lang  \
# 0    Nehalennia speciosa (CHARPENTIER, 1840)*   0      ex         NaN
# 1  Onychogomphus forcipatus (LINNAEUS, 1758)*   0      ex         NaN
# 2     Cordulegaster boltonii (DONOVAN, 1807)*   0      ex         NaN
# 3   Leucorrhinia dubia (VANDER LINDEN, 1825)*   0      ex         NaN
#
#    Trend_kurz  RF  BB  D  GS                GfU               Deutscher Name
# 0         NaN NaN   2  1  §§  1a, 1c, 2d, 10c,                  Zwerglibelle
# 1         NaN NaN   3  V   §    3a, 3b, 5a, 5b,         Kleine Zangenlibelle
# 2         NaN NaN   3  *   §        1a, 5b, 11c  Zweigestreifte Quelljungfer
# 3         NaN NaN   2  3   §   2d, 7e, 10c, 11c           Kleine Moosjungfer

# %%
# Removing columns 
df.drop(columns = ["Bestand",
                   "Trend_lang",
                   "Trend_kurz",
                   "RF",
                   "BB",
                   "D",
                   "GS",
                   "GfU"
                  ], inplace = True)
df
# Out:
#                       Wissenschaftlicher_Name  BE               Deutscher Name
# 0    Nehalennia speciosa (CHARPENTIER, 1840)*   0                 Zwerglibelle
# 1  Onychogomphus forcipatus (LINNAEUS, 1758)*   0         Kleine Zangenlibelle
# 2     Cordulegaster boltonii (DONOVAN, 1807)*   0  Zweigestreifte Quelljungfer
# 3   Leucorrhinia dubia (VANDER LINDEN, 1825)*   0           Kleine Moosjungfer

# %%
# Rename column names
df.rename(columns={
    "Wissenschaftlicher_Name": "Species"
}, inplace = True
         )

# %%
# Editing species column based on binomial nomenclature

df1 = df.Species.str.split(pat=" ", n = 3, expand = True)
df1
df.Species = df1[0].str.cat(df1[1], sep = " ")
df
# Out:
#                     Species  BE               Deutscher Name
# 0       Nehalennia speciosa   0                 Zwerglibelle
# 1  Onychogomphus forcipatus   0         Kleine Zangenlibelle
# 2    Cordulegaster boltonii   0  Zweigestreifte Quelljungfer
# 3        Leucorrhinia dubia   0           Kleine Moosjungfer

# %%
# Creating a dictionary and extracting GBIF data
d = {}

for i in df.Species:     
   d[i] = species.name_backbone(name=str(i), kingdom='animals')
print("Complete")
# Out:
# Complete

# %%
gbif_data = pd.DataFrame.from_dict(d, orient = "index")
gbif_data.reset_index(inplace = True)
gbif_data.columns
# Out:
# Index(['index', 'usageKey', 'scientificName', 'canonicalName', 'rank',
#        'status', 'confidence', 'matchType', 'kingdom', 'phylum', 'order',
#        'family', 'genus', 'species', 'kingdomKey', 'phylumKey', 'classKey',
#        'orderKey', 'familyKey', 'genusKey', 'speciesKey', 'synonym', 'class'],
#       dtype='object')

# %%
df["Family"] = gbif_data["family"]
df
# Out:
#                     Species  BE               Deutscher Name            Family
# 0       Nehalennia speciosa   0                 Zwerglibelle    Coenagrionidae
# 1  Onychogomphus forcipatus   0         Kleine Zangenlibelle         Gomphidae
# 2    Cordulegaster boltonii   0  Zweigestreifte Quelljungfer  Cordulegastridae
# 3        Leucorrhinia dubia   0           Kleine Moosjungfer      Libellulidae

# %%
# Saving the extracted csv to the "Data_cleaning_step1" directory
# export the dataframe as CSV

df.to_csv('../../Transformation/Data_cleaning_step1/Odonata.csv', 
          index=False)

# %% [markdown]
# ## 17. Psychidae.csv

# %%
# Read file into dataframe

df = pd.read_csv('Psychidae.csv')
df.head()
# Out:
#                           Art Brandenburg Nachweise in Berlin bis 1989  \
# 0     Epichnopterix sieboldii           ●                         1965
# 1          Acanthopsyche atra           ●                         1982
# 2      Pachythelia villosella           ●                         1963
# 3  Phalacropterix graslinella           ●                      um 1900
# 4       Megalophanes viciella           ●                         1966
#
#     Habitat
# 0     CB,TR
# 1  CB,WS,ZM
# 2  CB,TR,ZM
# 3     CB,ZM
# 4    MGL,NM

# %%
# Removing columns 
df.drop(columns = ["Brandenburg",
                   "Habitat"
                  ], inplace = True)
df
# Out:
#                           Art Nachweise in Berlin bis 1989
# 0     Epichnopterix sieboldii                         1965
# 1          Acanthopsyche atra                         1982
# 2      Pachythelia villosella                         1963
# 3  Phalacropterix graslinella                      um 1900
# 4       Megalophanes viciella                         1966

# %%
# Rename column names
df.rename(columns={
    "Art": "Species"
}, inplace = True
         )

# %%
# Editing species column based on binomial nomenclature

#df1 = df.Species.str.split(pat=" ", n = 3, expand = True)
#df1
#df.Species = df1[0].str.cat(df1[1], sep = " ")
#df

# %%
# Creating a dictionary and extracting GBIF data
d = {}

for i in df.Species:     
   d[i] = species.name_backbone(name=str(i), kingdom='animals')
print("Complete")
# Out:
# Complete

# %%
gbif_data = pd.DataFrame.from_dict(d, orient = "index")
gbif_data.reset_index(inplace = True)
gbif_data.columns
# Out:
# Index(['index', 'usageKey', 'scientificName', 'canonicalName', 'rank',
#        'status', 'confidence', 'matchType', 'kingdom', 'phylum', 'order',
#        'family', 'genus', 'species', 'kingdomKey', 'phylumKey', 'classKey',
#        'orderKey', 'familyKey', 'genusKey', 'speciesKey', 'synonym', 'class'],
#       dtype='object')

# %%
df["Family"] = gbif_data["family"]
df
# Out:
#                       Species Nachweise in Berlin bis 1989     Family
# 0     Epichnopterix sieboldii                         1965  Psychidae
# 1          Acanthopsyche atra                         1982  Psychidae
# 2      Pachythelia villosella                         1963  Psychidae
# 3  Phalacropterix graslinella                      um 1900  Psychidae
# 4       Megalophanes viciella                         1966  Psychidae

# %%
# Saving the extracted csv to the "Data_cleaning_step1" directory
# export the dataframe as CSV

df.to_csv('../../Transformation/Data_cleaning_step1/Psychidae.csv', 
          index=False)

# %% [markdown]
# ## 18. Raphidioptera_Megaloptera_Neuroptera.csv

# %%
# Read file into dataframe

df = pd.read_csv('Raphidioptera_Megaloptera_Neuroptera.csv')
df.head()
# Out:
#                     Wissenschaftlicher Name  BE ST DE   GS    Vorzugshabitate  \
# 0            Dichrostigma flavipes (STEIN)*   0  -  V  NaN              W, WK
# 1               Nineta inpunctata (REUTER)*   0  -  G  NaN              W, WT
# 2  Sympherobius fuscescens (WAL-\nLENGREN)*   0  -  V  NaN              W, WK
# 3                 Mantispa styriaca (PODA)*   0  0  0  NaN  B, BLT, BFT, \nWT
# 4     Distoleon tetragrammicus (FABRICIUS)*   0  -  2    §          W, WK, WT
#
#   Gefährdungsursachen
# 0              9, 12b
# 1              9, 12b
# 2              9, 12b
# 3          2a, 9, 12b
# 4              9, 12b

# %%
# Removing columns 
df.drop(columns = ["ST",
                   "DE",
                   "GS",
                   "Vorzugshabitate",
                   "Gefährdungsursachen"
                  ], inplace = True)
df
# Out:
#                     Wissenschaftlicher Name  BE
# 0            Dichrostigma flavipes (STEIN)*   0
# 1               Nineta inpunctata (REUTER)*   0
# 2  Sympherobius fuscescens (WAL-\nLENGREN)*   0
# 3                 Mantispa styriaca (PODA)*   0
# 4     Distoleon tetragrammicus (FABRICIUS)*   0

# %%
# Rename column names
df.rename(columns={
    "Wissenschaftlicher Name": "Species"
}, inplace = True
         )

# %%
# Editing species column based on binomial nomenclature

df1 = df.Species.str.split(pat=" ", n = 3, expand = True)
df1
df.Species = df1[0].str.cat(df1[1], sep = " ")
df
# Out:
#                     Species  BE
# 0     Dichrostigma flavipes   0
# 1         Nineta inpunctata   0
# 2   Sympherobius fuscescens   0
# 3         Mantispa styriaca   0
# 4  Distoleon tetragrammicus   0

# %%
# Creating a dictionary and extracting GBIF data
d = {}

for i in df.Species:     
   d[i] = species.name_backbone(name=str(i), kingdom='animals')
print("Complete")
# Out:
# Complete

# %%
gbif_data = pd.DataFrame.from_dict(d, orient = "index")
gbif_data.reset_index(inplace = True)
gbif_data.columns
# Out:
# Index(['index', 'usageKey', 'scientificName', 'canonicalName', 'rank',
#        'status', 'confidence', 'matchType', 'kingdom', 'phylum', 'order',
#        'family', 'genus', 'species', 'kingdomKey', 'phylumKey', 'classKey',
#        'orderKey', 'familyKey', 'genusKey', 'speciesKey', 'synonym', 'class'],
#       dtype='object')

# %%
df["Family"] = gbif_data["family"]
df
# Out:
#                     Species  BE          Family
# 0     Dichrostigma flavipes   0     Raphidiidae
# 1         Nineta inpunctata   0     Chrysopidae
# 2   Sympherobius fuscescens   0    Hemerobiidae
# 3         Mantispa styriaca   0     Mantispidae
# 4  Distoleon tetragrammicus   0  Myrmeleontidae

# %%
# Saving the extracted csv to the "Data_cleaning_step1" directory
# export the dataframe as CSV

df.to_csv('../../Transformation/Data_cleaning_step1/Raphidioptera_Megaloptera_Neuroptera.csv', 
          index=False)

# %% [markdown]
# ## 19. Koecherfliegen_Trichoptera.csv

# %%
# Read file into dataframe

df = pd.read_csv('Koecherfliegen_Trichoptera.csv')
df.head()
# Out:
#                         Wissenschaftlicher Name  BE Bestand Letzter Nachweis  \
# 0               Agapetus fuscipes CURTIS, 1834*   0      ex         vor 1882
# 1         Grammotaulius nitidus (MÜLLER, 1764)*   0      ex         ca. 1890
# 2    Hydropsyche contubernalis MCLACHLAN, 1865*   0      ex             1889
# 3             Limnephilus elegans CURTIS, 1834*   0      ex         vor 1991
# 4  Limnephilus fuscinervis (ZETTERSTEDT, 1840)*   0      ex         vor 1909
#
#     BB   D          GfU Gewässer-zonierung         Familie
# 0  NaN   *          11c               K-ER   Glossomatidae
# 1  NaN   G          11c           MP-HP, L   Limnephilidae
# 2  NaN   *  3b, 5a, 11c              MR-MP  Hydropsychidae
# 3  1.0  2       2d, 11c             L (ÜM)   Limnephilidae
# 4  2.0  G           11c                  L   Limnephilidae

# %%
# Removing columns 
df.drop(columns = ["Bestand",
                   "BB",
                   "D",
                   "GfU",
                   "Gewässer-zonierung"
                  ], inplace = True)
df
# Out:
#                          Wissenschaftlicher Name  BE Letzter Nachweis  \
# 0                Agapetus fuscipes CURTIS, 1834*   0         vor 1882
# 1          Grammotaulius nitidus (MÜLLER, 1764)*   0         ca. 1890
# 2     Hydropsyche contubernalis MCLACHLAN, 1865*   0             1889
# 3              Limnephilus elegans CURTIS, 1834*   0         vor 1991
# 4   Limnephilus fuscinervis (ZETTERSTEDT, 1840)*   0         vor 1909
# 5  Nemotaulius punctatolineatus (RETZIUS, 1783)*   0             1890
# 6          Psychomyia pusilla (FABRICIUS, 1781)*   0        vor 1914?
#
#           Familie
# 0   Glossomatidae
# 1   Limnephilidae
# 2  Hydropsychidae
# 3   Limnephilidae
# 4   Limnephilidae
# 5   Limnephilidae
# 6   Psychomyiidae

# %%
# Rename column names
df.rename(columns={
    "Wissenschaftlicher Name": "Species"
}, inplace = True
         )

# %%
# Editing species column based on binomial nomenclature

df1 = df.Species.str.split(pat=" ", n = 3, expand = True)
df1
df.Species = df1[0].str.cat(df1[1], sep = " ")
df
# Out:
#                         Species  BE Letzter Nachweis         Familie
# 0             Agapetus fuscipes   0         vor 1882   Glossomatidae
# 1         Grammotaulius nitidus   0         ca. 1890   Limnephilidae
# 2     Hydropsyche contubernalis   0             1889  Hydropsychidae
# 3           Limnephilus elegans   0         vor 1991   Limnephilidae
# 4       Limnephilus fuscinervis   0         vor 1909   Limnephilidae
# 5  Nemotaulius punctatolineatus   0             1890   Limnephilidae
# 6            Psychomyia pusilla   0        vor 1914?   Psychomyiidae

# %%
# Creating a dictionary and extracting GBIF data
d = {}

for i in df.Species:     
   d[i] = species.name_backbone(name=str(i), kingdom='animals')
print("Complete")
# Out:
# Complete

# %%
gbif_data = pd.DataFrame.from_dict(d, orient = "index")
gbif_data.reset_index(inplace = True)
gbif_data.columns
# Out:
# Index(['index', 'usageKey', 'scientificName', 'canonicalName', 'rank',
#        'status', 'confidence', 'matchType', 'kingdom', 'phylum', 'order',
#        'family', 'genus', 'species', 'kingdomKey', 'phylumKey', 'classKey',
#        'orderKey', 'familyKey', 'genusKey', 'speciesKey', 'synonym', 'class'],
#       dtype='object')

# %%
df["Family"] = gbif_data["family"]
df
# Out:
#                         Species  BE Letzter Nachweis         Familie  \
# 0             Agapetus fuscipes   0         vor 1882   Glossomatidae
# 1         Grammotaulius nitidus   0         ca. 1890   Limnephilidae
# 2     Hydropsyche contubernalis   0             1889  Hydropsychidae
# 3           Limnephilus elegans   0         vor 1991   Limnephilidae
# 4       Limnephilus fuscinervis   0         vor 1909   Limnephilidae
# 5  Nemotaulius punctatolineatus   0             1890   Limnephilidae
# 6            Psychomyia pusilla   0        vor 1914?   Psychomyiidae
#
#             Family
# 0  Glossosomatidae
# 1    Limnephilidae
# 2   Hydropsychidae
# 3    Limnephilidae
# 4    Limnephilidae
# 5    Limnephilidae
# 6    Psychomyiidae

# %%
df.drop(columns = ["Familie"
                  ], inplace = True)
df
# Out:
#                         Species  BE Letzter Nachweis           Family
# 0             Agapetus fuscipes   0         vor 1882  Glossosomatidae
# 1         Grammotaulius nitidus   0         ca. 1890    Limnephilidae
# 2     Hydropsyche contubernalis   0             1889   Hydropsychidae
# 3           Limnephilus elegans   0         vor 1991    Limnephilidae
# 4       Limnephilus fuscinervis   0         vor 1909    Limnephilidae
# 5  Nemotaulius punctatolineatus   0             1890    Limnephilidae
# 6            Psychomyia pusilla   0        vor 1914?    Psychomyiidae

# %%
# Saving the extracted csv to the "Data_cleaning_step1" directory
# export the dataframe as CSV

df.to_csv('../../Transformation/Data_cleaning_step1/Koecherfliegen_Trichoptera.csv', 
          index=False)

# %% [markdown]
# ## 20. Next

# %%
# Read file into dataframe

df = pd.read_csv('name.csv')
df.head()

# %%
# Removing columns 
df.drop(columns = ["BB",
                   "DE",
                   "GS",
                   "H",
                   "Vorzugs-habitate",
                   "Biol_ökol_Typ",
                   "Gefährdungsursachen"
                  ], inplace = True)
df

# %%
# Editing species column based on binomial nomenclature

df1 = df.Species.str.split(pat=" ", n = 3, expand = True)
df1
df.Species = df1[0].str.cat(df1[1], sep = " ")
df

# %%
# Creating a dictionary and extracting GBIF data
d = {}

for i in df.Species:     
   d[i] = species.name_backbone(name=str(i), kingdom='animals')
print("Complete")

# %%
gbif_data = pd.DataFrame.from_dict(d, orient = "index")
gbif_data.reset_index(inplace = True)
gbif_data.columns

# %%
df["Family"] = gbif_data["family"]
df

# %%
# Saving the extracted csv to the "Data_cleaning_step1" directory
# export the dataframe as CSV

df.to_csv('../../Transformation/Data_cleaning_step1/name.csv', 
          index=False)

# %% [markdown]
# ## 21. Next

# %%
# Read file into dataframe

df = pd.read_csv('name.csv')
df.head()

# %%
# Removing columns 
df.drop(columns = ["BB",
                   "DE",
                   "GS",
                   "H",
                   "Vorzugs-habitate",
                   "Biol_ökol_Typ",
                   "Gefährdungsursachen"
                  ], inplace = True)
df

# %%
# Editing species column based on binomial nomenclature

df1 = df.Species.str.split(pat=" ", n = 3, expand = True)
df1
df.Species = df1[0].str.cat(df1[1], sep = " ")
df

# %%
# Creating a dictionary and extracting GBIF data
d = {}

for i in df.Species:     
   d[i] = species.name_backbone(name=str(i), kingdom='animals')
print("Complete")

# %%
gbif_data = pd.DataFrame.from_dict(d, orient = "index")
gbif_data.reset_index(inplace = True)
gbif_data.columns

# %%
df["Family"] = gbif_data["family"]
df

# %%
# Saving the extracted csv to the "Data_cleaning_step1" directory
# export the dataframe as CSV

df.to_csv('../../Transformation/Data_cleaning_step1/name.csv', 
          index=False)
