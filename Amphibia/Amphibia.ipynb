# %%
import camelot
import pandas as pd

# %% [markdown]
# # Updated Process

# %% [markdown]
# ## 1. Create empty dataframe with proper column names

# %%
# This is where data will be added after cleaning. The final dataframe for export

# %%
df = pd.DataFrame(columns = [
    "Species",
    "BE", 
    "Bestand", 
    "Trend_lang",
    "Trend_kurz",
    "RF",
    "BB",
    "D",
    "GS",
    "GfU",
    "Letzter_Nachweis",
    "Common_name"
])
df
# Out:
# Empty DataFrame
# Columns: [Species, BE, Bestand, Trend_lang, Trend_kurz, RF, BB, D, GS, GfU, Letzter_Nachweis, Common_name]
# Index: []

# %%
df.shape
# Out:
# (0, 12)

# %% [markdown]
# ## 2. Setup mechanism to store accuracy report : QA step

# %%
accuracy = []

# %% [markdown]
# ## 3. Dictionary of dataframes on the go

# %%
# Dictionary to collect dataframes created from each table
d = {}

# %% [markdown]
# ## 4. Adding the list of pages to be parsed

# %%
pages = []
i = 7
while i < 8:
    pages.append(i)
    i = i + 1
print(pages)
# Out:
# [7]

# %% [markdown]
# ## 5. Parsing through the pages

# %%
for i in pages:
    # print page number
    print (i)
    # create dataframe with page number
    d[i] = pd.DataFrame()
    #read the page
    tables = camelot.read_pdf('rote_liste_amphibien_kuehnel_et_al.pdf', 
                              pages= str(i), 
                              flavor='stream', edge_tol=1000, row_tol=10)
    #tables = camelot.read_pdf('18_netzfl_print.pdf', pages= str(i), flavor='lattice')
    # add the accuracy report
    accuracy.append(tables[0].parsing_report)
    # assign the first table to a dataframe
    d[i] = tables[0].df
    print(d[i].shape)
# Print Done once all pages are parsed
print ("Done")
# Out:
# 7
# (28, 12)
# Done

# %%
# Check accuracy reports for the process
accuracy
# Out:
# [{'accuracy': 99.77, 'whitespace': 47.02, 'order': 1, 'page': 7}]

# %% [markdown]
# # Data cleanup steps

# %% [raw]
# d[67]
#     : Look at the data frame extracted from 67th page
# d[67].shape
#     : Look at the shape of the dataframe
# d[68] = d[68].drop([12], axis=1)
#     : Drop the 12th column in place
# d[68][10] = d[68][[10, 11]].agg(' '.join, axis=1)
#     : Join 10th and 11th columns with a space in between
# d[69][[9,11]] = d[69][9].str.split('\n', expand=True)
#     : Split 9th Column at the '\n' sign and add a new column called 11
# column_to_move = d[69].pop(11)
# column_to_move
# d[69].insert(9, 11, column_to_move )
#     : Pop column 11 and insert it at column 9
# d[75].insert(9, '10', ["",""])
#     : Insert two rows of column 10 after 9 with empty cells

# %%
# Check whether all dataframes are of the same size
for key in d:
    print(key)
    print(d[key].shape)
# Out:
# 7
# (28, 12)

# %%
# Removing empty dataframes
# del d[64]
# del d[74]

# %%
# Creates a sorted dictionary (sorted by key)
from collections import OrderedDict
d2 = OrderedDict(sorted(d.items()))

# %%
# Check whether the dictionary is sorted
for key in d2:
    print(key)
# Out:
# 7

# %%
# Rename all the dataframes in the sorted dictionary
for key in d2:
    print(key)
    d2[key].columns = [ "Species",
    "BE", 
    "Bestand", 
    "Trend_lang",
    "Trend_kurz",
    "RF",
    "BB",
    "D",
    "GS",
    "GfU",
    "Letzter_Nachweis",
    "Common_name"]
print("Rename completed for concat")
# Out:
# 7
# Rename completed for concat

# %%
# Concatanate all the non-empty dataframes in the sorted dictionary into the empty df
for key in d2:
    df = pd.concat([df, d2[key]], axis = 0)
df
# Out:
#                                               Species  BE  Bestand Trend_lang  \
# 0   Tabelle 3: Rote Liste und Gesamtartenliste der...
# 1                             Wissenschaftlicher Name  BE  Bestand      Trend
# 2                                                                        lang
# 3                             Schwanzlurche (Urodela)
# 4             Ichthyosaura alpestris (LAURENTI, 1768)   ♦       nb
# 5               Lissotriton vulgaris (LINNAEUS, 1758)   *       sh         <<
# 6
# 7                 Triturus cristatus (LAURENTI, 1768)   2        s         <<
# 8
# 9                                Froschlurche (ANURA)
# 10                   Bombina bombina (LINNAEUS, 1758)   1       es        <<<
# 11
# 12                 Pelobates fuscus  (LAURENTI, 1768)   3       mh         <<
# 13                         Bufo bufo (LINNAEUS, 1758)   *       sh          <
# 14
# 15                 Epidalea calamita (LAURENTI, 1768)   1       es          <
# 16
# 17                   Bufotes viridis (LAURENTI, 1768)   2        s         <<
# 18
# 19                      Hyla arborea (LINNAEUS, 1758)   0       ex
# 20
# 21         Pelophylax kl. esculentus (Linnaeus, 1758)   *       sh          <
# 22              Pelophylax lessonae (CAMERANAO, 1782)   0       ex
# 23                Pelophylax ridibundus (PALLAS, 1771   3        s          <
# 24                         Rana arvalis NILSSON, 1842   3       mh         <<
# 25
# 26                     Rana temporaria LINNAEUS, 1758   3       mh         <<
# 27
#
#                    Trend_kurz  RF  BB  D       GS                       GfU  \
# 0
# 1                       Trend  RF  BB  D       GS                       GfU
# 2                        kurz
# 3
# 4                                   2  *        §             10c, 11c, 14l
# 5                           =   =  **  *        §  1a, 2a, 6e, 8a, 9a, 10c,
# 6                                                                       11c
# 7   (cid:114)(cid:114)(cid:3)   =   3  V  §§, II,   1a, 2a, 6e, 8a 9a, 10c,
# 8                                              IV                       11c
# 9
# 10                ((cid:114))   =   1  2  §§, II,   1a, 2a, 4a, 6a, 6e, 7e,
# 11                                             IV        10c, 11c, 12c, 14e
# 12  (cid:114)(cid:114)(cid:3)   =   3  3   §§, IV          1a, 6e, 10c, 14k
# 13                ((cid:114))   =   *  *        §     1a, 8a, 9a, 11c, 12b,
# 14                                                                      14k
# 15                          =   -   3  V   §§, IV     1a, 7a, 7e, 10c, 11c,
# 16                                                            12c, 14c, 14k
# 17                ((cid:114))   =   3  3   §§, IV  1a, 2a, 6e, 7a, 7e, 10c,
# 18                                                            11c, 12c, 14c
# 19                                  2  3   §§, IV  1a, 2a, 4a, 6a,10c, 11c,
# 20                                                                 12c, 14c
# 21                          =   =  **  *        §  2d, 3b, 5a, 5b, 10c, 11c
# 22                                  G  G    §, IV         2d, 10c, 11c, 12b
# 23                ((cid:114))   =   3  *        §      3b, 5a, 5b, 10c, 11c
# 24  (cid:114)(cid:114)(cid:3)   =   *  3   §§, IV   1a, 2d, 6a, 6b, 6c, 6e,
# 25                                                        8a, 11c, 12b, 14k
# 26                ((cid:114))   =   3  *        §   1a, 2d, 6a, 6b, 6c, 6e,
# 27                                                   8a, 10c, 11c, 12b, 14k
#
#    Letzter_Nachweis            Common_name
# 0
# 1           Letzter         Deutscher Name
# 2          Nachweis
# 3
# 4                                Bergmolch
# 5                               Teichmolch
# 6
# 7                    Nördlicher Kammmolch,
# 8                                Kammmolch
# 9
# 10                            Rotbauchunke
# 11
# 12                          Knoblauchkröte
# 13                                Erdkröte
# 14
# 15                              Kreuzkröte
# 16
# 17                            Wechselkröte
# 18
# 19         vor 1960     Mitteleuropäischer
# 20                              Laubfrosch
# 21                             Teichfrosch
# 22             1991   Kleiner Wasserfrosch
# 23                               Seefrosch
# 24                              Moorfrosch
# 25
# 26                              Grasfrosch
# 27

# %%
# Definition of extinction
df2 = df.loc[df["BE"] == "0"]
df2.head()
# Out:
#                                   Species BE Bestand Trend_lang Trend_kurz RF  \
# 19          Hyla arborea (LINNAEUS, 1758)  0      ex
# 22  Pelophylax lessonae (CAMERANAO, 1782)  0      ex
#
#    BB  D      GS                       GfU Letzter_Nachweis  \
# 19  2  3  §§, IV  1a, 2a, 4a, 6a,10c, 11c,         vor 1960
# 22  G  G   §, IV         2d, 10c, 11c, 12b             1991
#
#              Common_name
# 19    Mitteleuropäischer
# 22  Kleiner Wasserfrosch

# %%
df2.reset_index(inplace = True)
df2.head()
# Out:
#    index                                Species BE Bestand Trend_lang  \
# 0     19          Hyla arborea (LINNAEUS, 1758)  0      ex
# 1     22  Pelophylax lessonae (CAMERANAO, 1782)  0      ex
#
#   Trend_kurz RF BB  D      GS                       GfU Letzter_Nachweis  \
# 0                2  3  §§, IV  1a, 2a, 4a, 6a,10c, 11c,         vor 1960
# 1                G  G   §, IV         2d, 10c, 11c, 12b             1991
#
#             Common_name
# 0    Mitteleuropäischer
# 1  Kleiner Wasserfrosch

# %%
df2 = df2.drop(['index'], axis=1)
df2.head()
# Out:
#                                  Species BE Bestand Trend_lang Trend_kurz RF  \
# 0          Hyla arborea (LINNAEUS, 1758)  0      ex
# 1  Pelophylax lessonae (CAMERANAO, 1782)  0      ex
#
#   BB  D      GS                       GfU Letzter_Nachweis  \
# 0  2  3  §§, IV  1a, 2a, 4a, 6a,10c, 11c,         vor 1960
# 1  G  G   §, IV         2d, 10c, 11c, 12b             1991
#
#             Common_name
# 0    Mitteleuropäischer
# 1  Kleiner Wasserfrosch

# %%
df3 = df.loc[df["Bestand"] == "ex"]
df3.reset_index(inplace = True)
df3 = df3.drop(['index'], axis=1)
df3.head()
# Out:
#                                  Species BE Bestand Trend_lang Trend_kurz RF  \
# 0          Hyla arborea (LINNAEUS, 1758)  0      ex
# 1  Pelophylax lessonae (CAMERANAO, 1782)  0      ex
#
#   BB  D      GS                       GfU Letzter_Nachweis  \
# 0  2  3  §§, IV  1a, 2a, 4a, 6a,10c, 11c,         vor 1960
# 1  G  G   §, IV         2d, 10c, 11c, 12b             1991
#
#             Common_name
# 0    Mitteleuropäischer
# 1  Kleiner Wasserfrosch

# %%
df2.describe()
# Out:
#                               Species BE Bestand Trend_lang Trend_kurz RF BB  \
# count                               2  2       2          2          2  2  2
# unique                              2  1       1          1          1  1  2
# top     Hyla arborea (LINNAEUS, 1758)  0      ex                           2
# freq                                1  2       2          2          2  2  1
#
#         D      GS                       GfU Letzter_Nachweis  \
# count   2       2                         2                2
# unique  2       2                         2                2
# top     3  §§, IV  1a, 2a, 4a, 6a,10c, 11c,         vor 1960
# freq    1       1                         1                1
#
#                Common_name
# count                    2
# unique                   2
# top     Mitteleuropäischer
# freq                     1

# %%
df3.describe()
# Out:
#                               Species BE Bestand Trend_lang Trend_kurz RF BB  \
# count                               2  2       2          2          2  2  2
# unique                              2  1       1          1          1  1  2
# top     Hyla arborea (LINNAEUS, 1758)  0      ex                           2
# freq                                1  2       2          2          2  2  1
#
#         D      GS                       GfU Letzter_Nachweis  \
# count   2       2                         2                2
# unique  2       2                         2                2
# top     3  §§, IV  1a, 2a, 4a, 6a,10c, 11c,         vor 1960
# freq    1       1                         1                1
#
#                Common_name
# count                    2
# unique                   2
# top     Mitteleuropäischer
# freq                     1

# %%
# export the dataframe as CSV
df2.to_csv('Amphibia.csv', index=False)
