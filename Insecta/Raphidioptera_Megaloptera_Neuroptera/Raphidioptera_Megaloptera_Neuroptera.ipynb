# %%
import camelot
import pandas as pd

# %% [markdown]
# # Updated Process

# %% [markdown]
# ## 1. Create empty dataframe with proper column names

# %%
# This is where data will be added after cleaning. The final dataframe for export

# %%
df = pd.DataFrame(columns = [
    "Wissenschaftlicher Name",
    "BE", 
    "ST", 
    "DE", 
    "GS",
    "Vorzugshabitate",
    "Gefährdungsursachen"
])
df
# Out:
# Empty DataFrame
# Columns: [Wissenschaftlicher Name, BE, ST, DE, GS, Vorzugshabitate, Gefährdungsursachen]
# Index: []

# %%
df.shape
# Out:
# (0, 7)

# %% [markdown]
# ## 2. Setup mechanism to store accuracy report : QA step

# %%
accuracy = []

# %% [markdown]
# ## 3. Dictionary of dataframes on the go

# %%
# Dictionary to collect dataframes created from each table
d = {}

# %% [markdown]
# ## 4. Adding the list of pages to be parsed

# %%
pages = []
i = 3
while i < 6:
    pages.append(i)
    i = i + 1
print(pages)
# Out:
# [3, 4, 5]

# %% [markdown]
# ## 5. Parsing through the pages

# %%
for i in pages:
    # print page number
    print (i)
    # create dataframe with page number
    d[i] = pd.DataFrame()
    #read the page
    #tables = camelot.read_pdf('18_netzfl_print.pdf', 
    #                          pages= str(i), 
    #                          flavor='stream', edge_tol=1000, row_tol=10)
    tables = camelot.read_pdf('18_netzfl_print.pdf', pages= str(i), flavor='lattice')
    # add the accuracy report
    accuracy.append(tables[0].parsing_report)
    # assign the first table to a dataframe
    d[i] = tables[0].df
    print(d[i].shape)
# Print Done once all pages are parsed
print ("Done")
# Out:
# 3
# (20, 7)
# 4
# (36, 7)
# 5
# (33, 7)
# Done

# %%
# Check accuracy reports for the process
accuracy
# Out:
# [{'accuracy': 100.0, 'whitespace': 42.86, 'order': 1, 'page': 3},
#  {'accuracy': 100.0, 'whitespace': 26.98, 'order': 1, 'page': 4},
#  {'accuracy': 100.0, 'whitespace': 30.3, 'order': 1, 'page': 5}]

# %%
d[3]
# Out:
#                                         0   1   2   3   4  \
# 0                 Wissenschaftlicher Name  BE  ST  DE  GS
# 1        Raphidioptera – Kamelhalsfliegen
# 2          Raphidiidae – Kamelhalsfliegen
# 3          Dichrostigma flavipes (STEIN)*   0   -   V
# 4          Phaeostigma major (BURMEISTER)   3   2   3
# 5          Phaeostigma notata (FABRICIUS)   -   -   -
# 6             Puncha ratzeburgi (BRAUER)*   D   3   -
# 7             Raphidia ophiopsis LINNAEUS   -   -   -
# 8             Subilla confinis (STEPHENS)   3   -   G
# 9   Venustoraphidia nigricollis (ALBARDA)   3   -   V
# 10   Xanthostigma xanthostigma (SCHUMMEL)   -   -   -
# 11        Inocelliidae – Kamelhalsfliegen
# 12      Inocellia crassicornis (SCHUMMEL)   3   3   3
# 13              Megaloptera – Großflügler
# 14              Sialidae – Schlammfliegen
# 15             Sialis lutaria (LINNAEUS)*   -   -   -
# 16               Neuroptera – Netzflügler
# 17              Chrysopidae – Florfliegen
# 18             Chrysopa abbreviata CURTIS   3   3   V
# 19        Chrysopa commata KIS & UJHELYI*   -   -   D
#
#                       5                       6
# 0   Vorzugs- \nhabitate  Gefährdungs-\nursachen
# 1
# 2
# 3                 W, WK                  9, 12b
# 4                 W, WT                  9, 12b
# 5                  W, P
# 6                 W, WK
# 7                 W, WK
# 8          W, WT, B, BS                  9, 12b
# 9          W, WT, B, BS                  9, 12b
# 10                W, WT
# 11
# 12                W, WK                  9, 12b
# 13
# 14
# 15                    S
# 16
# 17
# 18               RR, AD                 8d, 12c
# 19               RS, GA

# %%
d[4]
# Out:
#                                                     0   1   2   3   4  \
# 0                             Wissenschaftlicher Name  BE  ST  DE  GS
# 1                        Chrysopa dorsalis BURMEISTER   -   3   -
# 2                             Chrysopa formosa BRAUER   -   -   V
# 3                       Chrysopa nigricostata BRAUER*   D   -   G
# 4                           Chrysopa pallens (RAMBUR)   -   -   -
# 5                           Chrysopa perla (LINNAEUS)   -   -   -
# 6                      Chrysopa phyllochroma WESMAEL*   -   -   -
# 7                         Chrysopa viridana SCHNEIDER   3   -   V
# 8                      Chrysoperla carnea (STEPHENS)*   -   -   -
# 9   Chrysoperla pallida HENRY, BROOKS, \nDUELLI & ...   D   -   -
# 10                     Chrysotropia ciliata (WESMAEL)   -   3   -
# 11              Cunctochrysa albolineata (KILLINGTON)   -   -   -
# 12                  Dichochrysa abdominalis (BRAUER)*   D   -   -
# 13                    Dichochrysa flavifrons (BRAUER)   -   -   -
# 14                  Dichochrysa prasina (BURMEISTER)*   -   -   -
# 15                     Dichochrysa ventralis (CURTIS)   -   -   -
# 16                             Nineta flava (SCOPOLI)   -   -   -
# 17                        Nineta inpunctata (REUTER)*   0   -   G
# 18                          Nineta vittata (WESMAEL)*   G   3   V
# 19                Peyerimhoffina gracilis (SCHNEIDER)   -   -   -
# 20                            Hemerobiidae – Taghafte
# 21                   Drepanepteryx algida (ERICHSON)*   D   -   V
# 22              Drepanepteryx phalaenoides (LINNAEUS)   -   -   -
# 23                     Hemerobius atrifrons MCLACHLAN   -   3   -
# 24                      Hemerobius humulinus LINNAEUS   -   -   -
# 25                     Hemerobius lutescens FABRICIUS   -   3   -
# 26                    Hemerobius marginatus STEPHENS*   3   3   V
# 27                          Hemerobius micans OLIVIER   -   -   -
# 28                     Hemerobius nitidulus FABRICIUS   -   -   -
# 29                           Hemerobius pini STEPHENS   -   -   -
# 30                         Hemerobius stigma STEPHENS   -   -   -
# 31                      Micromus angulatus (STEPHENS)   -   -   -
# 32                       Micromus paganus (LINNAEUS)*   D   -   V
# 33                    Micromus variegatus (FABRICIUS)   -   -   -
# 34                      Psectra diptera (BURMEISTER)*   G   -   3
# 35                    Sympherobius elegans (STEPHENS)   -   -   -
#
#                       5                       6
# 0   Vorzugs- \nhabitate  Gefährdungs-\nursachen
# 1                 W, WK                  9, 12b
# 2                  W, B
# 3                G?, W?
# 4                  W, P
# 5               W, B, P
# 6                RS, GA
# 7                 W, WT                  9, 12b
# 8               G, B, P
# 9                  W, B
# 10                 W, B
# 11              W, B, P
# 12               W, WNF
# 13              W, B, P
# 14              W, B, P
# 15                 W, B
# 16              W, B, P
# 17                W, WT                  9, 12b
# 18                 W, B                  9, 12b
# 19               W, WNF
# 20
# 21               W, WNL
# 22              W, B, P
# 23               W, WNL
# 24              W, B, P
# 25              W, B, P
# 26            B, BL, BF                  9, 12b
# 27              W, B, P
# 28                W, WK
# 29               W, WNF
# 30                W, WK
# 31                    G
# 32                    B
# 33                    G
# 34           G, GF, GSF                 5b, 12c
# 35                 W, B

# %%
d[5]
# Out:
#                                            0   1   2   3   4  \
# 0                    Wissenschaftlicher Name  BE  ST  DE  GS
# 1   Sympherobius fuscescens (WAL-\nLENGREN)*   0   -   V
# 2              Sympherobius klapaleki ZELENY   -   -   V
# 3          Sympherobius pellucidus (WALKER)*   D   0   V
# 4             Sympherobius pygmaeus (RAMBUR)   -   -   -
# 5            Wesmaelius concinnus (STEPHENS)   -   -   -
# 6             Wesmaelius mortoni (MCLACHLAN)   3   -   3
# 7            Wesmaelius nervosus (FABRICIUS)   -   -   -
# 8        Wesmaelius quadrifasciatus (REUTER)   -   -   -
# 9         Wesmaelius subnebulosus (STEPHENS)   -   -   -
# 10                Sisyridae – Schwammfliegen
# 11                   Sisyra nigra (RETZIUS)*   -   -   -
# 12              Coniopterygidae – Staubhafte
# 13                Aleuropteryx juniperi OHM*   D   -   3
# 14              Aleuropteryx loewii KLAPALEK   -   3   V
# 15               Coniopteryx borealis TJEDER   -   -   -
# 16         Coniopteryx esbenpeterseni TJEDER   -   -   -
# 17           Coniopteryx haematica MCLACHLAN   -   -   V
# 18            Coniopteryx pygmaea ENDERLEIN*   -   -   -
# 19            Coniopteryx tineiformis CURTIS   -   -   -
# 20           Conwentzia pineticola ENDERLEIN   -   -   -
# 21           Conwentzia psociformis (CURTIS)   -   -   -
# 22           Helicoconis lutea (WALLENGREN)*   D   3   V
# 23        Parasemidalis fuscipennis (REUTER)   -   -   V
# 24       Semidalis aleyrodiformis (STEPHENS)   -   -   -
# 25       Semidalis pseudouncinata MEINANDER*   D   -   -
# 26                   Mantispidae – Fanghafte
# 27                 Mantispa styriaca (PODA)*   0   0   0
# 28          Myrmeleontidae – Ameisenjungfern
# 29     Distoleon tetragrammicus (FABRICIUS)*   0   -   2   §
# 30               Euroleon nostras (FOURCROY)   -   -   V   §
# 31                   Myrmeleon bore (TJEDER)   3   2   3   §
# 32            Myrmeleon formicarius LINNAEUS   3   3   V   §
#
#                       5                       6
# 0   Vorzugs- \nhabitate  Gefährdungs-\nursachen
# 1                 W, WK                  9, 12b
# 2                 W, WT
# 3                     W
# 4                 W, WT
# 5                 W, WK
# 6                 W, WK                  9, 12b
# 7               W, B, P
# 8                W, WNL
# 9               W, B, P
# 10
# 11                 F, S
# 12
# 13                    P
# 14                W, WK
# 15                 W, B
# 16                 W, B
# 17                W, WT
# 18                 W, P
# 19              W, B, P
# 20                W, WK
# 21          W, WT, B, P
# 22               W, WNF
# 23                W, WK
# 24              W, B, P
# 25                    P
# 26
# 27    B, BLT, BFT, \nWT              2a, 9, 12b
# 28
# 29            W, WK, WT                  9, 12b
# 30            W, WK, WT
# 31               WK, AD              8d, 9, 12b
# 32            W, WK, WT                  9, 12b

# %% [markdown]
# # Data cleanup steps

# %% [raw]
# d[67]
#     : Look at the data frame extracted from 67th page
# d[67].shape
#     : Look at the shape of the dataframe
# d[68] = d[68].drop([12], axis=1)
#     : Drop the 12th column in place
# d[68][10] = d[68][[10, 11]].agg(' '.join, axis=1)
#     : Join 10th and 11th columns with a space in between
# d[69][[9,11]] = d[69][9].str.split('\n', expand=True)
#     : Split 9th Column at the '\n' sign and add a new column called 11
# column_to_move = d[69].pop(11)
# column_to_move
# d[69].insert(9, 11, column_to_move )
#     : Pop column 11 and insert it at column 9
# d[75].insert(9, '10', ["",""])
#     : Insert two rows of column 10 after 9 with empty cells

# %%
# Check whether all dataframes are of the same size
for key in d:
    print(key)
    print(d[key].shape)
# Out:
# 3
# (20, 7)
# 4
# (36, 7)
# 5
# (33, 7)

# %%
# Removing empty dataframes
# del d[64]
# del d[74]

# %%
# for each df from d[7] drop 0 and 1
i = 3
while i < 6:
    d[i] = d[i].drop([0], axis=0)
    print(d[i].shape)
    i = i + 1
# Out:
# (19, 7)
# (35, 7)
# (32, 7)

# %%
# Creates a sorted dictionary (sorted by key)
from collections import OrderedDict
d2 = OrderedDict(sorted(d.items()))

# %%
# Check whether the dictionary is sorted
for key in d2:
    print(key)
# Out:
# 3
# 4
# 5

# %%
# Rename all the dataframes in the sorted dictionary
for key in d2:
    print(key)
    d2[key].columns = [ "Wissenschaftlicher Name",
    "BE", 
    "ST", 
    "DE", 
    "GS",
    "Vorzugshabitate",
    "Gefährdungsursachen"]
print("Rename completed for concat")
# Out:
# 3
# 4
# 5
# Rename completed for concat

# %%
# Concatanate all the non-empty dataframes in the sorted dictionary into the empty df
for key in d2:
    df = pd.concat([df, d2[key]], axis = 0)
df
# Out:
#                   Wissenschaftlicher Name BE ST DE GS Vorzugshabitate  \
# 1        Raphidioptera – Kamelhalsfliegen
# 2          Raphidiidae – Kamelhalsfliegen
# 3          Dichrostigma flavipes (STEIN)*  0  -  V              W, WK
# 4          Phaeostigma major (BURMEISTER)  3  2  3              W, WT
# 5          Phaeostigma notata (FABRICIUS)  -  -  -               W, P
# ..                                    ... .. .. .. ..             ...
# 28       Myrmeleontidae – Ameisenjungfern
# 29  Distoleon tetragrammicus (FABRICIUS)*  0  -  2  §       W, WK, WT
# 30            Euroleon nostras (FOURCROY)  -  -  V  §       W, WK, WT
# 31                Myrmeleon bore (TJEDER)  3  2  3  §          WK, AD
# 32         Myrmeleon formicarius LINNAEUS  3  3  V  §       W, WK, WT
#
#    Gefährdungsursachen
# 1
# 2
# 3               9, 12b
# 4               9, 12b
# 5
# ..                 ...
# 28
# 29              9, 12b
# 30
# 31          8d, 9, 12b
# 32              9, 12b
#
# [86 rows x 7 columns]

# %%
df2 = df.loc[df["BE"] == "0"]
df2
# Out:
#                      Wissenschaftlicher Name BE ST DE GS    Vorzugshabitate  \
# 3             Dichrostigma flavipes (STEIN)*  0  -  V                 W, WK
# 17               Nineta inpunctata (REUTER)*  0  -  G                 W, WT
# 1   Sympherobius fuscescens (WAL-\nLENGREN)*  0  -  V                 W, WK
# 27                 Mantispa styriaca (PODA)*  0  0  0     B, BLT, BFT, \nWT
# 29     Distoleon tetragrammicus (FABRICIUS)*  0  -  2  §          W, WK, WT
#
#    Gefährdungsursachen
# 3               9, 12b
# 17              9, 12b
# 1               9, 12b
# 27          2a, 9, 12b
# 29              9, 12b

# %%
df2.describe()
# Out:
#                Wissenschaftlicher Name BE ST DE GS Vorzugshabitate  \
# count                                5  5  5  5  5               5
# unique                               5  1  2  4  2               4
# top     Dichrostigma flavipes (STEIN)*  0  -  V              W, WK
# freq                                 1  5  4  2  4               2
#
#        Gefährdungsursachen
# count                    5
# unique                   2
# top                 9, 12b
# freq                     4

# %%
df2.reset_index(inplace = True)
df2
# Out:
#    index                   Wissenschaftlicher Name BE ST DE GS  \
# 0      3            Dichrostigma flavipes (STEIN)*  0  -  V
# 1     17               Nineta inpunctata (REUTER)*  0  -  G
# 2      1  Sympherobius fuscescens (WAL-\nLENGREN)*  0  -  V
# 3     27                 Mantispa styriaca (PODA)*  0  0  0
# 4     29     Distoleon tetragrammicus (FABRICIUS)*  0  -  2  §
#
#      Vorzugshabitate Gefährdungsursachen
# 0              W, WK              9, 12b
# 1              W, WT              9, 12b
# 2              W, WK              9, 12b
# 3  B, BLT, BFT, \nWT          2a, 9, 12b
# 4          W, WK, WT              9, 12b

# %%
df2 = df2.drop(['index'], axis=1)
df2
# Out:
#                     Wissenschaftlicher Name BE ST DE GS    Vorzugshabitate  \
# 0            Dichrostigma flavipes (STEIN)*  0  -  V                 W, WK
# 1               Nineta inpunctata (REUTER)*  0  -  G                 W, WT
# 2  Sympherobius fuscescens (WAL-\nLENGREN)*  0  -  V                 W, WK
# 3                 Mantispa styriaca (PODA)*  0  0  0     B, BLT, BFT, \nWT
# 4     Distoleon tetragrammicus (FABRICIUS)*  0  -  2  §          W, WK, WT
#
#   Gefährdungsursachen
# 0              9, 12b
# 1              9, 12b
# 2              9, 12b
# 3          2a, 9, 12b
# 4              9, 12b

# %%
df2.describe()
# Out:
#                Wissenschaftlicher Name BE ST DE GS Vorzugshabitate  \
# count                                5  5  5  5  5               5
# unique                               5  1  2  4  2               4
# top     Dichrostigma flavipes (STEIN)*  0  -  V              W, WK
# freq                                 1  5  4  2  4               2
#
#        Gefährdungsursachen
# count                    5
# unique                   2
# top                 9, 12b
# freq                     4

# %%
df2
# Out:
#                     Wissenschaftlicher Name BE ST DE GS    Vorzugshabitate  \
# 0            Dichrostigma flavipes (STEIN)*  0  -  V                 W, WK
# 1               Nineta inpunctata (REUTER)*  0  -  G                 W, WT
# 2  Sympherobius fuscescens (WAL-\nLENGREN)*  0  -  V                 W, WK
# 3                 Mantispa styriaca (PODA)*  0  0  0     B, BLT, BFT, \nWT
# 4     Distoleon tetragrammicus (FABRICIUS)*  0  -  2  §          W, WK, WT
#
#   Gefährdungsursachen
# 0              9, 12b
# 1              9, 12b
# 2              9, 12b
# 3          2a, 9, 12b
# 4              9, 12b

# %%
# Updated export location
# export the dataframe as CSV
df2.to_csv('../../Transformation/Raw_csv/Raphidioptera_Megaloptera_Neuroptera.csv',
           index=False)
