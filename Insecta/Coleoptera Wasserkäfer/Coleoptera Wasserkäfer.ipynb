# %%
import camelot
import pandas as pd

# %% [markdown]
# # Updated Process

# %% [markdown]
# ## 1. Create empty dataframe with proper column names

# %%
# This is where data will be added after cleaning. The final dataframe for export

# %%
df = pd.DataFrame(columns = [
    "Species",
    "RL", 
    "Gefährdungsursachen", 
    "Letzter Nachweis in Berlin"
])
df
# Out:
# Empty DataFrame
# Columns: [Species, RL, Gefährdungsursachen, Letzter Nachweis in Berlin]
# Index: []

# %%
df.shape
# Out:
# (0, 4)

# %% [markdown]
# ## 2. Setup mechanism to store accuracy report : QA step

# %%
accuracy = []

# %% [markdown]
# ## 3. Dictionary of dataframes on the go

# %%
# Dictionary to collect dataframes created from each table
d = {}

# %% [markdown]
# ## 4. Adding the list of pages to be parsed

# %%
pages = []
i = 19
while i < 23:
    pages.append(i)
    i = i + 1
print(pages)
# Out:
# [19, 20, 21, 22]

# %% [markdown]
# ## 5. Parsing through the pages

# %%
for i in pages:
    # print page number
    print (i)
    # create dataframe with page number
    d[i] = pd.DataFrame()
    #read the page
    tables = camelot.read_pdf('rote_liste_wasserkaefer_hendrich_mueller.pdf', 
                              pages= str(i), 
                              flavor='stream', edge_tol=1000, row_tol=10)
    #tables = camelot.read_pdf('rote_liste_wasserkaefer_hendrich_mueller.pdf', pages= str(i), flavor='lattice')
    # add the accuracy report
    accuracy.append(tables[0].parsing_report)
    # assign the first table to a dataframe
    d[i] = tables[0].df
    print(d[i].shape)
# Print Done once all pages are parsed
print ("Done")
# Out:
# 19
# (28, 3)
# 20
# (45, 4)
# 21
# (45, 4)
# 22
# (45, 4)
# Done

# %%
tables = camelot.read_pdf('rote_liste_wasserkaefer_hendrich_mueller.pdf', 
                              pages= str(19), 
                              flavor='stream', edge_tol=1000, row_tol=10)
accuracy.append(tables[0].parsing_report)
d[19] = tables[1].df
print(d[19].shape)
# Out:
# (16, 4)

# %%
# Check accuracy reports for the process
accuracy
# Out:
# [{'accuracy': 68.9, 'whitespace': 47.62, 'order': 1, 'page': 19},
#  {'accuracy': 100.0, 'whitespace': 20.0, 'order': 1, 'page': 20},
#  {'accuracy': 100.0, 'whitespace': 18.33, 'order': 1, 'page': 21},
#  {'accuracy': 100.0, 'whitespace': 30.0, 'order': 1, 'page': 22},
#  {'accuracy': 68.9, 'whitespace': 47.62, 'order': 1, 'page': 19}]

# %% [markdown]
# # Data cleanup steps

# %% [raw]
# d[67]
#     : Look at the data frame extracted from 67th page
# d[67].shape
#     : Look at the shape of the dataframe
# d[68] = d[68].drop([12], axis=1)
#     : Drop the 12th column in place
# d[68][10] = d[68][[10, 11]].agg(' '.join, axis=1)
#     : Join 10th and 11th columns with a space in between
# d[69][[9,11]] = d[69][9].str.split('\n', expand=True)
#     : Split 9th Column at the '\n' sign and add a new column called 11
# column_to_move = d[69].pop(11)
# column_to_move
# d[69].insert(9, 11, column_to_move )
#     : Pop column 11 and insert it at column 9
# d[75].insert(9, '10', ["",""])
#     : Insert two rows of column 10 after 9 with empty cells

# %%
# Check whether all dataframes are of the same size
for key in d:
    print(key)
    print(d[key].shape)
# Out:
# 19
# (16, 4)
# 20
# (45, 4)
# 21
# (45, 4)
# 22
# (45, 4)

# %%
for key in d:
    d[key] = d[key].drop([0,1], axis=0)

# %%
for key in d:
    print(key)
    print(d[key].shape)
# Out:
# 19
# (14, 4)
# 20
# (43, 4)
# 21
# (43, 4)
# 22
# (43, 4)

# %%
d[19] = d[19].drop([2,3,4], axis=0)
d[19].head()
# Out:
#                    0  1         2  \
# 5        Hygrobiidae
# 6  Hygrobia hermanni  0         ?
# 7         Haliplidae
# 8  Brychius elevatus  0        5b
# 9  Haliplus confinis  3  12a, 14a
#
#                                                 3
# 5
# 6        Weißensee, ca. 1900, HORION (1941) (ZMB)
# 7
# 8           Tempelhof, ca. 1900, coll. Weiß (ZMB)
# 9  Zehlendorf, Teich am Teltowkanal im Forst Düp-

# %%
# Removing empty dataframes
# del d[64]
# del d[74]

# %%
# Creates a sorted dictionary (sorted by key)
from collections import OrderedDict
d2 = OrderedDict(sorted(d.items()))

# %%
# Check whether the dictionary is sorted
for key in d2:
    print(key)
# Out:
# 19
# 20
# 21
# 22

# %%
# Rename all the dataframes in the sorted dictionary
for key in d2:
    print(key)
    d2[key].columns = [
    "Species",
    "RL", 
    "Gefährdungsursachen", 
    "Letzter Nachweis in Berlin"]
print("Rename completed for concat")
# Out:
# 19
# 20
# 21
# 22
# Rename completed for concat

# %%
# Concatanate all the non-empty dataframes in the sorted dictionary into the empty df
for key in d2:
    df = pd.concat([df, d2[key]], axis = 0)
df
# Out:
#               Species RL Gefährdungsursachen  \
# 5         Hygrobiidae
# 6   Hygrobia hermanni  0                   ?
# 7          Haliplidae
# 8   Brychius elevatus  0                  5b
# 9   Haliplus confinis  3            12a, 14a
# ..                ... ..                 ...
# 40  Dryops anglicanus  2             2d, 11c
# 41     Dryops griseus  0             2d, 11c
# 42   Dryops nitidulus  0                   ?
# 43
# 44   Dryops similaris  0                  1a
#
#                           Letzter Nachweis in Berlin
# 5
# 6           Weißensee, ca. 1900, HORION (1941) (ZMB)
# 7
# 8              Tempelhof, ca. 1900, coll. Weiß (ZMB)
# 9     Zehlendorf, Teich am Teltowkanal im Forst Düp-
# ..                                               ...
# 40   Schmöckwitz, ND Langes Luch 2006, Hendrich leg.
# 41  Spandau, NSG Teufelsbruch, 1973, Korge leg. (CK)
# 42   Lichterfelde, US-Truppenübungsplatz, 1983, Hen-
# 43                                        drich leg.
# 44             Spandau, Elsgraben, 1921, leg. ? (CK)
#
# [140 rows x 4 columns]

# %%
# Definition of extinction
df2 = df.loc[df["RL"] == "0"]
df2.head()
# Out:
#               Species RL Gefährdungsursachen  \
# 6   Hygrobia hermanni  0                   ?
# 8   Brychius elevatus  0                  5b
# 12  Agabus biguttatus  0             5b, 11c
# 13   Agabus clypealis  0             2d, 11c
# 19    Agabus guttatus  0             5b, 11c
#
#                    Letzter Nachweis in Berlin
# 6    Weißensee, ca. 1900, HORION (1941) (ZMB)
# 8       Tempelhof, ca. 1900, coll. Weiß (ZMB)
# 12  Frohnau, Bieselfließ, 1996, Hendrich leg.
# 13     Dahlem, NSG Langes Luch, 1987, BH leg.
# 19  Frohnau, Bieselfließ, 1996, Hendrich leg.

# %%
df2.reset_index(inplace = True)
df2.head()
# Out:
#    index            Species RL Gefährdungsursachen  \
# 0      6  Hygrobia hermanni  0                   ?
# 1      8  Brychius elevatus  0                  5b
# 2     12  Agabus biguttatus  0             5b, 11c
# 3     13   Agabus clypealis  0             2d, 11c
# 4     19    Agabus guttatus  0             5b, 11c
#
#                   Letzter Nachweis in Berlin
# 0   Weißensee, ca. 1900, HORION (1941) (ZMB)
# 1      Tempelhof, ca. 1900, coll. Weiß (ZMB)
# 2  Frohnau, Bieselfließ, 1996, Hendrich leg.
# 3     Dahlem, NSG Langes Luch, 1987, BH leg.
# 4  Frohnau, Bieselfließ, 1996, Hendrich leg.

# %%
df2 = df2.drop(['index'], axis=1)
df2.head()
# Out:
#              Species RL Gefährdungsursachen  \
# 0  Hygrobia hermanni  0                   ?
# 1  Brychius elevatus  0                  5b
# 2  Agabus biguttatus  0             5b, 11c
# 3   Agabus clypealis  0             2d, 11c
# 4    Agabus guttatus  0             5b, 11c
#
#                   Letzter Nachweis in Berlin
# 0   Weißensee, ca. 1900, HORION (1941) (ZMB)
# 1      Tempelhof, ca. 1900, coll. Weiß (ZMB)
# 2  Frohnau, Bieselfließ, 1996, Hendrich leg.
# 3     Dahlem, NSG Langes Luch, 1987, BH leg.
# 4  Frohnau, Bieselfließ, 1996, Hendrich leg.

# %%
#df3 = df.loc[df["Bestand"] == "ex"]
#df3.reset_index(inplace = True)
#df3 = df3.drop(['index'], axis=1)
#df3.head()

# %%
df2.describe()
# Out:
#                   Species  RL Gefährdungsursachen  \
# count                  31  31                  31
# unique                 31   1                  13
# top     Hygrobia hermanni   0             2d, 11c
# freq                    1  31                  10
#
#                        Letzter Nachweis in Berlin
# count                                          31
# unique                                         29
# top     Frohnau, Bieselfließ, 1996, Hendrich leg.
# freq                                            2

# %%
df2
# Out:
#                      Species RL Gefährdungsursachen  \
# 0          Hygrobia hermanni  0                   ?
# 1          Brychius elevatus  0                  5b
# 2          Agabus biguttatus  0             5b, 11c
# 3           Agabus clypealis  0             2d, 11c
# 4            Agabus guttatus  0             5b, 11c
# 5            Agabus labiatus  0              1a, 5b
# 6          Agabus striolatus  0             2d, 11c
# 7        Dytiscus latissimus  0                 11c
# 8      Dytiscus semisulcatus  0              1a, 5b
# 9     Graphoderus bilineatus  0        5b, 11c, 12c
# 10       Graphoderus zonatus  0        5b, 11c, 12c
# 11    Hydroporus elongatulus  0        2d, 11c, 12c
# 12  Hydroporus glabriusculus  0             2d, 11c
# 13    Hydroporus gyllenhalii  0                  1a
# 14        Hydroporus notatus  0                  1a
# 15      Hydroporus rufifrons  0        2d, 11c, 12c
# 16         Ilybius aenescens  0             2d, 11c
# 17           Ilybius similis  0             2d, 11c
# 18      Rhantus notaticollis  0                 12c
# 19        Rhantus suturellus  0             2d, 11c
# 20      Suphrodytes dorsalis  0             2d, 11c
# 21        Gyrinus distinctus  0          3b, 5, 11c
# 22           Gyrinus marinus  0          3b, 5, 11c
# 23           Gyrinus minutus  0             2d, 11c
# 24           Gyrinus natator  0             2d, 11c
# 25     Hydrochus megaphallus  0                   ?
# 26   Helophorus tuberculatus  0          Ausbleiben
# 27    Stenelmis canaliculata  0             5a, 11c
# 28            Dryops griseus  0             2d, 11c
# 29          Dryops nitidulus  0                   ?
# 30          Dryops similaris  0                  1a
#
#                           Letzter Nachweis in Berlin
# 0           Weißensee, ca. 1900, HORION (1941) (ZMB)
# 1              Tempelhof, ca. 1900, coll. Weiß (ZMB)
# 2          Frohnau, Bieselfließ, 1996, Hendrich leg.
# 3             Dahlem, NSG Langes Luch, 1987, BH leg.
# 4          Frohnau, Bieselfließ, 1996, Hendrich leg.
# 5     Tegel, Jungfernheide, ca. 1900, coll. Schilsky
# 6     Reinickendorf, ehem. Hermsdorfer See, 1994, BH
# 7            Tegel, Tegeler See, 1949, Weinhold leg.
# 8                      Pankow, Buch, 1926, Beck leg.
# 9        Berlin 10.1.1905, Sammlung Zimmermann (ZSM)
# 10      Zehlendorf, Buschgraben, 2001, Hendrich leg.
# 11     Köpenick, Gosener Wiesen, 1996, Hendrich leg.
# 12   Spandau, NSG Großer u. Kleiner Rohrpfuhl, 1993,
# 13     Spandau, ca. 1920, Schöppa leg. (HORION 1941)
# 14             Karlshorst, 1913, Ahlwarth leg. (ZMB)
# 15             Wannsee, NSG Bäkewiese, 1995, BH leg.
# 16       Spandau, NSG Teufelsbruch, 1987, Schlarbaum
# 17      Grunewald, NSG Hundekehlefenn, 1990, BH leg.
# 18             Karlshorst, 1913, Ahlwarth leg. (ZMB)
# 19       Schmöckwitz, ND Langes Luch, 1995, Hendrich
# 20    Spandau, NSG Teufelsbruch, 1986, Hendrich leg.
# 21          Havelufer, Großes Fenster, 1989, BH leg.
# 22         Buch, Karower Teiche, 1996, Hendrich leg.
# 23       Reinickendorf, Tegeler Fließ, 1989, BH leg.
# 24  Grunewald, NSG Teufelsfenn, 1959, Fery leg. (CF)
# 25        Tegel, Jungfernheide, ca. 1920, Zumpt leg.
# 26                  Tiergarten, 1889, Habelmann leg.
# 27   Berlin, 10.8.1900, 2 Exemplare, Maas leg. (MNG)
# 28  Spandau, NSG Teufelsbruch, 1973, Korge leg. (CK)
# 29   Lichterfelde, US-Truppenübungsplatz, 1983, Hen-
# 30             Spandau, Elsgraben, 1921, leg. ? (CK)

# %%
#df3.describe()

# %%
# export the dataframe as CSV
df2.to_csv('../../Transformation/Raw_csv/Coleoptera_Wasserkäfer.csv', index=False)
