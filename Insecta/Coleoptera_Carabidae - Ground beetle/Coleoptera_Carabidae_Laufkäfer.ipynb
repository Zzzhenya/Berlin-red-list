# %%
import camelot
import pandas as pd

# %% [markdown]
# # Updated Process

# %% [markdown]
# ## 1. Create empty dataframe with proper column names

# %%
# This is where data will be added after cleaning. The final dataframe for export

# %%
df = pd.DataFrame(columns = [
    "Species",
    "BE", 
    "BB", 
    "DE", 
    "GS",
    "Häufigkeit",
    "Vorzugshabitate",
    "Gefährdungsursachen"
])
df
# Out:
# Empty DataFrame
# Columns: [Species, BE, BB, DE, GS, Häufigkeit, Vorzugshabitate, Gefährdungsursachen]
# Index: []

# %%
df.shape
# Out:
# (0, 8)

# %% [markdown]
# ## 2. Setup mechanism to store accuracy report : QA step

# %%
accuracy = []

# %% [markdown]
# ## 3. Dictionary of dataframes on the go

# %%
# Dictionary to collect dataframes created from each table
d = {}

# %% [markdown]
# ## 4. Adding the list of pages to be parsed

# %%
pages = []
i = 8
while i < 17:
    if i != 10 and i != 15:
        pages.append(i)
    i = i + 1
print(pages)
# Out:
# [8, 9, 11, 12, 13, 14, 16]

# %% [markdown]
# ## 5. Parsing through the pages

# %%
for i in pages:
    # print page number
    print (i)
    # create dataframe with page number
    d[i] = pd.DataFrame()
    #read the page
    #tables = camelot.read_pdf('18_netzfl_print.pdf', 
    #                          pages= str(i), 
    #                          flavor='stream', edge_tol=1000, row_tol=10)
    tables = camelot.read_pdf('19_laufkaefer_print.pdf', pages= str(i), flavor='lattice')
    # add the accuracy report
    accuracy.append(tables[0].parsing_report)
    # assign the first table to a dataframe
    d[i] = tables[0].df
    print(d[i].shape)
# Print Done once all pages are parsed
print ("Done")
# Out:
# 8
# (16, 8)
# 9
# (36, 8)
# 11
# (35, 8)
# 12
# (36, 8)
# 13
# (35, 8)
# 14
# (36, 8)
# 16
# (33, 8)
# Done

# %%
# Check accuracy reports for the process
accuracy
# Out:
# [{'accuracy': 99.35, 'whitespace': 20.31, 'order': 1, 'page': 8},
#  {'accuracy': 99.71, 'whitespace': 22.92, 'order': 1, 'page': 9},
#  {'accuracy': 99.71, 'whitespace': 21.79, 'order': 1, 'page': 11},
#  {'accuracy': 99.71, 'whitespace': 9.03, 'order': 1, 'page': 12},
#  {'accuracy': 99.71, 'whitespace': 20.0, 'order': 1, 'page': 13},
#  {'accuracy': 99.71, 'whitespace': 21.53, 'order': 1, 'page': 14},
#  {'accuracy': 99.69, 'whitespace': 21.59, 'order': 1, 'page': 16}]

# %%
# page 10

tables = camelot.read_pdf('19_laufkaefer_print.pdf', pages= str(10), flavor='lattice')
# add the accuracy report
accuracy.append(tables[0].parsing_report)
accuracy.append(tables[1].parsing_report)
df_10_1 = tables[0].df
df_10_2 = tables[1].df

# %%
df_10_1.head()
# Out:
#                                       0  1                    2  3 4     5  \
# 0               Wissenschaftlicher Name     BE BB DE GS Häufig-       keit
# 1             Amara plebeja (GYLLENHAL)  -                    -  -       h
# 2   Amara praetermissa (C. R. SAHLBERG)  -                    3  2      mh
# 3  Amara quenseli silvicola ZIMMERMANN*  1                    -  2      es
# 4            Amara similata (GYLLENHAL)  -                    -  -       h
#
#                     6                       7
# 0  Vorzugs-\nhabitate  Gefährdungs-\nursachen
# 1                  14
# 2                  11
# 3                  11            7a, 11b, 12a
# 4                  14

# %%
df_10_2.head()
# Out:
#                                  0  1  2  3 4   5  6           7
# 0  Badister dorsiger (DUFTSCHMID)*  2  1  3    ss  3  1c, 2d, 5c
# 1        Badister lacertosus STURM  -  -  -     h  6
# 2       Badister meridionalis PUEL  2  3  D    ss  3  1c, 2d, 5b
# 3       Badister peltatus (PANZER)  3  -  2     s  3  1c, 2d, 5b
# 4    Badister sodalis (DUFTSCHMID)  -  -  -     s  3

# %%
df_10_1.describe()
# Out:
#                               0   1   2   3   4   5   6   7
# count                        17  17  17  17  17  17  17  17
# unique                       17   4   5   6   1   6   8   5
# top     Wissenschaftlicher Name   -   -   -       h  14
# freq                          1  13  13   7  17   5   6  13

# %%
df_10_2.describe()
# Out:
#                                       0   1   2   3   4   5   6   7
# count                                18  18  18  18  18  18  18  18
# unique                               18   6   5   5   1   6   6   6
# top     Badister dorsiger (DUFTSCHMID)*   -   -   -       s   3
# freq                                  1  10  12   7  18   6  11  11

# %%
d[10] = pd.DataFrame()
d[10] = pd.concat([df_10_1, df_10_2], axis = 0)
d[10].describe()
# Out:
#                               0   1   2   3   4   5   6   7
# count                        35  35  35  35  35  35  35  35
# unique                       35   7   8   6   1   7  12  10
# top     Wissenschaftlicher Name   -   -   -       s   3
# freq                          1  23  25  14  35   9  15  24

# %%
d[10].head()
# Out:
#                                       0  1                    2  3 4     5  \
# 0               Wissenschaftlicher Name     BE BB DE GS Häufig-       keit
# 1             Amara plebeja (GYLLENHAL)  -                    -  -       h
# 2   Amara praetermissa (C. R. SAHLBERG)  -                    3  2      mh
# 3  Amara quenseli silvicola ZIMMERMANN*  1                    -  2      es
# 4            Amara similata (GYLLENHAL)  -                    -  -       h
#
#                     6                       7
# 0  Vorzugs-\nhabitate  Gefährdungs-\nursachen
# 1                  14
# 2                  11
# 3                  11            7a, 11b, 12a
# 4                  14

# %%
d[10].reset_index(inplace = True)
d[10].head()
# Out:
#    index                                     0  1                    2  3 4  \
# 0      0               Wissenschaftlicher Name     BE BB DE GS Häufig-
# 1      1             Amara plebeja (GYLLENHAL)  -                    -  -
# 2      2   Amara praetermissa (C. R. SAHLBERG)  -                    3  2
# 3      3  Amara quenseli silvicola ZIMMERMANN*  1                    -  2
# 4      4            Amara similata (GYLLENHAL)  -                    -  -
#
#       5                   6                       7
# 0  keit  Vorzugs-\nhabitate  Gefährdungs-\nursachen
# 1     h                  14
# 2    mh                  11
# 3    es                  11            7a, 11b, 12a
# 4     h                  14

# %%
d[10] = d[10].drop(['index'], axis=1)
d[10].head()
# Out:
#                                       0  1                    2  3 4     5  \
# 0               Wissenschaftlicher Name     BE BB DE GS Häufig-       keit
# 1             Amara plebeja (GYLLENHAL)  -                    -  -       h
# 2   Amara praetermissa (C. R. SAHLBERG)  -                    3  2      mh
# 3  Amara quenseli silvicola ZIMMERMANN*  1                    -  2      es
# 4            Amara similata (GYLLENHAL)  -                    -  -       h
#
#                     6                       7
# 0  Vorzugs-\nhabitate  Gefährdungs-\nursachen
# 1                  14
# 2                  11
# 3                  11            7a, 11b, 12a
# 4                  14

# %%
# page 15

tables = camelot.read_pdf('19_laufkaefer_print.pdf', pages= str(15), flavor='lattice')
# add the accuracy report
accuracy.append(tables[0].parsing_report)
accuracy.append(tables[1].parsing_report)
df_15_1 = tables[0].df
df_15_2 = tables[1].df

# %%
df_15_1.head()
# Out:
#                                         0  1                    2  3 4     5  \
# 0                 Wissenschaftlicher Name     BE BB DE GS Häufig-       keit
# 1      Notiophilus aesthuans MOTSCHULSKY*  R                    R  V      es
# 2        Notiophilus aquaticus (LINNAEUS)  -                    -  V      mh
# 3      Notiophilus biguttatus (FABRICIUS)  -                    -  -      sh
# 4  Notiophilus germinyi FAUVEL in GRENIER  2                    -  3      ss
#
#                     6                       7
# 0  Vorzugs-\nhabitate  Gefährdungs-\nursachen
# 1                (11)
# 2                  13
# 3                   8
# 4                  11            7a, 11b, 12a

# %%
df_15_2.head()
# Out:
#                                            0  1  2  3 4   5     6        7
# 0        Paratachys bistriatus (DUFTSCHMID)*  R  R  -    es   (1)
# 1  Paratachys micros (FISCHER VON WALDHEIM)*  0  0  2    ex  (1)?  1c, 12a
# 2               Patrobus assimilis CHAUDOIR*  1  2  2    es     2  2d, 11c
# 3                Patrobus atrorufus (STROEM)  -  -  -    mh     6
# 4             Patrobus australis J. SAHLBERG  3  3  2     s     6   1c, 2d

# %%
d[15] = pd.DataFrame()
d[15] = pd.concat([df_15_1, df_15_2], axis = 0)
d[15].describe()
# Out:
#                               0   1   2   3   4   5   6   7
# count                        35  35  35  35  35  35  35  35
# unique                       35   9   7   5   1   8  18  12
# top     Wissenschaftlicher Name   -   -   -       s   3
# freq                          1  18  24  17  35  11   5  21

# %%
d[15].head()
# Out:
#                                         0  1                    2  3 4     5  \
# 0                 Wissenschaftlicher Name     BE BB DE GS Häufig-       keit
# 1      Notiophilus aesthuans MOTSCHULSKY*  R                    R  V      es
# 2        Notiophilus aquaticus (LINNAEUS)  -                    -  V      mh
# 3      Notiophilus biguttatus (FABRICIUS)  -                    -  -      sh
# 4  Notiophilus germinyi FAUVEL in GRENIER  2                    -  3      ss
#
#                     6                       7
# 0  Vorzugs-\nhabitate  Gefährdungs-\nursachen
# 1                (11)
# 2                  13
# 3                   8
# 4                  11            7a, 11b, 12a

# %%
d[15].reset_index(inplace = True)
d[15].head()
# Out:
#    index                                       0  1                    2  3 4  \
# 0      0                 Wissenschaftlicher Name     BE BB DE GS Häufig-
# 1      1      Notiophilus aesthuans MOTSCHULSKY*  R                    R  V
# 2      2        Notiophilus aquaticus (LINNAEUS)  -                    -  V
# 3      3      Notiophilus biguttatus (FABRICIUS)  -                    -  -
# 4      4  Notiophilus germinyi FAUVEL in GRENIER  2                    -  3
#
#       5                   6                       7
# 0  keit  Vorzugs-\nhabitate  Gefährdungs-\nursachen
# 1    es                (11)
# 2    mh                  13
# 3    sh                   8
# 4    ss                  11            7a, 11b, 12a

# %%
d[15] = d[15].drop(['index'], axis=1)
d[15].head()
# Out:
#                                         0  1                    2  3 4     5  \
# 0                 Wissenschaftlicher Name     BE BB DE GS Häufig-       keit
# 1      Notiophilus aesthuans MOTSCHULSKY*  R                    R  V      es
# 2        Notiophilus aquaticus (LINNAEUS)  -                    -  V      mh
# 3      Notiophilus biguttatus (FABRICIUS)  -                    -  -      sh
# 4  Notiophilus germinyi FAUVEL in GRENIER  2                    -  3      ss
#
#                     6                       7
# 0  Vorzugs-\nhabitate  Gefährdungs-\nursachen
# 1                (11)
# 2                  13
# 3                   8
# 4                  11            7a, 11b, 12a

# %% [markdown]
# # Data cleanup steps

# %% [raw]
# d[67]
#     : Look at the data frame extracted from 67th page
# d[67].shape
#     : Look at the shape of the dataframe
# d[68] = d[68].drop([12], axis=1)
#     : Drop the 12th column in place
# d[68][10] = d[68][[10, 11]].agg(' '.join, axis=1)
#     : Join 10th and 11th columns with a space in between
# d[69][[9,11]] = d[69][9].str.split('\n', expand=True)
#     : Split 9th Column at the '\n' sign and add a new column called 11
# column_to_move = d[69].pop(11)
# column_to_move
# d[69].insert(9, 11, column_to_move )
#     : Pop column 11 and insert it at column 9
# d[75].insert(9, '10', ["",""])
#     : Insert two rows of column 10 after 9 with empty cells

# %%
# Check whether all dataframes are of the same size
for key in d:
    print(key)
    print(d[key].shape)
# Out:
# 8
# (16, 8)
# 9
# (36, 8)
# 11
# (35, 8)
# 12
# (36, 8)
# 13
# (35, 8)
# 14
# (36, 8)
# 16
# (33, 8)
# 10
# (35, 8)
# 15
# (35, 8)

# %%
# Removing empty dataframes
# del d[64]
# del d[74]

# %%
d[16]
# Out:
#                                             0  1                    2  3 4  \
# 0                     Wissenschaftlicher Name     BE BB DE GS Häufig-
# 1            Porotachys bisulcatus (NICOLAI)*  G                    D  -
# 2          Pterostichus anthracinus (ILLIGER)  -                    -  -
# 3             Pterostichus aterrimus (HERBST)  2                    2  2
# 4               Pterostichus diligens (STURM)  -                    -  V
# 5              Pterostichus gracilis (DEJEAN)  -                    -  3
# 6           Pterostichus melanarius (ILLIGER)  -                    -  -
# 7              Pterostichus minor (GYLLENHAL)  -                    -  -
# 8               Pterostichus niger (SCHALLER)  -                    -  -
# 9              Pterostichus nigrita (PAYKULL)  -                    -  -
# 10  Pterostichus oblongopunctatus (FABRICIUS)  -                    -  -
# 11             Pterostichus ovoideus (STURM)*  0                    R  -
# 12     Pterostichus quadrifoveolatus LETZNER*  G                    -  V
# 13                Pterostichus rhaeticus HEER  -                    -  -
# 14             Pterostichus strenuus (PANZER)  -                    -  -
# 15              Pterostichus taksonyis CSIKI*  0                    0  0
# 16             Pterostichus vernalis (PANZER)  -                    -  -
# 17         Sericoda quadripunctata (DE GEER)*  G                    D  2
# 18        Sphodrus leucophthalmus (LINNAEUS)*  0                    0  1
# 19                Stenolophus mixtus (HERBST)  -                    -  -
# 20       Stenolophus skrimshiranus (STEPHENS)  2                    -  2
# 21             Stenolophus teutonus (SCHRANK)  -                    -  -
# 22                  Stomis pumicatus (PANZER)  -                    -  -
# 23   Syntomus foveatus (GEOFFROY in FOURCROY)  -                    -  -
# 24           Syntomus truncatellus (LINNAEUS)  -                    -  -
# 25                 Synuchus vivalis (ILLIGER)  -                    -  -
# 26                  Tachyta nana (GYLLENHAL)*  -                    -  -
# 27               Trechoblemus micros (HERBST)  -                    -  -
# 28                  Trechus austriacus DEJEAN  2                    D  R
# 29                   Trechus obtusus ERICHSON  -                    -  -
# 30           Trechus quadristriatus (SCHRANK)  -                    -  -
# 31          Trichocellus placidus (GYLLENHAL)  -                    -  -
# 32               Zabrus tenebrioides (GOEZE)*  1                    -  -
#
#        5                   6                       7
# 0   keit  Vorzugs-\nhabitate  Gefährdungs-\nursachen
# 1     ss                  15                     12a
# 2     mh                   6
# 3     ss                   2                 2d, 11c
# 4      h                   2
# 5      s                   3
# 6     sh                   5
# 7      h                   2
# 8      h                   7
# 9     sh                   6
# 10     h                   8
# 11    ex               (13)?                       ?
# 12    ss                   8                     12b
# 13    mh                   2
# 14    sh                   7
# 15    ex                   4              1a, 5a, 6a
# 16    mh                   4
# 17    es                   8                     12b
# 18    ex                  15                      2c
# 19     h                   3
# 20    ss                   3              1a, 2d, 5b
# 21    mh                   1
# 22    mh                   4
# 23     h                  11
# 24    sh                  13
# 25     h                  13
# 26     s                   7
# 27     s              (4,13)
# 28    ss                  15                      2c
# 29     h                   7
# 30    mh                  14
# 31    mh                   6
# 32    es                  14                  1a, 7c

# %%
for key in d:
    d[key] = d[key].drop([0], axis=0)

# %%
for key in d:
    print(key)
    print(d[key].shape)
# Out:
# 8
# (15, 8)
# 9
# (35, 8)
# 11
# (34, 8)
# 12
# (35, 8)
# 13
# (34, 8)
# 14
# (35, 8)
# 16
# (32, 8)
# 10
# (34, 8)
# 15
# (34, 8)

# %%
# Creates a sorted dictionary (sorted by key)
from collections import OrderedDict
d2 = OrderedDict(sorted(d.items()))

# %%
# Check whether the dictionary is sorted
for key in d2:
    print(key)
# Out:
# 8
# 9
# 10
# 11
# 12
# 13
# 14
# 15
# 16

# %%
# Rename all the dataframes in the sorted dictionary
for key in d2:
    print(key)
    d2[key].columns = [ "Species",
    "BE", 
    "BB", 
    "DE", 
    "GS",
    "Häufigkeit",
    "Vorzugshabitate",
    "Gefährdungsursachen"]
print("Rename completed for concat")
# Out:
# 8
# 9
# 10
# 11
# 12
# 13
# 14
# 15
# 16
# Rename completed for concat

# %%
# Concatanate all the non-empty dataframes in the sorted dictionary into the empty df
for key in d2:
    df = pd.concat([df, d2[key]], axis = 0)
df
# Out:
#                                              Species BE BB DE GS Häufigkeit  \
# 1   Abax parallelepipedus (PILLER & MITTERPA-\nCHER)  2  -  -            es
# 2                          Acupalpus dubius SCHILSKY  -  -  V            mh
# 3                           Acupalpus exiguus DEJEAN  2  3  3            ss
# 4                      Acupalpus flavicollis (STURM)  -  -  -            mh
# 5                   Acupalpus luteatus (DUFTSCHMID)*  D  D  R            es
# ..                                               ... .. .. .. ..        ...
# 28                         Trechus austriacus DEJEAN  2  D  R            ss
# 29                          Trechus obtusus ERICHSON  -  -  -             h
# 30                  Trechus quadristriatus (SCHRANK)  -  -  -            mh
# 31                 Trichocellus placidus (GYLLENHAL)  -  -  -            mh
# 32                      Zabrus tenebrioides (GOEZE)*  1  -  -            es
#
#    Vorzugshabitate Gefährdungsursachen
# 1                7     2d, 3a, 9a, 12b
# 2                3
# 3                3          1a, 2d, 6a
# 4                3
# 5                3
# ..             ...                 ...
# 28              15                  2c
# 29               7
# 30              14
# 31               6
# 32              14              1a, 7c
#
# [288 rows x 8 columns]

# %%
# Definition of extinction
df2 = df.loc[df["BE"] == "0"]
df2.head()
# Out:
#                             Species BE BB DE GS Häufigkeit Vorzugshabitate  \
# 6     Acupalpus maculatus (SCHAUM)*  0  2  3            ex            (1)?
# 13  Agonum gracilipes (DUFTSCHMID)*  0  1  D            ex             (7)
# 14    Agonum hypocrita (APFELBECK)*  0  1  1            ex               2
# 15       Agonum impressum (PANZER)*  0  1  1            ex               1
# 24       Amara famelica ZIMMERMANN*  0  R  2            ex           (14)?
#
#    Gefährdungsursachen
# 6              1c, 12a
# 13                   ?
# 14             2d, 11c
# 15         3a, 5a, 12c
# 24                   ?

# %%
df2.reset_index(inplace = True)
df2.head()
# Out:
#    index                          Species BE BB DE GS Häufigkeit  \
# 0      6    Acupalpus maculatus (SCHAUM)*  0  2  3            ex
# 1     13  Agonum gracilipes (DUFTSCHMID)*  0  1  D            ex
# 2     14    Agonum hypocrita (APFELBECK)*  0  1  1            ex
# 3     15       Agonum impressum (PANZER)*  0  1  1            ex
# 4     24       Amara famelica ZIMMERMANN*  0  R  2            ex
#
#   Vorzugshabitate Gefährdungsursachen
# 0            (1)?             1c, 12a
# 1             (7)                   ?
# 2               2             2d, 11c
# 3               1         3a, 5a, 12c
# 4           (14)?                   ?

# %%
df2 = df2.drop(['index'], axis=1)
df2.head()
# Out:
#                            Species BE BB DE GS Häufigkeit Vorzugshabitate  \
# 0    Acupalpus maculatus (SCHAUM)*  0  2  3            ex            (1)?
# 1  Agonum gracilipes (DUFTSCHMID)*  0  1  D            ex             (7)
# 2    Agonum hypocrita (APFELBECK)*  0  1  1            ex               2
# 3       Agonum impressum (PANZER)*  0  1  1            ex               1
# 4       Amara famelica ZIMMERMANN*  0  R  2            ex           (14)?
#
#   Gefährdungsursachen
# 0             1c, 12a
# 1                   ?
# 2             2d, 11c
# 3         3a, 5a, 12c
# 4                   ?

# %%
df3 = df.loc[df["Häufigkeit"] == "ex"]
df3.reset_index(inplace = True)
df3 = df3.drop(['index'], axis=1)
df3.head()
# Out:
#                            Species BE BB DE GS Häufigkeit Vorzugshabitate  \
# 0    Acupalpus maculatus (SCHAUM)*  0  2  3            ex            (1)?
# 1  Agonum gracilipes (DUFTSCHMID)*  0  1  D            ex             (7)
# 2    Agonum hypocrita (APFELBECK)*  0  1  1            ex               2
# 3       Agonum impressum (PANZER)*  0  1  1            ex               1
# 4       Amara famelica ZIMMERMANN*  0  R  2            ex           (14)?
#
#   Gefährdungsursachen
# 0             1c, 12a
# 1                   ?
# 2             2d, 11c
# 3         3a, 5a, 12c
# 4                   ?

# %%
df2.describe()
# Out:
#                               Species  BE  BB  DE  GS Häufigkeit  \
# count                              34  34  34  34  34         34
# unique                             34   1   4   7   3          1
# top     Acupalpus maculatus (SCHAUM)*   0   1   2             ex
# freq                                1  34  11  11  25         34
#
#        Vorzugshabitate Gefährdungsursachen
# count               34                  34
# unique              18                  17
# top                  1                   ?
# freq                 9                   7

# %%
df3.describe()
# Out:
#                               Species  BE  BB  DE  GS Häufigkeit  \
# count                              34  34  34  34  34         34
# unique                             34   1   4   7   3          1
# top     Acupalpus maculatus (SCHAUM)*   0   1   2             ex
# freq                                1  34  11  11  25         34
#
#        Vorzugshabitate Gefährdungsursachen
# count               34                  34
# unique              18                  17
# top                  1                   ?
# freq                 9                   7

# %%
df2
# Out:
#                                       Species BE BB DE  GS Häufigkeit  \
# 0               Acupalpus maculatus (SCHAUM)*  0  2  3             ex
# 1             Agonum gracilipes (DUFTSCHMID)*  0  1  D             ex
# 2               Agonum hypocrita (APFELBECK)*  0  1  1             ex
# 3                  Agonum impressum (PANZER)*  0  1  1             ex
# 4                  Amara famelica ZIMMERMANN*  0  R  2             ex
# 5     Anisodactylus nemorivagus (DUFTSCHMID)*  0  0  2             ex
# 6                   Bembidion humerale STURM*  0  1  2             ex
# 7              Bembidion punctulatum DRAPIEZ*  0  1  V             ex
# 8          Bembidion semipunctatum (DONOVAN)*  0  2  -             ex
# 9             Bembidion striatum (FABRICIUS)*  0  0  1             ex
# 10                Bembidion velox (LINNAEUS)*  0  R  2             ex
# 11      Callisthenes reticulatus (FABRICIUS)*  0  1  1  §§         ex
# 12            Calosoma sycophanta (LINNAEUS)*  0  1  2   §         ex
# 13               Carabus cancellatus ILLIGER*  0  2  V   §         ex
# 14                Carabus clatratus LINNAEUS*  0  2  2   §         ex
# 15                 Carabus glabratus PAYKULL*  0  2  -   §         ex
# 16               Carabus intricatus LINNAEUS*  0  R  3   §         ex
# 17                   Carabus nitens LINNAEUS*  0  1  2   §         ex
# 18              Carabus problematicus HERBST*  0  R  -   §         ex
# 19        Chlaenius costulatus (MOTSCHULSKY)*  0  0  1             ex
# 20             Chlaenius nitidulus (SCHRANK)*  0  R  3             ex
# 21           Chlaenius sulcicollis (PAYKULL)*  0  0  0             ex
# 22   Cylindera arenaria viennensis (SCHRANK)*  0  1  1  §§         ex
# 23              Dolichus halensis (SCHALLER)*  0  R  2             ex
# 24              Dyschirius chalceus ERICHSON*  0  0  1             ex
# 25            Dyschirius neresheimeri WAGNER*  0  1  1             ex
# 26               Dyschirius nitidus (DEJEAN)*  0  0  2             ex
# 27           Dyschirius obscurus (GYLLENHAL)*  0  1  -             ex
# 28              Elaphropus parvulus (DEJEAN)*  0  R  -             ex
# 29      Limodromus longiventris (MANNERHEIM)*  0  2  2             ex
# 30  Paratachys micros (FISCHER VON WALDHEIM)*  0  0  2             ex
# 31             Pterostichus ovoideus (STURM)*  0  R  -             ex
# 32              Pterostichus taksonyis CSIKI*  0  0  0             ex
# 33        Sphodrus leucophthalmus (LINNAEUS)*  0  0  1             ex
#
#    Vorzugshabitate Gefährdungsursachen
# 0             (1)?             1c, 12a
# 1              (7)                   ?
# 2                2             2d, 11c
# 3                1         3a, 5a, 12c
# 4            (14)?                   ?
# 5         (10,14)?                   ?
# 6                2             2d, 11c
# 7                1         3a, 5a, 12c
# 8                1         3a, 5a, 12c
# 9                1         3a, 5a, 12c
# 10               1         3a, 5a, 12c
# 11              10              7d, 8e
# 12               7                  9a
# 13         (7,14)?                   ?
# 14               4          1a, 5a, 6a
# 15               7         2d, 9a, 12b
# 16               8                   ?
# 17         (8,10)?                 7d?
# 18               8                   ?
# 19               3          1a, 2d, 5b
# 20             (1)             1c, 12a
# 21               3          3a, 5a, 5b
# 22               1         1c, 3a, 12a
# 23              13                 12a
# 24             (1)             1c, 12a
# 25               1             3a, 12c
# 26               1              1c, 3a
# 27               1              1c, 3a
# 28              12             1a, 12a
# 29               4          1a, 5a, 6a
# 30            (1)?             1c, 12a
# 31           (13)?                   ?
# 32               4          1a, 5a, 6a
# 33              15                  2c

# %%
# export the dataframe as CSV- without dates
#df2.to_csv('Coleoptera_Carabidae_Laufkäfer.csv', index=False)

# Updated the export location

# export the dataframe as CSV
df2.to_csv(
    '../../Transformation/Raw_csv/Coleoptera_Carabidae_Laufkäfer.csv', 
    index=False
)

# %% [markdown]
# # Second table

# %%
# Dictionary to collect dataframes created from each table
e = {}

# %%
accuracy_2 = []

# %%
pages_2 = []
i = 25
while i < 28:
    pages_2.append(i)
    i = i + 1
print(pages_2)
# Out:
# [25, 26, 27]

# %%
for i in pages_2:
    print (i)
    # create dataframe with page number
    e[i] = pd.DataFrame()
    #read the page
    tables = camelot.read_pdf('19_laufkaefer_print.pdf', pages= str(i), flavor='lattice')
    # add the accuracy report
    accuracy_2.append(tables[0].parsing_report)
    # assign the first table to a dataframe
    e[i] = tables[0].df
    print(e[i].shape)
# Print Done once all pages are parsed
print ("Done")
# Out:
# 25
# (8, 2)
# 26
# (29, 2)
# 27
# (8, 2)
# Done

# %%
e[25] = e[25].drop([0], axis=0)
e[25]
# Out:
#                               0  \
# 1  Abax carinatus (DUFTSCHMID)*
# 2     Abax ovalis (DUFTSCHMID)*
# 3   Acupalpus brunnipes (STURM)
# 4    Agonum duftschmidi SCHMIDT
# 5        Agonum scitulum DEJEAN
# 6  Agonum viridicupreum (GOEZE)
# 7        Amara montivaga STURM*
#
#                                                    1
# 1    Steglitz 1909, 1 Expl., leg. Hedicke, coll. ZMB
# 2  KORGE (1960): Grunewald 1958, 1 Expl., leg. D....
# 3  Berlin, o. D. (um 1900), 5 Expl. coll. DEI, 1 ...
# 4  Umgebung Berlin, 6 Expl., u. a. coll. Kraatz u...
# 5  Umgebung Berlin, 4 Expl., coll. Germar-Schaum ...
# 6  Umgebung Berlin, 1 Expl., coll. Kraatz in coll...
# 7  Berlin Schüppel, 1 Expl., coll. Kraatz in coll...

# %%
e[26] = e[26].drop([0], axis=0)
e[26]
# Out:
#                                                     0  \
# 1                                 Amara nitida STURM*
# 2                            Amara pseudostrenua KULT
# 3                           Amara strenua ZIMMERMANN*
# 4                    Bembidion decoratum (DUFTSCHMID)
# 5                     Bembidion modestum (FABRICIUS)*
# 6                        Bembidion tenellum ERICHSON*
# 7                     Brachinus crepitans (LINNAEUS)*
# 8                      Brachinus explodens DUFTSCHMID
# 9                      Callistus lunatus (FABRICIUS)*
# 10        Carabus violaceus purpurascens  \nFABRICIUS
# 11                         Carabus scheidleri PANZER*
# 12                Chlaenius quadrisulcatus (Paykull)*
# 13                      Cylindera germanica LINNAEUS*
# 14                  Demetrias atricapillus (LINNAEUS)
# 15                    Dicheirotrichus gustavii CROTCH
# 16                 Dicheirotrichus obsoletus (DEJEAN)
# 17                    Dromius fenestratus (FABRICIUS)
# 18                  Dyschirius impunctipennis DAWSON*
# 19  Elaphropus quadrisignatus (DUFTSCHMID) Berlin,...
# 20                          Elaphrus aureus P. MÜLLER
# 21                    Harpalus dimidiatus (P. ROSSI)*
# 22                     Harpalus subcylindricus DEJEAN
# 23                      Lebia cyanocephala (LINNAEUS)
# 24                       Limodromus krynickii (SPERK)
# 25                       Miscodera arctica (PAYKULL)*
# 26                          Nebria livida (LINNAEUS)*
# 27              Nebria salina FAIRMAIRE & LABOULBÈNE*
# 28                Notiophilus quadripunctatus DEJEAN*
#
#                                                     1
# 1   Berlin, o. D. (um 1900), je 1 Expl. coll. DEI ...
# 2   Berlin, o. D. (um 1900), 1 Expl., coll. DEI, d...
# 3                       MÜLLER (1907): Tegel, 2 Expl.
# 4   KORGE (1973): Tiefwerder 1966, 1 Expl., leg. W...
# 5   HORION (1941): Nach Quedenfeldt 1886: Umgebung...
# 6   GRIEP & KORGE (1956): Lankwitz 1951, 1 Expl., ...
# 7   KORGE (1960): Spandauer Forst Jg. 35, 1 Expl.,...
# 8         Berlin, o. D. (um 1900), 1 Expl., coll. ZMB
# 9   Tegel 6.1947, leg. E. Weinhold, 1 Expl., coll....
# 10  Umgebung Berlin, leg. Dr. Zuelchaur, o. D., 2 ...
# 11            KUNTZEN (1915): Treptower Park, 1 Expl.
# 12       Berlin, o. D. (vor 1900), 7 Expl., coll. ZMB
# 13  Tegel 10.6.1947, leg. E. Weinhold, 1 Expl., co...
# 14        Berlin, o. D. (um 1900), 1 Expl., coll. ZMB
# 15  „Tierpark Berlin“ 13.6.1941, 1 Expl., coll. D....
# 16        Berlin, o. D. (um 1900), 1 Expl., coll. DEI
# 17  SCHULZE (1918): Niederschönhausen, 1 Expl., le...
# 18  HORION (1941): Niederschönhausen, mehrfach, co...
# 19
# 20                 Berlin, o. D. (um 1900), coll. ZMB
# 21     SCHULZE (1918): Rehberge, leg. Wendeler 4.1912
# 22  Berlin, o. D. (um 1900), 1 Expl., coll. ZMB ex...
# 23        Berlin, o. D. (um 1900), 2 Expl., coll. ZMB
# 24  Berlin und Umgebung Berlin, o. D. (um 1900), z...
# 25  WRASE (1995): Forst Düppel 1995, 1 Expl., leg....
# 26  Malchow 1976, 1 Expl., leg. Rössel, coll. Kiel...
# 27                  HUBENTHAL (1919): Berlin, 1 Expl.
# 28  SCHULZE (1916): Spandau 9.1911 und Siemensstad...

# %%
e[27] = e[27].drop([0], axis=0)
e[27]
# Out:
#                                    0  \
# 1        Ophonus azureus (FABRICIUS)
# 2     Ophonus cordatus (DUFTSCHMID)*
# 3           Ophonus rupicola (STURM)
# 4     Ophonus schaubergerianus PUEL*
# 5    Perileptus areolatus (CREUTZER)
# 6     Pterostichus aethiops (PANZER)
# 7  Trichocellus cognatus (GYLLENHAL)
#
#                                                    1
# 1  WRASE (1995) führt irrtümlich Berliner Funde a...
# 2  Spandauer Stadtforst, ca. 1900, 1 Expl., leg. ...
# 3  Fundortangabe „Berl (?)“, o. D., 2 Expl., coll...
# 4  BARNDT et al. (2002): Gatow 1969, 1 Expl., leg...
# 5        Umgebung Berlin, o. D., 12 Expl., coll. DEI
# 6  KORGE (1958): Humboldthain 1957, 1 Expl., leg....
# 7        Berlin, o. D. (um 1900), 2 Expl., coll. DEI

# %%
df_dates = pd.DataFrame(columns = [
    "Species",
    "Fundangaben"
])
df_dates
# Out:
# Empty DataFrame
# Columns: [Species, Fundangaben]
# Index: []

# %%
for key in e:
    print(key)
    e[key].columns = ["Species",
    "Fundangaben"]
print("Rename completed for concat")
# Out:
# 25
# 26
# 27
# Rename completed for concat

# %%
for key in e:
    df_dates = pd.concat([df_dates, e[key]], axis = 0)
df_dates
# Out:
#                                               Species  \
# 1                        Abax carinatus (DUFTSCHMID)*
# 2                           Abax ovalis (DUFTSCHMID)*
# 3                         Acupalpus brunnipes (STURM)
# 4                          Agonum duftschmidi SCHMIDT
# 5                              Agonum scitulum DEJEAN
# 6                        Agonum viridicupreum (GOEZE)
# 7                              Amara montivaga STURM*
# 1                                 Amara nitida STURM*
# 2                            Amara pseudostrenua KULT
# 3                           Amara strenua ZIMMERMANN*
# 4                    Bembidion decoratum (DUFTSCHMID)
# 5                     Bembidion modestum (FABRICIUS)*
# 6                        Bembidion tenellum ERICHSON*
# 7                     Brachinus crepitans (LINNAEUS)*
# 8                      Brachinus explodens DUFTSCHMID
# 9                      Callistus lunatus (FABRICIUS)*
# 10        Carabus violaceus purpurascens  \nFABRICIUS
# 11                         Carabus scheidleri PANZER*
# 12                Chlaenius quadrisulcatus (Paykull)*
# 13                      Cylindera germanica LINNAEUS*
# 14                  Demetrias atricapillus (LINNAEUS)
# 15                    Dicheirotrichus gustavii CROTCH
# 16                 Dicheirotrichus obsoletus (DEJEAN)
# 17                    Dromius fenestratus (FABRICIUS)
# 18                  Dyschirius impunctipennis DAWSON*
# 19  Elaphropus quadrisignatus (DUFTSCHMID) Berlin,...
# 20                          Elaphrus aureus P. MÜLLER
# 21                    Harpalus dimidiatus (P. ROSSI)*
# 22                     Harpalus subcylindricus DEJEAN
# 23                      Lebia cyanocephala (LINNAEUS)
# 24                       Limodromus krynickii (SPERK)
# 25                       Miscodera arctica (PAYKULL)*
# 26                          Nebria livida (LINNAEUS)*
# 27              Nebria salina FAIRMAIRE & LABOULBÈNE*
# 28                Notiophilus quadripunctatus DEJEAN*
# 1                         Ophonus azureus (FABRICIUS)
# 2                      Ophonus cordatus (DUFTSCHMID)*
# 3                            Ophonus rupicola (STURM)
# 4                      Ophonus schaubergerianus PUEL*
# 5                     Perileptus areolatus (CREUTZER)
# 6                      Pterostichus aethiops (PANZER)
# 7                   Trichocellus cognatus (GYLLENHAL)
#
#                                           Fundangaben
# 1     Steglitz 1909, 1 Expl., leg. Hedicke, coll. ZMB
# 2   KORGE (1960): Grunewald 1958, 1 Expl., leg. D....
# 3   Berlin, o. D. (um 1900), 5 Expl. coll. DEI, 1 ...
# 4   Umgebung Berlin, 6 Expl., u. a. coll. Kraatz u...
# 5   Umgebung Berlin, 4 Expl., coll. Germar-Schaum ...
# 6   Umgebung Berlin, 1 Expl., coll. Kraatz in coll...
# 7   Berlin Schüppel, 1 Expl., coll. Kraatz in coll...
# 1   Berlin, o. D. (um 1900), je 1 Expl. coll. DEI ...
# 2   Berlin, o. D. (um 1900), 1 Expl., coll. DEI, d...
# 3                       MÜLLER (1907): Tegel, 2 Expl.
# 4   KORGE (1973): Tiefwerder 1966, 1 Expl., leg. W...
# 5   HORION (1941): Nach Quedenfeldt 1886: Umgebung...
# 6   GRIEP & KORGE (1956): Lankwitz 1951, 1 Expl., ...
# 7   KORGE (1960): Spandauer Forst Jg. 35, 1 Expl.,...
# 8         Berlin, o. D. (um 1900), 1 Expl., coll. ZMB
# 9   Tegel 6.1947, leg. E. Weinhold, 1 Expl., coll....
# 10  Umgebung Berlin, leg. Dr. Zuelchaur, o. D., 2 ...
# 11            KUNTZEN (1915): Treptower Park, 1 Expl.
# 12       Berlin, o. D. (vor 1900), 7 Expl., coll. ZMB
# 13  Tegel 10.6.1947, leg. E. Weinhold, 1 Expl., co...
# 14        Berlin, o. D. (um 1900), 1 Expl., coll. ZMB
# 15  „Tierpark Berlin“ 13.6.1941, 1 Expl., coll. D....
# 16        Berlin, o. D. (um 1900), 1 Expl., coll. DEI
# 17  SCHULZE (1918): Niederschönhausen, 1 Expl., le...
# 18  HORION (1941): Niederschönhausen, mehrfach, co...
# 19
# 20                 Berlin, o. D. (um 1900), coll. ZMB
# 21     SCHULZE (1918): Rehberge, leg. Wendeler 4.1912
# 22  Berlin, o. D. (um 1900), 1 Expl., coll. ZMB ex...
# 23        Berlin, o. D. (um 1900), 2 Expl., coll. ZMB
# 24  Berlin und Umgebung Berlin, o. D. (um 1900), z...
# 25  WRASE (1995): Forst Düppel 1995, 1 Expl., leg....
# 26  Malchow 1976, 1 Expl., leg. Rössel, coll. Kiel...
# 27                  HUBENTHAL (1919): Berlin, 1 Expl.
# 28  SCHULZE (1916): Spandau 9.1911 und Siemensstad...
# 1   WRASE (1995) führt irrtümlich Berliner Funde a...
# 2   Spandauer Stadtforst, ca. 1900, 1 Expl., leg. ...
# 3   Fundortangabe „Berl (?)“, o. D., 2 Expl., coll...
# 4   BARNDT et al. (2002): Gatow 1969, 1 Expl., leg...
# 5         Umgebung Berlin, o. D., 12 Expl., coll. DEI
# 6   KORGE (1958): Humboldthain 1957, 1 Expl., leg....
# 7         Berlin, o. D. (um 1900), 2 Expl., coll. DEI

# %%
df_dates.reset_index(inplace = True)
df_dates = df_dates.drop(['index'], axis=1)
df_dates.head()
# Out:
#                         Species  \
# 0  Abax carinatus (DUFTSCHMID)*
# 1     Abax ovalis (DUFTSCHMID)*
# 2   Acupalpus brunnipes (STURM)
# 3    Agonum duftschmidi SCHMIDT
# 4        Agonum scitulum DEJEAN
#
#                                          Fundangaben
# 0    Steglitz 1909, 1 Expl., leg. Hedicke, coll. ZMB
# 1  KORGE (1960): Grunewald 1958, 1 Expl., leg. D....
# 2  Berlin, o. D. (um 1900), 5 Expl. coll. DEI, 1 ...
# 3  Umgebung Berlin, 6 Expl., u. a. coll. Kraatz u...
# 4  Umgebung Berlin, 4 Expl., coll. Germar-Schaum ...

# %%
df_dates.describe()
# Out:
#                              Species  \
# count                             42
# unique                            42
# top     Abax carinatus (DUFTSCHMID)*
# freq                               1
#
#                                         Fundangaben
# count                                            42
# unique                                           41
# top     Berlin, o. D. (um 1900), 1 Expl., coll. ZMB
# freq                                              2

# %%
df_dates
# Out:
#                                               Species  \
# 0                        Abax carinatus (DUFTSCHMID)*
# 1                           Abax ovalis (DUFTSCHMID)*
# 2                         Acupalpus brunnipes (STURM)
# 3                          Agonum duftschmidi SCHMIDT
# 4                              Agonum scitulum DEJEAN
# 5                        Agonum viridicupreum (GOEZE)
# 6                              Amara montivaga STURM*
# 7                                 Amara nitida STURM*
# 8                            Amara pseudostrenua KULT
# 9                           Amara strenua ZIMMERMANN*
# 10                   Bembidion decoratum (DUFTSCHMID)
# 11                    Bembidion modestum (FABRICIUS)*
# 12                       Bembidion tenellum ERICHSON*
# 13                    Brachinus crepitans (LINNAEUS)*
# 14                     Brachinus explodens DUFTSCHMID
# 15                     Callistus lunatus (FABRICIUS)*
# 16        Carabus violaceus purpurascens  \nFABRICIUS
# 17                         Carabus scheidleri PANZER*
# 18                Chlaenius quadrisulcatus (Paykull)*
# 19                      Cylindera germanica LINNAEUS*
# 20                  Demetrias atricapillus (LINNAEUS)
# 21                    Dicheirotrichus gustavii CROTCH
# 22                 Dicheirotrichus obsoletus (DEJEAN)
# 23                    Dromius fenestratus (FABRICIUS)
# 24                  Dyschirius impunctipennis DAWSON*
# 25  Elaphropus quadrisignatus (DUFTSCHMID) Berlin,...
# 26                          Elaphrus aureus P. MÜLLER
# 27                    Harpalus dimidiatus (P. ROSSI)*
# 28                     Harpalus subcylindricus DEJEAN
# 29                      Lebia cyanocephala (LINNAEUS)
# 30                       Limodromus krynickii (SPERK)
# 31                       Miscodera arctica (PAYKULL)*
# 32                          Nebria livida (LINNAEUS)*
# 33              Nebria salina FAIRMAIRE & LABOULBÈNE*
# 34                Notiophilus quadripunctatus DEJEAN*
# 35                        Ophonus azureus (FABRICIUS)
# 36                     Ophonus cordatus (DUFTSCHMID)*
# 37                           Ophonus rupicola (STURM)
# 38                     Ophonus schaubergerianus PUEL*
# 39                    Perileptus areolatus (CREUTZER)
# 40                     Pterostichus aethiops (PANZER)
# 41                  Trichocellus cognatus (GYLLENHAL)
#
#                                           Fundangaben
# 0     Steglitz 1909, 1 Expl., leg. Hedicke, coll. ZMB
# 1   KORGE (1960): Grunewald 1958, 1 Expl., leg. D....
# 2   Berlin, o. D. (um 1900), 5 Expl. coll. DEI, 1 ...
# 3   Umgebung Berlin, 6 Expl., u. a. coll. Kraatz u...
# 4   Umgebung Berlin, 4 Expl., coll. Germar-Schaum ...
# 5   Umgebung Berlin, 1 Expl., coll. Kraatz in coll...
# 6   Berlin Schüppel, 1 Expl., coll. Kraatz in coll...
# 7   Berlin, o. D. (um 1900), je 1 Expl. coll. DEI ...
# 8   Berlin, o. D. (um 1900), 1 Expl., coll. DEI, d...
# 9                       MÜLLER (1907): Tegel, 2 Expl.
# 10  KORGE (1973): Tiefwerder 1966, 1 Expl., leg. W...
# 11  HORION (1941): Nach Quedenfeldt 1886: Umgebung...
# 12  GRIEP & KORGE (1956): Lankwitz 1951, 1 Expl., ...
# 13  KORGE (1960): Spandauer Forst Jg. 35, 1 Expl.,...
# 14        Berlin, o. D. (um 1900), 1 Expl., coll. ZMB
# 15  Tegel 6.1947, leg. E. Weinhold, 1 Expl., coll....
# 16  Umgebung Berlin, leg. Dr. Zuelchaur, o. D., 2 ...
# 17            KUNTZEN (1915): Treptower Park, 1 Expl.
# 18       Berlin, o. D. (vor 1900), 7 Expl., coll. ZMB
# 19  Tegel 10.6.1947, leg. E. Weinhold, 1 Expl., co...
# 20        Berlin, o. D. (um 1900), 1 Expl., coll. ZMB
# 21  „Tierpark Berlin“ 13.6.1941, 1 Expl., coll. D....
# 22        Berlin, o. D. (um 1900), 1 Expl., coll. DEI
# 23  SCHULZE (1918): Niederschönhausen, 1 Expl., le...
# 24  HORION (1941): Niederschönhausen, mehrfach, co...
# 25
# 26                 Berlin, o. D. (um 1900), coll. ZMB
# 27     SCHULZE (1918): Rehberge, leg. Wendeler 4.1912
# 28  Berlin, o. D. (um 1900), 1 Expl., coll. ZMB ex...
# 29        Berlin, o. D. (um 1900), 2 Expl., coll. ZMB
# 30  Berlin und Umgebung Berlin, o. D. (um 1900), z...
# 31  WRASE (1995): Forst Düppel 1995, 1 Expl., leg....
# 32  Malchow 1976, 1 Expl., leg. Rössel, coll. Kiel...
# 33                  HUBENTHAL (1919): Berlin, 1 Expl.
# 34  SCHULZE (1916): Spandau 9.1911 und Siemensstad...
# 35  WRASE (1995) führt irrtümlich Berliner Funde a...
# 36  Spandauer Stadtforst, ca. 1900, 1 Expl., leg. ...
# 37  Fundortangabe „Berl (?)“, o. D., 2 Expl., coll...
# 38  BARNDT et al. (2002): Gatow 1969, 1 Expl., leg...
# 39        Umgebung Berlin, o. D., 12 Expl., coll. DEI
# 40  KORGE (1958): Humboldthain 1957, 1 Expl., leg....
# 41        Berlin, o. D. (um 1900), 2 Expl., coll. DEI

# %%
# export the dataframe as CSV- the dates
df_dates.to_csv('Second_table_Coleoptera_Carabidae_Laufkäfer.csv', index=False)

# %%
df2.head()
# Out:
#                            Species BE BB DE GS Häufigkeit Vorzugshabitate  \
# 0    Acupalpus maculatus (SCHAUM)*  0  2  3            ex            (1)?
# 1  Agonum gracilipes (DUFTSCHMID)*  0  1  D            ex             (7)
# 2    Agonum hypocrita (APFELBECK)*  0  1  1            ex               2
# 3       Agonum impressum (PANZER)*  0  1  1            ex               1
# 4       Amara famelica ZIMMERMANN*  0  R  2            ex           (14)?
#
#   Gefährdungsursachen
# 0             1c, 12a
# 1                   ?
# 2             2d, 11c
# 3         3a, 5a, 12c
# 4                   ?

# %%
df_dates.describe()
# Out:
#                              Species  \
# count                             42
# unique                            42
# top     Abax carinatus (DUFTSCHMID)*
# freq                               1
#
#                                         Fundangaben
# count                                            42
# unique                                           41
# top     Berlin, o. D. (um 1900), 1 Expl., coll. ZMB
# freq                                              2

# %%
#df2 and df_dates
inner_join = pd.merge(df2, 
                      df_dates, 
                      on ='Species', 
                      how ='inner')
inner_join.describe()
# Out:
#        Species   BE   BB   DE   GS Häufigkeit Vorzugshabitate  \
# count        0    0    0    0    0          0               0
# unique       0    0    0    0    0          0               0
# top        NaN  NaN  NaN  NaN  NaN        NaN             NaN
# freq       NaN  NaN  NaN  NaN  NaN        NaN             NaN
#
#        Gefährdungsursachen Fundangaben
# count                    0           0
# unique                   0           0
# top                    NaN         NaN
# freq                   NaN         NaN

# %%
df_dates
# Out:
#                                               Species  \
# 0                        Abax carinatus (DUFTSCHMID)*
# 1                           Abax ovalis (DUFTSCHMID)*
# 2                         Acupalpus brunnipes (STURM)
# 3                          Agonum duftschmidi SCHMIDT
# 4                              Agonum scitulum DEJEAN
# 5                        Agonum viridicupreum (GOEZE)
# 6                              Amara montivaga STURM*
# 7                                 Amara nitida STURM*
# 8                            Amara pseudostrenua KULT
# 9                           Amara strenua ZIMMERMANN*
# 10                   Bembidion decoratum (DUFTSCHMID)
# 11                    Bembidion modestum (FABRICIUS)*
# 12                       Bembidion tenellum ERICHSON*
# 13                    Brachinus crepitans (LINNAEUS)*
# 14                     Brachinus explodens DUFTSCHMID
# 15                     Callistus lunatus (FABRICIUS)*
# 16        Carabus violaceus purpurascens  \nFABRICIUS
# 17                         Carabus scheidleri PANZER*
# 18                Chlaenius quadrisulcatus (Paykull)*
# 19                      Cylindera germanica LINNAEUS*
# 20                  Demetrias atricapillus (LINNAEUS)
# 21                    Dicheirotrichus gustavii CROTCH
# 22                 Dicheirotrichus obsoletus (DEJEAN)
# 23                    Dromius fenestratus (FABRICIUS)
# 24                  Dyschirius impunctipennis DAWSON*
# 25  Elaphropus quadrisignatus (DUFTSCHMID) Berlin,...
# 26                          Elaphrus aureus P. MÜLLER
# 27                    Harpalus dimidiatus (P. ROSSI)*
# 28                     Harpalus subcylindricus DEJEAN
# 29                      Lebia cyanocephala (LINNAEUS)
# 30                       Limodromus krynickii (SPERK)
# 31                       Miscodera arctica (PAYKULL)*
# 32                          Nebria livida (LINNAEUS)*
# 33              Nebria salina FAIRMAIRE & LABOULBÈNE*
# 34                Notiophilus quadripunctatus DEJEAN*
# 35                        Ophonus azureus (FABRICIUS)
# 36                     Ophonus cordatus (DUFTSCHMID)*
# 37                           Ophonus rupicola (STURM)
# 38                     Ophonus schaubergerianus PUEL*
# 39                    Perileptus areolatus (CREUTZER)
# 40                     Pterostichus aethiops (PANZER)
# 41                  Trichocellus cognatus (GYLLENHAL)
#
#                                           Fundangaben
# 0     Steglitz 1909, 1 Expl., leg. Hedicke, coll. ZMB
# 1   KORGE (1960): Grunewald 1958, 1 Expl., leg. D....
# 2   Berlin, o. D. (um 1900), 5 Expl. coll. DEI, 1 ...
# 3   Umgebung Berlin, 6 Expl., u. a. coll. Kraatz u...
# 4   Umgebung Berlin, 4 Expl., coll. Germar-Schaum ...
# 5   Umgebung Berlin, 1 Expl., coll. Kraatz in coll...
# 6   Berlin Schüppel, 1 Expl., coll. Kraatz in coll...
# 7   Berlin, o. D. (um 1900), je 1 Expl. coll. DEI ...
# 8   Berlin, o. D. (um 1900), 1 Expl., coll. DEI, d...
# 9                       MÜLLER (1907): Tegel, 2 Expl.
# 10  KORGE (1973): Tiefwerder 1966, 1 Expl., leg. W...
# 11  HORION (1941): Nach Quedenfeldt 1886: Umgebung...
# 12  GRIEP & KORGE (1956): Lankwitz 1951, 1 Expl., ...
# 13  KORGE (1960): Spandauer Forst Jg. 35, 1 Expl.,...
# 14        Berlin, o. D. (um 1900), 1 Expl., coll. ZMB
# 15  Tegel 6.1947, leg. E. Weinhold, 1 Expl., coll....
# 16  Umgebung Berlin, leg. Dr. Zuelchaur, o. D., 2 ...
# 17            KUNTZEN (1915): Treptower Park, 1 Expl.
# 18       Berlin, o. D. (vor 1900), 7 Expl., coll. ZMB
# 19  Tegel 10.6.1947, leg. E. Weinhold, 1 Expl., co...
# 20        Berlin, o. D. (um 1900), 1 Expl., coll. ZMB
# 21  „Tierpark Berlin“ 13.6.1941, 1 Expl., coll. D....
# 22        Berlin, o. D. (um 1900), 1 Expl., coll. DEI
# 23  SCHULZE (1918): Niederschönhausen, 1 Expl., le...
# 24  HORION (1941): Niederschönhausen, mehrfach, co...
# 25
# 26                 Berlin, o. D. (um 1900), coll. ZMB
# 27     SCHULZE (1918): Rehberge, leg. Wendeler 4.1912
# 28  Berlin, o. D. (um 1900), 1 Expl., coll. ZMB ex...
# 29        Berlin, o. D. (um 1900), 2 Expl., coll. ZMB
# 30  Berlin und Umgebung Berlin, o. D. (um 1900), z...
# 31  WRASE (1995): Forst Düppel 1995, 1 Expl., leg....
# 32  Malchow 1976, 1 Expl., leg. Rössel, coll. Kiel...
# 33                  HUBENTHAL (1919): Berlin, 1 Expl.
# 34  SCHULZE (1916): Spandau 9.1911 und Siemensstad...
# 35  WRASE (1995) führt irrtümlich Berliner Funde a...
# 36  Spandauer Stadtforst, ca. 1900, 1 Expl., leg. ...
# 37  Fundortangabe „Berl (?)“, o. D., 2 Expl., coll...
# 38  BARNDT et al. (2002): Gatow 1969, 1 Expl., leg...
# 39        Umgebung Berlin, o. D., 12 Expl., coll. DEI
# 40  KORGE (1958): Humboldthain 1957, 1 Expl., leg....
# 41        Berlin, o. D. (um 1900), 2 Expl., coll. DEI
