# %%
import camelot
import pandas as pd

# %% [markdown]
# # Updated Process

# %% [markdown]
# ## 1. Create empty dataframe with proper column names

# %%
# This is where data will be added after cleaning. The final dataframe for export

# %%
df = pd.DataFrame(columns = [
    "Species",
    "BE", 
    "Bestand", 
    "Trend_lang", 
    "Trend_kurz",
    "RF",
    "D",
    "GfU",
    "Letzter_Nachweis"
])
df
# Out:
# Empty DataFrame
# Columns: [Species, BE, Bestand, Trend_lang, Trend_kurz, RF, D, GfU, Letzter_Nachweis]
# Index: []

# %%
df.shape
# Out:
# (0, 9)

# %% [markdown]
# ## 2. Setup mechanism to store accuracy report : QA step

# %%
accuracy = []

# %% [markdown]
# ## 3. Dictionary of dataframes on the go

# %%
# Dictionary to collect dataframes created from each table
d = {}

# %% [markdown]
# ## 4. Adding the list of pages to be parsed

# %%
pages = []
i = 7
while i < 9:
    pages.append(i)
    i = i + 1
print(pages)
# Out:
# [7, 8]

# %% [markdown]
# ## 5. Parsing through the pages

# %%
for i in pages:
    # print page number
    print (i)
    # create dataframe with page number
    d[i] = pd.DataFrame()
    #read the page
    tables = camelot.read_pdf('rote_liste_raubfliegen_degen.pdf', 
                              pages= str(i), 
                              flavor='stream', edge_tol=1000, row_tol=10)
    #tables = camelot.read_pdf('rote_liste_raubfliegen_degen.pdf', pages= str(i), flavor='lattice')
    # add the accuracy report
    accuracy.append(tables[0].parsing_report)
    # assign the first table to a dataframe
    d[i] = tables[0].df
    print(d[i].shape)
# Print Done once all pages are parsed
print ("Done")
# Out:
# 7
# (26, 9)
# 8
# (20, 9)
# Done

# %%
# Check accuracy reports for the process
accuracy
# Out:
# [{'accuracy': 99.7, 'whitespace': 28.21, 'order': 1, 'page': 7},
#  {'accuracy': 99.35, 'whitespace': 22.78, 'order': 1, 'page': 8}]

# %%
d[8]
# Out:
#                                              0   1        2      3  \
# 0                      Wissenschaftlicher Name  BE  Bestand  Trend
# 1                                                             lang
# 2   Leptogaster guttiventris ZETTERSTEDT, 1842   *       ss      =
# 3              Leptogaster subtilis LOEW, 1847   *       ss      >
# 4          Machimus arthriticus (ZELLER, 1840)   1       es     <<
# 5            Machimus chrysitis (MEIGEN, 1820)   *       ss      =
# 6           Machimus gonatistes (ZELLER, 1840)   1       es      =
# 7             Machimus rusticus (MEIGEN, 1820)   *       ss      =
# 8       Neoepitriptus setosulus (ZELLER, 1840)   *        s      =
# 9        Neoitamus cothurnatus (MEIGEN, 1820)*   *       ss      ?
# 10             Neoitamus cyanurus (LOEW, 1849)   *       mh      =
# 11               Neoitamus socius (LOEW, 1871)   1       es     <<
# 12    Neomochtherus geniculatus (MEIGEN, 1820)   *        s      =
# 13       Neomochtherus pallipes (MEIGEN, 1820)   *        s      =
# 14      Pamponerus germanicus (LINNAEUS, 1758)   *       ss      =
# 15          Philonicus albiceps (MEIGEN, 1820)   *       mh      =
# 16   Rhadiurgus variabilis (ZETTERSTEDT, 1838)   1       es      <
# 17        Tolmerus atricapillus (FALLÉN, 1814)   *       mh      =
# 18       Tolmerus cingulatus (FABRICIUS, 1781)   *        h      >
# 19             Tolmerus pyragra (ZELLER, 1840)   *        s      =
#
#                             4   5  6    7         8
# 0                       Trend  RF  D  GfU   Letzter
# 1                        kurz              Nachweis
# 2                           =   =  *
# 3            (cid:113)(cid:3)   =  *
# 4   (cid:114)(cid:114)(cid:3)   =  *
# 5            (cid:113)(cid:3)   =  2
# 6                 ((cid:114))   =  2
# 7                           =   =  V
# 8            (cid:113)(cid:3)   =  3
# 9            (cid:113)(cid:3)   =  G
# 10                          =   =  *
# 11                          ?   =  *
# 12           (cid:113)(cid:3)   =  *
# 13                          =   =  *
# 14                          =   =  3
# 15                          =   =  *
# 16                ((cid:114))   =  V    ?
# 17                          =   =  *
# 18                          =   =  *
# 19                          =   =  V

# %% [markdown]
# # Data cleanup steps

# %% [raw]
# d[67]
#     : Look at the data frame extracted from 67th page
# d[67].shape
#     : Look at the shape of the dataframe
# d[68] = d[68].drop([12], axis=1)
#     : Drop the 12th column in place
# d[68][10] = d[68][[10, 11]].agg(' '.join, axis=1)
#     : Join 10th and 11th columns with a space in between
# d[69][[9,11]] = d[69][9].str.split('\n', expand=True)
#     : Split 9th Column at the '\n' sign and add a new column called 11
# column_to_move = d[69].pop(11)
# column_to_move
# d[69].insert(9, 11, column_to_move )
#     : Pop column 11 and insert it at column 9
# d[75].insert(9, '10', ["",""])
#     : Insert two rows of column 10 after 9 with empty cells

# %%
d[7] = d[7].drop([0,1], axis=0)
d[7]
# Out:
#                                           0  1   2    3  \
# 2        Andrenosoma atrum (LINNAEUS, 1758)  0  ex
# 3          Antipalus varipes (MEIGEN, 1820)  *   h    =
# 4      Asilus crabroniformis LINNAEUS, 1758  0  ex
# 5         Choerades femorata (MEIGEN, 1804)  *  ss    =
# 6          Choerades gilva (LINNAEUS, 1758)  0  ex
# 7            Choerades ignea (MEIGEN, 1820)  1  es   <<
# 8      Choerades marginata (LINNAEUS, 1758)  *   s    =
# 9       Dasypogon diadema (FABRICIUS, 1781)  V   s    =
# 10        Dioctria atricapilla MEIGEN, 1804  *  mh    =
# 11         Dioctria cothurnata MEIGEN, 1820  0  ex
# 12   Dioctria hyalipennis (FABRICIUS, 1794)  *  mh    =
# 13     Dioctria linearis (FABRICIUS, 1787)*  R  es    ?
# 14      Dioctria oelandica (LINNAEUS, 1758)  *  ss    =
# 15         Dioctria rufipes (DE GEER, 1776)  *   s    =
# 16        Dysmachus trigonus (MEIGEN, 1804)  *   s    =
# 17     Echthistus rufinervis (MEIGEN, 1820)  G  ss  (<)
# 18              Erax barbatus SCOPOLI, 1763  0  ex
# 19       Eutolmus rufibarbis (MEIGEN, 1820)  *  mh    =
# 20     Holopogon fumipennis (MEIGEN, 1820)*  0  ex
# 21           Laphria flava (LINNAEUS, 1758)  1  es   <<
# 22         Laphria gibbosa (LINNAEUS, 1758)  0  ex
# 23     Lasiopogon cinctus (FABRICIUS, 1781)  *  ss    =
# 24  Leptarthrus brevirostris (MEIGEN, 1804)  0  ex
# 25   Leptogaster cylindrica (DE GEER, 1776)  *   s    =
#
#                                      4  5  6        7         8
# 2                                          2               1904
# 3                                    =  =  V
# 4                                          2               1936
# 5                                    =  =  *
# 6                                          G               1958
# 7            (cid:114)(cid:114)(cid:3)  =  V      12b
# 8                                    =  =  *
# 9                          ((cid:114))  =  2  7a, 14e
# 10                                   =  =  *
# 11                                         *               1951
# 12                                   =  =  *
# 13                                   ?  =  *        ?
# 14                                   ?  =  *
# 15                                   =  =  *
# 16                                   =  =  *
# 17                                   =  =  3
# 18                                         2           vor 1945
# 19                    (cid:113)(cid:3)  =  V
# 20                                         3           vor 1945
# 21  (cid:114)(cid:114)(cid:114)(cid:3)  =  *      12b
# 22                                         2               1965
# 23                                   =  =  *
# 24                                         V               1932
# 25                                   =  =  *

# %%
d[8] = d[8].drop([0,1], axis=0)
d[8]
# Out:
#                                              0  1   2   3  \
# 2   Leptogaster guttiventris ZETTERSTEDT, 1842  *  ss   =
# 3              Leptogaster subtilis LOEW, 1847  *  ss   >
# 4          Machimus arthriticus (ZELLER, 1840)  1  es  <<
# 5            Machimus chrysitis (MEIGEN, 1820)  *  ss   =
# 6           Machimus gonatistes (ZELLER, 1840)  1  es   =
# 7             Machimus rusticus (MEIGEN, 1820)  *  ss   =
# 8       Neoepitriptus setosulus (ZELLER, 1840)  *   s   =
# 9        Neoitamus cothurnatus (MEIGEN, 1820)*  *  ss   ?
# 10             Neoitamus cyanurus (LOEW, 1849)  *  mh   =
# 11               Neoitamus socius (LOEW, 1871)  1  es  <<
# 12    Neomochtherus geniculatus (MEIGEN, 1820)  *   s   =
# 13       Neomochtherus pallipes (MEIGEN, 1820)  *   s   =
# 14      Pamponerus germanicus (LINNAEUS, 1758)  *  ss   =
# 15          Philonicus albiceps (MEIGEN, 1820)  *  mh   =
# 16   Rhadiurgus variabilis (ZETTERSTEDT, 1838)  1  es   <
# 17        Tolmerus atricapillus (FALLÉN, 1814)  *  mh   =
# 18       Tolmerus cingulatus (FABRICIUS, 1781)  *   h   >
# 19             Tolmerus pyragra (ZELLER, 1840)  *   s   =
#
#                             4  5  6  7 8
# 2                           =  =  *
# 3            (cid:113)(cid:3)  =  *
# 4   (cid:114)(cid:114)(cid:3)  =  *
# 5            (cid:113)(cid:3)  =  2
# 6                 ((cid:114))  =  2
# 7                           =  =  V
# 8            (cid:113)(cid:3)  =  3
# 9            (cid:113)(cid:3)  =  G
# 10                          =  =  *
# 11                          ?  =  *
# 12           (cid:113)(cid:3)  =  *
# 13                          =  =  *
# 14                          =  =  3
# 15                          =  =  *
# 16                ((cid:114))  =  V  ?
# 17                          =  =  *
# 18                          =  =  *
# 19                          =  =  V

# %%
# Check whether all dataframes are of the same size
for key in d:
    print(key)
    print(d[key].shape)
# Out:
# 7
# (24, 9)
# 8
# (18, 9)

# %%
# Removing empty dataframes
# del d[64]
# del d[74]

# %%
# Creates a sorted dictionary (sorted by key)
from collections import OrderedDict
d2 = OrderedDict(sorted(d.items()))

# %%
# Check whether the dictionary is sorted
for key in d2:
    print(key)
# Out:
# 7
# 8

# %%
# Rename all the dataframes in the sorted dictionary
for key in d2:
    print(key)
    d2[key].columns = [
        "Species",
        "BE", 
        "Bestand", 
        "Trend_lang", 
        "Trend_kurz",
        "RF",
        "D",
        "GfU",
        "Letzter_Nachweis"
    ]
print("Rename completed for concat")
# Out:
# 7
# 8
# Rename completed for concat

# %%
# Concatanate all the non-empty dataframes in the sorted dictionary into the empty df
for key in d2:
    df = pd.concat([df, d2[key]], axis = 0)
df
# Out:
#                                        Species BE Bestand Trend_lang  \
# 2           Andrenosoma atrum (LINNAEUS, 1758)  0      ex
# 3             Antipalus varipes (MEIGEN, 1820)  *       h          =
# 4         Asilus crabroniformis LINNAEUS, 1758  0      ex
# 5            Choerades femorata (MEIGEN, 1804)  *      ss          =
# 6             Choerades gilva (LINNAEUS, 1758)  0      ex
# 7               Choerades ignea (MEIGEN, 1820)  1      es         <<
# 8         Choerades marginata (LINNAEUS, 1758)  *       s          =
# 9          Dasypogon diadema (FABRICIUS, 1781)  V       s          =
# 10           Dioctria atricapilla MEIGEN, 1804  *      mh          =
# 11            Dioctria cothurnata MEIGEN, 1820  0      ex
# 12      Dioctria hyalipennis (FABRICIUS, 1794)  *      mh          =
# 13        Dioctria linearis (FABRICIUS, 1787)*  R      es          ?
# 14         Dioctria oelandica (LINNAEUS, 1758)  *      ss          =
# 15            Dioctria rufipes (DE GEER, 1776)  *       s          =
# 16           Dysmachus trigonus (MEIGEN, 1804)  *       s          =
# 17        Echthistus rufinervis (MEIGEN, 1820)  G      ss        (<)
# 18                 Erax barbatus SCOPOLI, 1763  0      ex
# 19          Eutolmus rufibarbis (MEIGEN, 1820)  *      mh          =
# 20        Holopogon fumipennis (MEIGEN, 1820)*  0      ex
# 21              Laphria flava (LINNAEUS, 1758)  1      es         <<
# 22            Laphria gibbosa (LINNAEUS, 1758)  0      ex
# 23        Lasiopogon cinctus (FABRICIUS, 1781)  *      ss          =
# 24     Leptarthrus brevirostris (MEIGEN, 1804)  0      ex
# 25      Leptogaster cylindrica (DE GEER, 1776)  *       s          =
# 2   Leptogaster guttiventris ZETTERSTEDT, 1842  *      ss          =
# 3              Leptogaster subtilis LOEW, 1847  *      ss          >
# 4          Machimus arthriticus (ZELLER, 1840)  1      es         <<
# 5            Machimus chrysitis (MEIGEN, 1820)  *      ss          =
# 6           Machimus gonatistes (ZELLER, 1840)  1      es          =
# 7             Machimus rusticus (MEIGEN, 1820)  *      ss          =
# 8       Neoepitriptus setosulus (ZELLER, 1840)  *       s          =
# 9        Neoitamus cothurnatus (MEIGEN, 1820)*  *      ss          ?
# 10             Neoitamus cyanurus (LOEW, 1849)  *      mh          =
# 11               Neoitamus socius (LOEW, 1871)  1      es         <<
# 12    Neomochtherus geniculatus (MEIGEN, 1820)  *       s          =
# 13       Neomochtherus pallipes (MEIGEN, 1820)  *       s          =
# 14      Pamponerus germanicus (LINNAEUS, 1758)  *      ss          =
# 15          Philonicus albiceps (MEIGEN, 1820)  *      mh          =
# 16   Rhadiurgus variabilis (ZETTERSTEDT, 1838)  1      es          <
# 17        Tolmerus atricapillus (FALLÉN, 1814)  *      mh          =
# 18       Tolmerus cingulatus (FABRICIUS, 1781)  *       h          >
# 19             Tolmerus pyragra (ZELLER, 1840)  *       s          =
#
#                             Trend_kurz RF  D      GfU Letzter_Nachweis
# 2                                          2                      1904
# 3                                    =  =  V
# 4                                          2                      1936
# 5                                    =  =  *
# 6                                          G                      1958
# 7            (cid:114)(cid:114)(cid:3)  =  V      12b
# 8                                    =  =  *
# 9                          ((cid:114))  =  2  7a, 14e
# 10                                   =  =  *
# 11                                         *                      1951
# 12                                   =  =  *
# 13                                   ?  =  *        ?
# 14                                   ?  =  *
# 15                                   =  =  *
# 16                                   =  =  *
# 17                                   =  =  3
# 18                                         2                  vor 1945
# 19                    (cid:113)(cid:3)  =  V
# 20                                         3                  vor 1945
# 21  (cid:114)(cid:114)(cid:114)(cid:3)  =  *      12b
# 22                                         2                      1965
# 23                                   =  =  *
# 24                                         V                      1932
# 25                                   =  =  *
# 2                                    =  =  *
# 3                     (cid:113)(cid:3)  =  *
# 4            (cid:114)(cid:114)(cid:3)  =  *
# 5                     (cid:113)(cid:3)  =  2
# 6                          ((cid:114))  =  2
# 7                                    =  =  V
# 8                     (cid:113)(cid:3)  =  3
# 9                     (cid:113)(cid:3)  =  G
# 10                                   =  =  *
# 11                                   ?  =  *
# 12                    (cid:113)(cid:3)  =  *
# 13                                   =  =  *
# 14                                   =  =  3
# 15                                   =  =  *
# 16                         ((cid:114))  =  V        ?
# 17                                   =  =  *
# 18                                   =  =  *
# 19                                   =  =  V

# %%
# Definition of extinction
df2 = df.loc[df["BE"] == "0"]
df2.head()
# Out:
#                                  Species BE Bestand Trend_lang Trend_kurz RF  \
# 2     Andrenosoma atrum (LINNAEUS, 1758)  0      ex
# 4   Asilus crabroniformis LINNAEUS, 1758  0      ex
# 6       Choerades gilva (LINNAEUS, 1758)  0      ex
# 11      Dioctria cothurnata MEIGEN, 1820  0      ex
# 18           Erax barbatus SCOPOLI, 1763  0      ex
#
#     D GfU Letzter_Nachweis
# 2   2                 1904
# 4   2                 1936
# 6   G                 1958
# 11  *                 1951
# 18  2             vor 1945

# %%
df2.reset_index(inplace = True)
df2.head()
# Out:
#    index                               Species BE Bestand Trend_lang  \
# 0      2    Andrenosoma atrum (LINNAEUS, 1758)  0      ex
# 1      4  Asilus crabroniformis LINNAEUS, 1758  0      ex
# 2      6      Choerades gilva (LINNAEUS, 1758)  0      ex
# 3     11      Dioctria cothurnata MEIGEN, 1820  0      ex
# 4     18           Erax barbatus SCOPOLI, 1763  0      ex
#
#   Trend_kurz RF  D GfU Letzter_Nachweis
# 0                2                 1904
# 1                2                 1936
# 2                G                 1958
# 3                *                 1951
# 4                2             vor 1945

# %%
df2 = df2.drop(['index'], axis=1)
df2.head()
# Out:
#                                 Species BE Bestand Trend_lang Trend_kurz RF  \
# 0    Andrenosoma atrum (LINNAEUS, 1758)  0      ex
# 1  Asilus crabroniformis LINNAEUS, 1758  0      ex
# 2      Choerades gilva (LINNAEUS, 1758)  0      ex
# 3      Dioctria cothurnata MEIGEN, 1820  0      ex
# 4           Erax barbatus SCOPOLI, 1763  0      ex
#
#    D GfU Letzter_Nachweis
# 0  2                 1904
# 1  2                 1936
# 2  G                 1958
# 3  *                 1951
# 4  2             vor 1945

# %%
df3 = df.loc[df["Bestand"] == "ex"]
df3.head()
# Out:
#                                  Species BE Bestand Trend_lang Trend_kurz RF  \
# 2     Andrenosoma atrum (LINNAEUS, 1758)  0      ex
# 4   Asilus crabroniformis LINNAEUS, 1758  0      ex
# 6       Choerades gilva (LINNAEUS, 1758)  0      ex
# 11      Dioctria cothurnata MEIGEN, 1820  0      ex
# 18           Erax barbatus SCOPOLI, 1763  0      ex
#
#     D GfU Letzter_Nachweis
# 2   2                 1904
# 4   2                 1936
# 6   G                 1958
# 11  *                 1951
# 18  2             vor 1945

# %%
df2.describe()
# Out:
#                                    Species BE Bestand Trend_lang Trend_kurz  \
# count                                    8  8       8          8          8
# unique                                   8  1       1          1          1
# top     Andrenosoma atrum (LINNAEUS, 1758)  0      ex
# freq                                     1  8       8          8          8
#
#        RF  D GfU Letzter_Nachweis
# count   8  8   8                8
# unique  1  5   1                7
# top        2             vor 1945
# freq    8  4   8                2

# %%
df3.describe()
# Out:
#                                    Species BE Bestand Trend_lang Trend_kurz  \
# count                                    8  8       8          8          8
# unique                                   8  1       1          1          1
# top     Andrenosoma atrum (LINNAEUS, 1758)  0      ex
# freq                                     1  8       8          8          8
#
#        RF  D GfU Letzter_Nachweis
# count   8  8   8                8
# unique  1  5   1                7
# top        2             vor 1945
# freq    8  4   8                2

# %%
# export the dataframe as CSV
# Updated location
df2.to_csv('../../Transformation/Raw_csv/Diptera_Asilidae_Raubfliegen.csv', index=False)
