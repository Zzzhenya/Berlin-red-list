# %%
import camelot
import pandas as pd

# %% [markdown]
# # Updated Process

# %% [markdown]
# ## 1. Create empty dataframe with proper column names

# %%
# This is where data will be added after cleaning. The final dataframe for export

# %%
df = pd.DataFrame(columns = [
    "Species",
    "BE", 
    "Bestand", 
    "Trend_lang",
    "Trend_kurz",
    "RF",
    "BB",
    "D"
])
df
# Out:
# Empty DataFrame
# Columns: [Species, BE, Bestand, Trend_lang, Trend_kurz, RF, BB, D]
# Index: []

# %%
df.shape
# Out:
# (0, 8)

# %% [markdown]
# ## 2. Setup mechanism to store accuracy report : QA step

# %%
accuracy = []

# %% [markdown]
# ## 3. Dictionary of dataframes on the go

# %%
# Dictionary to collect dataframes created from each table
d = {}

# %% [markdown]
# ## 4. Adding the list of pages to be parsed

# %%
pages = []
i = 5
while i < 6:
    pages.append(i)
    i = i + 1
print(pages)
# Out:
# [5]

# %% [markdown]
# ## 5. Parsing through the pages

# %%
for i in pages:
    # print page number
    print (i)
    # create dataframe with page number
    d[i] = pd.DataFrame()
    #read the page
    tables = camelot.read_pdf('rote_liste_flechtenpilze_wagner_et_al.pdf', 
                              pages= str(i), 
                              flavor='stream', edge_tol=1000, row_tol=10)
    #tables = camelot.read_pdf('18_netzfl_print.pdf', pages= str(i), flavor='lattice')
    # add the accuracy report
    accuracy.append(tables[1].parsing_report)
    # assign the first table to a dataframe
    d[i] = tables[1].df
    print(d[i].shape)
# Print Done once all pages are parsed
print ("Done")
# Out:
# 5
# (35, 8)
# Done

# %%
d[5]
# Out:
#                                                     0   1        2      3  \
# 0   Tabelle 1: Rote Liste und Gesamtartenliste der...
# 1                             Wissenschaftlicher Name  BE  Bestand  Trend
# 2                                                                    lang
# 3           Abrothallus parmeliarum (SOMMERF.) ARNOLD   0       ex
# 4               Arthonia phaeophysciae GRUBE & MATZER   *        s      =
# 5                  Athelia arachnoidea (BERK.) JÜLICH   *       sh      =
# 6             Capronia peltigerae (FUCKEL) D. HAWKSW.   D       ss      ?
# 7         Cercidospora macrospora (ULOTH) HAFELLNER &
# 8                                           NAV.-ROS.   D       ss      ?
# 9   Cladoniicola staurospora DIEDERICH, VAN DEN BO...
# 10                                            APTROOT   D       ss      ?
# 11       Didymosphaeria futilis (BERK. & BROOME) REHM   D       mh      ?
# 12              Graphium aphthosae ALSTRUP D. HAWKSW.   D       ss      ?
# 13                        Hainesia xanthoriae BRACKEL   *        s      =
# 14          Hawksworthiana peltigericola (D. HAWKSW.)
# 15                                           U. BRAUN   D        s      ?
# 16    Illosporiopsis christiansenii (B. L. BRADY & D.
# 17                                HAWKSW.) D. HAWKSW.   D        s      ?
# 18  Intralichen christiansenii (D. HAWKSW.) D. HAW...
# 19                                       & M. S. COLE   *        s      =
# 20             Libertiella malmedyensis SPEG. & ROUM.   D        s      ?
# 21                    Licea parasitica (ZUKAL) MARTIN   *        h      =
# 22         Lichenodiplis lecanorae (VOUAUX) DYKO & D.
# 23                                            HAWKSW.   D       ss      ?
# 24        Marchandiobasidium aurantiacum (LASCH) DIE-
# 25                                DERICH & SCHULTHEIS   *       mh      =
# 26   Marchandiomyces corallinus (ROBERGE) DIEDERICH &
# 27                                         D. HAWKSW.   *        h      =
# 28  Paranectria oropensis (CES. ex RABENH.) D. HAW...
# 29                                           & PIROZ.   *        s      =
# 30  Pezizella epithallina (W. PHILLIPS & PLOWR.) S...   D        s      ?
# 31                     Sarcopyrenia gibba (NYL.) NYL.   D        ?      ?
# 32                 Scutula miliaris (WALLR.) TREVISAN   0       ex
# 33  Thelocarpon lichenicola (FUCKEL) POELT & HAFEL...   D        ?      =
# 34        Xanthoriicola physciae (KALCHBR.) D.HAWKSW.   *        s      =
#
#         4   5   6   7
# 0
# 1   Trend  RF  BB   D
# 2    kurz
# 3               0   *
# 4       ?   =  kN   D
# 5       =   =   *   *
# 6       ?   =  kN   D
# 7
# 8       ?   =  kN   *
# 9
# 10      ?   =  kN   D
# 11      ?   =  kN   D
# 12      ?   =  kN  kN
# 13      ?   =  kN   *
# 14
# 15      ?   =  kN  kN
# 16
# 17      ?   =  kN   D
# 18
# 19      =   =  kN   *
# 20      ?   =  kN   D
# 21      ?   =   D  kN
# 22
# 23      ?   =  kN   *
# 24
# 25      ?   =  kN   *
# 26
# 27      ?   =   0   D
# 28
# 29      ?   =  kN   *
# 30      ?   =   *   D
# 31      ?   =   D   *
# 32              0   1
# 33      =   =   D   3
# 34      =   =   R   *

# %%
# Check accuracy reports for the process
accuracy
# Out:
# [{'accuracy': 99.81, 'whitespace': 29.29, 'order': 2, 'page': 5}]

# %% [markdown]
# # Data cleanup steps

# %% [raw]
# d[67]
#     : Look at the data frame extracted from 67th page
# d[67].shape
#     : Look at the shape of the dataframe
# d[68] = d[68].drop([12], axis=1)
#     : Drop the 12th column in place
# d[68][10] = d[68][[10, 11]].agg(' '.join, axis=1)
#     : Join 10th and 11th columns with a space in between
# d[69][[9,11]] = d[69][9].str.split('\n', expand=True)
#     : Split 9th Column at the '\n' sign and add a new column called 11
# column_to_move = d[69].pop(11)
# column_to_move
# d[69].insert(9, 11, column_to_move )
#     : Pop column 11 and insert it at column 9
# d[75].insert(9, '10', ["",""])
#     : Insert two rows of column 10 after 9 with empty cells

# %%
# Check whether all dataframes are of the same size
for key in d:
    print(key)
    print(d[key].shape)
# Out:
# 5
# (35, 8)

# %%
# Removing empty dataframes
# del d[64]
# del d[74]

# %%
# Creates a sorted dictionary (sorted by key)
from collections import OrderedDict
d2 = OrderedDict(sorted(d.items()))

# %%
# Check whether the dictionary is sorted
for key in d2:
    print(key)
# Out:
# 5

# %%
# Rename all the dataframes in the sorted dictionary
for key in d2:
    print(key)
    d2[key].columns = [ "Species",
    "BE", 
    "Bestand", 
    "Trend_lang",
    "Trend_kurz",
    "RF",
    "BB",
    "D"]
print("Rename completed for concat")
# Out:
# 5
# Rename completed for concat

# %%
# Concatanate all the non-empty dataframes in the sorted dictionary into the empty df
for key in d2:
    df = pd.concat([df, d2[key]], axis = 0)
df
# Out:
#                                               Species  BE  Bestand Trend_lang  \
# 0   Tabelle 1: Rote Liste und Gesamtartenliste der...
# 1                             Wissenschaftlicher Name  BE  Bestand      Trend
# 2                                                                        lang
# 3           Abrothallus parmeliarum (SOMMERF.) ARNOLD   0       ex
# 4               Arthonia phaeophysciae GRUBE & MATZER   *        s          =
# 5                  Athelia arachnoidea (BERK.) JÜLICH   *       sh          =
# 6             Capronia peltigerae (FUCKEL) D. HAWKSW.   D       ss          ?
# 7         Cercidospora macrospora (ULOTH) HAFELLNER &
# 8                                           NAV.-ROS.   D       ss          ?
# 9   Cladoniicola staurospora DIEDERICH, VAN DEN BO...
# 10                                            APTROOT   D       ss          ?
# 11       Didymosphaeria futilis (BERK. & BROOME) REHM   D       mh          ?
# 12              Graphium aphthosae ALSTRUP D. HAWKSW.   D       ss          ?
# 13                        Hainesia xanthoriae BRACKEL   *        s          =
# 14          Hawksworthiana peltigericola (D. HAWKSW.)
# 15                                           U. BRAUN   D        s          ?
# 16    Illosporiopsis christiansenii (B. L. BRADY & D.
# 17                                HAWKSW.) D. HAWKSW.   D        s          ?
# 18  Intralichen christiansenii (D. HAWKSW.) D. HAW...
# 19                                       & M. S. COLE   *        s          =
# 20             Libertiella malmedyensis SPEG. & ROUM.   D        s          ?
# 21                    Licea parasitica (ZUKAL) MARTIN   *        h          =
# 22         Lichenodiplis lecanorae (VOUAUX) DYKO & D.
# 23                                            HAWKSW.   D       ss          ?
# 24        Marchandiobasidium aurantiacum (LASCH) DIE-
# 25                                DERICH & SCHULTHEIS   *       mh          =
# 26   Marchandiomyces corallinus (ROBERGE) DIEDERICH &
# 27                                         D. HAWKSW.   *        h          =
# 28  Paranectria oropensis (CES. ex RABENH.) D. HAW...
# 29                                           & PIROZ.   *        s          =
# 30  Pezizella epithallina (W. PHILLIPS & PLOWR.) S...   D        s          ?
# 31                     Sarcopyrenia gibba (NYL.) NYL.   D        ?          ?
# 32                 Scutula miliaris (WALLR.) TREVISAN   0       ex
# 33  Thelocarpon lichenicola (FUCKEL) POELT & HAFEL...   D        ?          =
# 34        Xanthoriicola physciae (KALCHBR.) D.HAWKSW.   *        s          =
#
#    Trend_kurz  RF  BB   D
# 0
# 1       Trend  RF  BB   D
# 2        kurz
# 3                   0   *
# 4           ?   =  kN   D
# 5           =   =   *   *
# 6           ?   =  kN   D
# 7
# 8           ?   =  kN   *
# 9
# 10          ?   =  kN   D
# 11          ?   =  kN   D
# 12          ?   =  kN  kN
# 13          ?   =  kN   *
# 14
# 15          ?   =  kN  kN
# 16
# 17          ?   =  kN   D
# 18
# 19          =   =  kN   *
# 20          ?   =  kN   D
# 21          ?   =   D  kN
# 22
# 23          ?   =  kN   *
# 24
# 25          ?   =  kN   *
# 26
# 27          ?   =   0   D
# 28
# 29          ?   =  kN   *
# 30          ?   =   *   D
# 31          ?   =   D   *
# 32                  0   1
# 33          =   =   D   3
# 34          =   =   R   *

# %%
# Definition of extinction
df2 = df.loc[df["BE"] == "0"]
df2.head()
# Out:
#                                       Species BE Bestand Trend_lang  \
# 3   Abrothallus parmeliarum (SOMMERF.) ARNOLD  0      ex
# 32         Scutula miliaris (WALLR.) TREVISAN  0      ex
#
#    Trend_kurz RF BB  D
# 3                 0  *
# 32                0  1

# %%
df2.reset_index(inplace = True)
df2.head()
# Out:
#    index                                    Species BE Bestand Trend_lang  \
# 0      3  Abrothallus parmeliarum (SOMMERF.) ARNOLD  0      ex
# 1     32         Scutula miliaris (WALLR.) TREVISAN  0      ex
#
#   Trend_kurz RF BB  D
# 0                0  *
# 1                0  1

# %%
df2 = df2.drop(['index'], axis=1)
df2.head()
# Out:
#                                      Species BE Bestand Trend_lang Trend_kurz  \
# 0  Abrothallus parmeliarum (SOMMERF.) ARNOLD  0      ex
# 1         Scutula miliaris (WALLR.) TREVISAN  0      ex
#
#   RF BB  D
# 0     0  *
# 1     0  1

# %%
df3 = df.loc[df["Bestand"] == "ex"]
df3.reset_index(inplace = True)
df3 = df3.drop(['index'], axis=1)
df3.head()
# Out:
#                                      Species BE Bestand Trend_lang Trend_kurz  \
# 0  Abrothallus parmeliarum (SOMMERF.) ARNOLD  0      ex
# 1         Scutula miliaris (WALLR.) TREVISAN  0      ex
#
#   RF BB  D
# 0     0  *
# 1     0  1

# %%
df2.describe()
# Out:
#                                           Species BE Bestand Trend_lang  \
# count                                           2  2       2          2
# unique                                          2  1       1          1
# top     Abrothallus parmeliarum (SOMMERF.) ARNOLD  0      ex
# freq                                            1  2       2          2
#
#        Trend_kurz RF BB  D
# count           2  2  2  2
# unique          1  1  1  2
# top                   0  *
# freq            2  2  2  1

# %%
df3.describe()
# Out:
#                                           Species BE Bestand Trend_lang  \
# count                                           2  2       2          2
# unique                                          2  1       1          1
# top     Abrothallus parmeliarum (SOMMERF.) ARNOLD  0      ex
# freq                                            1  2       2          2
#
#        Trend_kurz RF BB  D
# count           2  2  2  2
# unique          1  1  1  2
# top                   0  *
# freq            2  2  2  1

# %%
# export the dataframe as CSV
df2.to_csv('Fungi_lichenicolen.csv', index=False)
