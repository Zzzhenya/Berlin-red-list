# %%
import camelot
import pandas as pd

# %% [markdown]
# # Updated Process

# %% [markdown]
# ## 1. Create empty dataframe with proper column names

# %%
# This is where data will be added after cleaning. The final dataframe for export

# %%
df = pd.DataFrame(columns = [
    "Species",
    "BE", 
    "Bestand", 
    "Trend_lang",
    "Trend_kurz",
    "RF",
    "BB",
    "D",
    "GS",
    "GfU",
    "Common_name"
])
df
# Out:
# Empty DataFrame
# Columns: [Species, BE, Bestand, Trend_lang, Trend_kurz, RF, BB, D, GS, GfU, Common_name]
# Index: []

# %%
df.shape
# Out:
# (0, 11)

# %% [markdown]
# ## 2. Setup mechanism to store accuracy report : QA step

# %%
accuracy = []

# %% [markdown]
# ## 3. Dictionary of dataframes on the go

# %%
# Dictionary to collect dataframes created from each table
d = {}

# %% [markdown]
# ## 4. Adding the list of pages to be parsed

# %%
pages = []
i = 7
while i < 8:
    pages.append(i)
    i = i + 1
print(pages)
# Out:
# [7]

# %% [markdown]
# ## 5. Parsing through the pages

# %%
for i in pages:
    # print page number
    print (i)
    # create dataframe with page number
    d[i] = pd.DataFrame()
    #read the page
    tables = camelot.read_pdf('rote_liste_reptilien_kuehnel_et_al.pdf', 
                              pages= str(i), 
                              flavor='stream', edge_tol=1000, row_tol=10)
    #tables = camelot.read_pdf('18_netzfl_print.pdf', pages= str(i), flavor='lattice')
    # add the accuracy report
    accuracy.append(tables[0].parsing_report)
    # assign the first table to a dataframe
    d[i] = tables[0].df
    print(d[i].shape)
# Print Done once all pages are parsed
print ("Done")
# Out:
# 7
# (17, 11)
# Done

# %%
# Check accuracy reports for the process
accuracy
# Out:
# [{'accuracy': 99.74, 'whitespace': 49.2, 'order': 1, 'page': 7}]

# %% [markdown]
# # Data cleanup steps

# %% [raw]
# d[67]
#     : Look at the data frame extracted from 67th page
# d[67].shape
#     : Look at the shape of the dataframe
# d[68] = d[68].drop([12], axis=1)
#     : Drop the 12th column in place
# d[68][10] = d[68][[10, 11]].agg(' '.join, axis=1)
#     : Join 10th and 11th columns with a space in between
# d[69][[9,11]] = d[69][9].str.split('\n', expand=True)
#     : Split 9th Column at the '\n' sign and add a new column called 11
# column_to_move = d[69].pop(11)
# column_to_move
# d[69].insert(9, 11, column_to_move )
#     : Pop column 11 and insert it at column 9
# d[75].insert(9, '10', ["",""])
#     : Insert two rows of column 10 after 9 with empty cells

# %%
# Check whether all dataframes are of the same size
for key in d:
    print(key)
    print(d[key].shape)
# Out:
# 7
# (17, 11)

# %%
# Removing empty dataframes
# del d[64]
# del d[74]

# %%
# Creates a sorted dictionary (sorted by key)
from collections import OrderedDict
d2 = OrderedDict(sorted(d.items()))

# %%
# Check whether the dictionary is sorted
for key in d2:
    print(key)
# Out:
# 7

# %%
# Rename all the dataframes in the sorted dictionary
for key in d2:
    print(key)
    d2[key].columns = ["Species",
    "BE", 
    "Bestand", 
    "Trend_lang",
    "Trend_kurz",
    "RF",
    "BB",
    "D",
    "GS",
    "GfU",
    "Common_name"]
print("Rename completed for concat")
# Out:
# 7
# Rename completed for concat

# %%
# Concatanate all the non-empty dataframes in the sorted dictionary into the empty df
for key in d2:
    df = pd.concat([df, d2[key]], axis = 0)
df
# Out:
#                                  Species  BE  Bestand Trend_lang  \
# 0                Wissenschaftlicher Name  BE  Bestand      Trend
# 1                                                           lang
# 2              Schildkröten (Testudines)
# 3      Emys orbicularis (LINNAEUS, 1758)   0       ex
# 4
# 5                        Echsen (Sauria)
# 6       Anguis fragilis (LINNAEUS, 1758)   V       mh          <
# 7
# 8        Lacerta agilis (LINNAEUS, 1758)   V        h         <<
# 9
# 10       Zootoca vivipara (JAQUIN, 1787)   2        s         <<
# 11                 Schlangen (Serpentes)
# 12  Coronella austriaca (LAURENTI, 1768)   D        ?          ?
# 13        Natrix natrix (LINNAEUS, 1768)   V       mh         <<
# 14
# 15         Vipera berus (LINNAEUS, 1758)   1       es        <<<
# 16
#
#           Trend_kurz  RF  BB  D          GS                               GfU  \
# 0              Trend  RF  BB  D          GS                               GfU
# 1               kurz
# 2
# 3                          1  1  §§, II, IV  4a, 5a, 5b, 10c, 12b , 13a, 14b,
# 4                                                               14c, 14i, 14l
# 5
# 6        ((cid:114))   =  **  *           §          2a, 3a, 8e, 9a, 12b, 14i
# 7
# 8        ((cid:114))   -   3  V          §§  1a, 1c, 2a,  4b, 6d, 7a, 8a, 8d,
# 9                                                           8e, 12a, 12b, 14i
# 10       ((cid:114))   =   G  *           §       2a, 8a, 8b, 8c, 8e, 9a, 12b
# 11
# 12                 ?   =   2  3          §§              2a, 7a, 8a,  8d, 12a
# 13                 =   =   3  V           §     1a, 3a, 5a,  5b, 7e, 8b, 11c,
# 14                                                                   12c, 14k
# 15  (cid:113)(cid:3)   -   1  2           §      2a, 4d, 7a, 8a, 8b, 8e, 12b,
# 16                                                                   14d, 14e
#
#                      Common_name
# 0                 Deutscher Name
# 1
# 2
# 3   Europäische Sumpfschildkröte
# 4
# 5
# 6                Blindschleiche,
# 7       Westliche Blindschleiche
# 8                   Zauneidechse
# 9
# 10                  Waldeidechse
# 11
# 12    Schlingnatter, Glattnatter
# 13                  Ringelnatter
# 14
# 15                    Kreuzotter
# 16

# %%
# Definition of extinction
df2 = df.loc[df["BE"] == "0"]
df2.head()
# Out:
#                              Species BE Bestand Trend_lang Trend_kurz RF BB  \
# 3  Emys orbicularis (LINNAEUS, 1758)  0      ex                           1
#
#    D          GS                               GfU  \
# 3  1  §§, II, IV  4a, 5a, 5b, 10c, 12b , 13a, 14b,
#
#                     Common_name
# 3  Europäische Sumpfschildkröte

# %%
df2.reset_index(inplace = True)
df2.head()
# Out:
#    index                            Species BE Bestand Trend_lang Trend_kurz  \
# 0      3  Emys orbicularis (LINNAEUS, 1758)  0      ex
#
#   RF BB  D          GS                               GfU  \
# 0     1  1  §§, II, IV  4a, 5a, 5b, 10c, 12b , 13a, 14b,
#
#                     Common_name
# 0  Europäische Sumpfschildkröte

# %%
df2 = df2.drop(['index'], axis=1)
df2.head()
# Out:
#                              Species BE Bestand Trend_lang Trend_kurz RF BB  \
# 0  Emys orbicularis (LINNAEUS, 1758)  0      ex                           1
#
#    D          GS                               GfU  \
# 0  1  §§, II, IV  4a, 5a, 5b, 10c, 12b , 13a, 14b,
#
#                     Common_name
# 0  Europäische Sumpfschildkröte

# %%
df3 = df.loc[df["Bestand"] == "ex"]
df3.reset_index(inplace = True)
df3 = df3.drop(['index'], axis=1)
df3.head()
# Out:
#                              Species BE Bestand Trend_lang Trend_kurz RF BB  \
# 0  Emys orbicularis (LINNAEUS, 1758)  0      ex                           1
#
#    D          GS                               GfU  \
# 0  1  §§, II, IV  4a, 5a, 5b, 10c, 12b , 13a, 14b,
#
#                     Common_name
# 0  Europäische Sumpfschildkröte

# %%
df2.describe()
# Out:
#                                   Species BE Bestand Trend_lang Trend_kurz RF  \
# count                                   1  1       1          1          1  1
# unique                                  1  1       1          1          1  1
# top     Emys orbicularis (LINNAEUS, 1758)  0      ex
# freq                                    1  1       1          1          1  1
#
#        BB  D          GS                               GfU  \
# count   1  1           1                                 1
# unique  1  1           1                                 1
# top     1  1  §§, II, IV  4a, 5a, 5b, 10c, 12b , 13a, 14b,
# freq    1  1           1                                 1
#
#                          Common_name
# count                              1
# unique                             1
# top     Europäische Sumpfschildkröte
# freq                               1

# %%
df3.describe()
# Out:
#                                   Species BE Bestand Trend_lang Trend_kurz RF  \
# count                                   1  1       1          1          1  1
# unique                                  1  1       1          1          1  1
# top     Emys orbicularis (LINNAEUS, 1758)  0      ex
# freq                                    1  1       1          1          1  1
#
#        BB  D          GS                               GfU  \
# count   1  1           1                                 1
# unique  1  1           1                                 1
# top     1  1  §§, II, IV  4a, 5a, 5b, 10c, 12b , 13a, 14b,
# freq    1  1           1                                 1
#
#                          Common_name
# count                              1
# unique                             1
# top     Europäische Sumpfschildkröte
# freq                               1

# %%
# export the dataframe as CSV
df2.to_csv('Reptilia.csv', index=False)
