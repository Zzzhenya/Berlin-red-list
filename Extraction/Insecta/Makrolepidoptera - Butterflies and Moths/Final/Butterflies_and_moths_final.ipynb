# %%
import pandas as pd

# %%
df_1 = pd.read_csv('first_30 - first_30.csv')

# %%
df_2 = pd.read_csv('second_31_60 - second_31_60.csv')

# %%
df_3 = pd.read_csv('third_61_89 - third_61_89.csv')

# %%
final_df = pd.concat([df_1, df_2, df_3], axis=0)

# %%
final_df.describe()
# Out:
#                         Gattung                       Artname   BE Bestand  \
# count                       153                           153  153     153
# unique                      126                           153    4       1
# top     Eupithecia CURTIS, 1825  fusconebulosa (DEGEER, 1778)    0      ex
# freq                          5                             1  100     153
#
#           Vor_1990 1990_2017 Trend_kurz Habitat    D   BB  GS  \
# count          153       152          4     153  153  153  47
# unique          55         4          3      69    9    3   5
# top     x vor 1900         –  declining      TR    2    ⬤   §
# freq            38       149          2      18   38  124  26
#
#                 Deutscher_name
# count                      153
# unique                     153
# top     Adlerfarn-Wurzelbohrer
# freq                         1

# %%
final_df.head()
# Out:
#                     Gattung                        Artname BE Bestand  \
# 0    Pharmacis HÜBNER, 1820   fusconebulosa (DEGEER, 1778)  0      ex
# 1   Heterogenea KNOCH, 1783  asella (DEN. & SCHIFF., 1775)  0      ex
# 2   Zygaena FABRICIUS, 1775   purpuralis (BRUENNICH, 1763)  0      ex
# 3   Malacosoma HÜBNER, 1820    castrensis (LINNAEUS, 1758)  0      ex
# 4  Eriogaster GERMAR, 1810      lanestris (LINNAEUS, 1758)  0      ex
#
#      Vor_1990 1990_2017 Trend_kurz Habitat  D BB   GS  \
# 0      x 1973         –        NaN     LKW  V  ⬤  NaN
# 1      x 1978         –        NaN     LMW  V  ⬤  NaN
# 2           x         –        NaN      TR  V  ⬤    §
# 3      x 1982         –        NaN      TR  3  ⬤    §
# 4  x vor 1900         –        NaN     WRS  3  ⬤    §
#
#              Deutscher_name
# 0    Adlerfarn-Wurzelbohrer
# 1  Kleiner Schneckenspinner
# 2        Thymian-Widderchen
# 3  Wolfsmilch-Ringelspinner
# 4                 Wollafter

# %%
final_df.loc[(final_df["BE"] == "0") | (final_df["BE"] == 0)].describe()
# Out:
#                         Gattung                       Artname   BE Bestand  \
# count                       150                           150  150     150
# unique                      124                           150    2       1
# top     Eupithecia CURTIS, 1825  fusconebulosa (DEGEER, 1778)    0      ex
# freq                          5                             1  100     150
#
#           Vor_1990 1990_2017 Trend_kurz Habitat    D   BB  GS  \
# count          150       149          4     150  150  150  47
# unique          53         4          3      68    8    3   5
# top     x vor 1900         –  declining      TR    2    ⬤   §
# freq            38       146          2      18   38  122  26
#
#                 Deutscher_name
# count                      150
# unique                     150
# top     Adlerfarn-Wurzelbohrer
# freq                         1

# %%
# Remove the three species with Bestand == ex but BE is not 0. 
# Based on author correspondance.
final = final_df.loc[(final_df["BE"] == "0") | (final_df["BE"] == 0)]

# %%
final.describe()
# Out:
#                         Gattung                       Artname   BE Bestand  \
# count                       150                           150  150     150
# unique                      124                           150    2       1
# top     Eupithecia CURTIS, 1825  fusconebulosa (DEGEER, 1778)    0      ex
# freq                          5                             1  100     150
#
#           Vor_1990 1990_2017 Trend_kurz Habitat    D   BB  GS  \
# count          150       149          4     150  150  150  47
# unique          53         4          3      68    8    3   5
# top     x vor 1900         –  declining      TR    2    ⬤   §
# freq            38       146          2      18   38  122  26
#
#                 Deutscher_name
# count                      150
# unique                     150
# top     Adlerfarn-Wurzelbohrer
# freq                         1

# %%
final["BE"] = "0"
# Out:
# /var/folders/sf/pjcpsvqj67b_pqmm82g4y8bm0000gq/T/ipykernel_97496/282753805.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final["BE"] = "0"

# %%
final["BE"].unique()
# Out:
# array(['0'], dtype=object)

# %%
final
# Out:
#                          Gattung                        Artname BE Bestand  \
# 0         Pharmacis HÜBNER, 1820   fusconebulosa (DEGEER, 1778)  0      ex
# 1        Heterogenea KNOCH, 1783  asella (DEN. & SCHIFF., 1775)  0      ex
# 2        Zygaena FABRICIUS, 1775   purpuralis (BRUENNICH, 1763)  0      ex
# 3        Malacosoma HÜBNER, 1820    castrensis (LINNAEUS, 1758)  0      ex
# 4       Eriogaster GERMAR, 1810      lanestris (LINNAEUS, 1758)  0      ex
# ..                           ...                            ... ..     ...
# 51           Xestia HÜBNER, 1818      stigmatica (HÜBNER, 1813)  0      ex
# 52           Xestia HÜBNER, 1818         castanea (ESPER, 1798)  0      ex
# 53           Xestia HÜBNER, 1818   ashworthii (DOUBLEDAY, 1855)  0      ex
# 54         Eugraphe HÜBNER, 1821   sigma (DEN. & SCHIFF., 1775)  0      ex
# 55  Protolampra MCDUNNOUGH, 1929      sobrina (DUPONCHEL, 1843)  0      ex
#
#       Vor_1990 1990_2017 Trend_kurz  Habitat  D BB   GS  \
# ...

# %%
final["BE"].unique()
# Out:
# array(['0'], dtype=object)

# %%
# Update export location
# Export the final collated csv
final.to_csv('../../../Transformation/Raw_csv/Butterflies_and_moths_final.csv', 
                index=False)
