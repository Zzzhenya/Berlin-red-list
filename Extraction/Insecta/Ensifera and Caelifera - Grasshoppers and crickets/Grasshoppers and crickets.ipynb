# %%
import camelot
import pandas as pd

# %% [markdown]
# # Updated Process

# %% [markdown]
# ## 1. Create empty dataframe with proper column names

# %%
# This is where data will be added after cleaning. The final dataframe for export

# %%
df = pd.DataFrame(columns = [
    "Wissenschaftlicher_Name",
    "BE", 
    "BB", 
    "DE", 
    "GS",
    "H",
    "Vorzugs-habitate ",
    "Biol_ökol_Typ",
    "Gefährdungsursachen"
])
df
# Out:
# Empty DataFrame
# Columns: [Wissenschaftlicher_Name, BE, BB, DE, GS, H, Vorzugs-habitate , Biol_ökol_Typ, Gefährdungsursachen]
# Index: []

# %%
df.shape
# Out:
# (0, 9)

# %% [markdown]
# ## 2. Setup mechanism to store accuracy report : QA step

# %%
accuracy = []

# %% [markdown]
# ## 3. Dictionary of dataframes on the go

# %%
# Dictionary to collect dataframes created from each table
d = {}

# %% [markdown]
# ## 4. Adding the list of pages to be parsed

# %%
pages = []
i = 8
while i < 12:
    pages.append(i)
    i = i + 1
print(pages)
# Out:
# [8, 9, 10, 11]

# %% [markdown]
# ## 5. Parsing through the pages

# %%
for i in pages:
    # print page number
    print (i)
    # create dataframe with page number
    d[i] = pd.DataFrame()
    #read the page
    tables = camelot.read_pdf('16_heuschreck_print.pdf', 
                              pages= str(i), 
                              flavor='lattice')
                              #edge_tol=1000, row_tol=10)
    # add the accuracy report
    accuracy.append(tables[0].parsing_report)
    # assign the first table to a dataframe
    d[i] = tables[0].df
    # check for rows with "ex" column 2 and get a list of indices for those rows
# ex_index = d[i][(d[i].iloc[:,1] == "0")].index #| (d[i].iloc[:,3] == "ex") ].index
    # only keep the rows if the index is in the ex_index
#    d[i] = d[i][(d[i].index.isin(ex_index))]
    # print the shape of the dataframe 
    # (check whether there are enough columns, if not change page reading parameters
    print(d[i].shape)
# Print Done once all pages are parsed
print ("Done")
# Out:
# 8
# (6, 9)
# 9
# (17, 9)
# 10
# (16, 9)
# 11
# (17, 9)
# Done

# %%
d[8] = d[8].drop([0], axis=0)
d[8]
# Out:
#                                                    0  1  2  3   4  5  \
# 1  Arcyptera microptera (FISCHER \nVON WALDHEIM)*...  0  0  0  §§  -
# 2  Calliptamus italicus (LINNAEUS)* \nItalienisch...  0  1  1   §  -
# 3  Chorthippus albomarginatus (DE \nGEER) \nWeißr...  -  -  -      h
# 4  Chorthippus apricarius (LINNAEUS) \nFeld-Grash...  -  -  V      h
# 5  Chorthippus biguttulus (LINNAEUS) \nNachtigall...  -  -  -      h
#
#                   6             7 8
# 1             GT, H           xer
# 2        GT, H, LBS           xer
# 3             RS, G
# 4  RS, GA, \nGM, WG  (xer), \nmes
# 5     GT, GZ, \nWGT         (xer)

# %%
d[9] = d[9].drop([0], axis=0)
d[9]
# Out:
#                                                     0  1  2  3   4   5  \
# 1   Chorthippus brunneus (THUN-\nBERG) \nBrauner G...  -  -  -      sh
# 2   Chorthippus dorsatus (ZET-\nTERSTEDT)  \nWiese...  -  -  -       h
# 3   Chorthippus mollis (CHARPENTIER) \nVerkannter ...  -  -  V       h
# 4   Chorthippus montanus (CHARPEN-\nTIER)* \nSumpf...  2  3  V       s
# 5   Chorthippus parallelus (ZET-\nTERSTEDT) \nGeme...  -  -  -       h
# 6   Chorthippus pullus (PHILIPPI)* \nKiesbank-Gras...  1  1  1      ss
# 7   Chorthippus vagans (EVERS-\nMANN)* \nSteppengr...  1  2  3
# 8   Chrysochraon dispar (GERMAR) \nGroße Goldschrecke  -  -  -       h
# 9   Conocephalus dorsalis (LATREIL-\nLE) \nKurzflü...  V  -  V      mh
# 10  Conocephalus fuscus (THUNBERG) \nLangflüglige ...  -  -  -       h
# 11   Decticus verrucivorus (LINNAEUS)* \nWarzenbeißer  1  V  3      ss
# 12       Gampsocleis glabra (HERBST)* \nHeideschrecke  0  0  1  §§   -
# 13  Gryllotalpa gryllotalpa (LINNAEUS)* \nMaulwurf...  G  V  2       s
# 14          Gryllus campestris LINNAEUS* \nFeldgrille  1  V  3      ss
# 15  Leptophyes punctatissima (BOSC) \nPunktierte Z...  -  -  -       h
# 16  Meconema thalassinum (DE \nGEER) \nGemeine Eic...  -  -  -      mh
#
#                                6           7                          8
# 1   RR, GT, H, \nO, LBS, PS, \nA         xer
# 2               GA, GF, \nGM, GT
# 3                     GT, GAT, H         xer
# 4                     M, GF, GAF         hyg     2d, 6b, 7b, \n14a, 14e
# 5           GM, GA, GI, \nGZ, LB
# 6                      GT, H, WR         xer             7a, 13a, \n14e
# 7        ss  WK, GTS, \nWGT, ATK         xer  7a, 11, \n12a, 14a, \n14e
# 8               RSC, M, \nGF, GA       (hyg)
# 9               FR, SR, M, \nGAF         hyg                2d, 6b, 14a
# 10           RS, GAM, \nGAF, MEP
# 11                 GT, GM, \nLBS         xer                7a, 7b, 14e
# 12                         GT, H         xer
# 13                       G, M; P  hyg, \nmes                 2d, 4b, 6a
# 14                         GT, H         xer          7a, 8a, 11, \n13a
# 15          B, WG, P, \nGSM, GAF
# 16                       B, W, P

# %%
d[10] = d[10].drop([0], axis=0)
d[10]
# Out:
#                                                     0  1  2  3   4  \
# 1   Metrioptera bicolor (PHILIPPI) \nZweifarbige B...  V  3  -
# 2   Metrioptera brachyptera (LIN-\nNAEUS)* \nKurzf...  0  2  -
# 3   Metrioptera roeselii (HAGENBACH) \nRoesels Bei...  -  -  -
# 4   Myrmecophilus acervorum (PAN-\nZER) \nAmeiseng...  -  G  D
# 5   Myrmeleotettix maculatus (THUN-\nBERG) \nGefle...  V  -  -
# 6            Nemobius sylvestris (BOSC)* \nWaldgrille  G  V  -
# 7   Oedipoda caerulescens (LIN-\nNAEUS) \nBlauflüg...  V  -  3   §
# 8   Omocestus haemorrhoidalis \n(CHARPENTIER) \nRo...  V  -  V
# 9   Omocestus viridulus (LINNAEUS)* \nBunter Grash...  2  V  -
# 10  Pholidoptera griseoaptera (DE \nGEER) \nGewöhn...  -  -  -
# 11  Platycleis albopunctata (GOEZE) \nWestliche Be...  V  -  V
# 12  Platycleis montana (KOLLAR)* \nSteppen-Beißsch...  0  1  1  §§
# 13  Psophus stridulus (LINNAEUS)* \nRotflüglige Sc...  0  1  2   §
# 14  Sphingonotus caerulans (LIN-\nNAEUS)* \nBlaufl...  1  3  2   §
# 15  Stauroderus scalaris (FISCHER \nVON WALDHEIM)*...  0  0  2
#
#               5                           6           7  \
# 1    mh  GT, H,             RSA, RSC, \nGAT         xer
# 2             -                       M, GF         hyg
# 3             h            RS, GF, \nGM, GA
# 4                           mh  GT, H, R, O         par
# 5     mh  GT, H                                     xer
# 6             s                       B, WT  xer, \nmes
# 7   mh  GTS, H,               OVG, OAA, \nA         xer
# 8                         mh  GTS, GAT, \nH         xer
# 9             s                       M, GF         hyg
# 10                            mh  WG, B, GA
# 11                           mh  GT, H, ADO         xer
# 12            -                       GT, H         xer
# 13            -                       GT, H         xer
# 14           ss  GTS, AT, \nRRS, OAA, \nATK         xer
# 15            -                       GT, H         xer
#
#                                  8
# 1            1a, 7, 8a, \n13a, 14e
# 2
# 3
# 4
# 5                               7a
# 6                         11b, 13a
# 7    1a, 7a, 8a, \n12a, 13a, \n14e
# 8               1a, 7a, \n13a, 14e
# 9                      2d, 7b, 14e
# 10
# 11                    2, 7, 8, 13a
# 12
# 13
# 14  7a, 8a, \n12a, 13a, \n14a, 14e
# 15                          1a, 7a

# %%
d[11] = d[11].drop([0], axis=0)
d[11]
# Out:
#                                                     0   1   2   3 4  \
# 1   Stenobothrus lineatus (PANZER)* \nHeidegrashüpfer   3   3   V
# 2   Stenobothrus nigromaculatus \n(HERRICH-SCHÄFFE...   0   1   2
# 3   Stenobothrus stigmaticus (RAM-\nBUR)* \nKleine...   1   1   2
# 4      Stethophyma grossum (LINNAEUS) \nSumpfschrecke   V   V   -
# 5      Tetrix subulata (LINNAEUS) \nSäbeldornschrecke   -   -   -
# 6   Tetrix tenuicornis (SAHLBERG)* \nLangfühler-Do...   G   G   -
# 7    Tetrix undulata (SOWERBY) \nGemeine Dornschrecke   -   -   -
# 8   Tettigonia cantans (FUESSLY)* \nZwitscherschrecke   1   3   -
# 9   Tettigonia caudata (CHARPEN-\nTIER)* \nÖstlich...   1   V   -
# 10  Tettigonia viridissima LINNAEUS \nGrünes Heupferd   -   -   -
# 11  Nicht etablierte oder nicht im Freiland etabli...
# 12            Acheta domesticus (LINNAEUS) \nHeimchen  ne   -  ne
# 13  Anacridium aegyptium (LIN-\nNAEUS)* \nÄgyptisc...  ne  ne  ne
# 14  Barbitistes serricauda (FABRICUS)* \nLaubholz-...  ne  ne   -
# 15  Leptophyes albovittata (KOLLAR)* \nGestreifte ...  ne   R   -
# 16  Locusta migratoria LINNAEUS* \nEuropäische Wan...  ne  ne   0
#
#             5                              6    7                      8
# 1   mh  GT, H                                 xer                     7a
# 2           -                          GT, H  xer
# 3           -                             GT  xer
# 4          mh               FR, M, GF, \nGAF  hyg             2d, 6b, 7b
# 5          mh         FP, GF, \nGAF, M, \nSW  hyg
# 6           s                      GT, H, AT  xer     7, 11a, \n13a, 14e
# 7          mh            FP, RR, G, \nAT, SW
# 8          ss                GA, GS, \nWG, B  hyg  2a, 2d, 6a, \n6b, 14e
# 9          ss                     GA, GS, RS  xer            1c, 2a, 14e
# 10          h  B, GA, GS, \nLB, P, RSB, \nWG
# 11
# 12                                            syn
# 13          -                                 syn
# 14          -
# 15          -
# 16          -

# %%
# Check accuracy reports for the process
accuracy
# Out:
# [{'accuracy': 100.0, 'whitespace': 16.67, 'order': 1, 'page': 8},
#  {'accuracy': 99.86, 'whitespace': 19.61, 'order': 1, 'page': 9},
#  {'accuracy': 98.35, 'whitespace': 16.67, 'order': 1, 'page': 10},
#  {'accuracy': 99.15, 'whitespace': 29.41, 'order': 1, 'page': 11}]

# %% [markdown]
# # Data cleanup steps

# %% [raw]
# d[67]
#     : Look at the data frame extracted from 67th page
# d[67].shape
#     : Look at the shape of the dataframe
# d[68] = d[68].drop([12], axis=1)
#     : Drop the 12th column in place
# d[68][10] = d[68][[10, 11]].agg(' '.join, axis=1)
#     : Join 10th and 11th columns with a space in between
# d[69][[9,11]] = d[69][9].str.split('\n', expand=True)
#     : Split 9th Column at the '\n' sign and add a new column called 11
# column_to_move = d[69].pop(11)
# column_to_move
# d[69].insert(9, 11, column_to_move )
#     : Pop column 11 and insert it at column 9
# d[75].insert(9, '10', ["",""])
#     : Insert two rows of column 10 after 9 with empty cells

# %%
# Check whether all dataframes are of the same size
for key in d:
    print(key)
    print(d[key].shape)
# Out:
# 8
# (5, 9)
# 9
# (16, 9)
# 10
# (15, 9)
# 11
# (16, 9)

# %%
# Removing empty dataframes
# del d[64]
# del d[74]

# %%
# Creates a sorted dictionary (sorted by key)
from collections import OrderedDict
d2 = OrderedDict(sorted(d.items()))

# %%
# Check whether the dictionary is sorted
for key in d2:
    print(key)
# Out:
# 8
# 9
# 10
# 11

# %%
# Rename all the dataframes in the sorted dictionary
for key in d2:
    print(key)
    d2[key].columns = [ "Wissenschaftlicher_Name",
    "BE", 
    "BB", 
    "DE", 
    "GS",
    "H",
    "Vorzugs-habitate ",
    "Biol_ökol_Typ",
    "Gefährdungsursachen"]
print("Rename completed for concat")
# Out:
# 8
# 9
# 10
# 11
# Rename completed for concat

# %%
# Concatanate all the non-empty dataframes in the sorted dictionary into the empty df
for key in d2:
    df = pd.concat([df, d2[key]], axis = 0)
df
# Out:
#                               Wissenschaftlicher_Name  BE  BB  DE  GS  \
# 1   Arcyptera microptera (FISCHER \nVON WALDHEIM)*...   0   0   0  §§
# 2   Calliptamus italicus (LINNAEUS)* \nItalienisch...   0   1   1   §
# 3   Chorthippus albomarginatus (DE \nGEER) \nWeißr...   -   -   -
# 4   Chorthippus apricarius (LINNAEUS) \nFeld-Grash...   -   -   V
# 5   Chorthippus biguttulus (LINNAEUS) \nNachtigall...   -   -   -
# 1   Chorthippus brunneus (THUN-\nBERG) \nBrauner G...   -   -   -
# 2   Chorthippus dorsatus (ZET-\nTERSTEDT)  \nWiese...   -   -   -
# 3   Chorthippus mollis (CHARPENTIER) \nVerkannter ...   -   -   V
# 4   Chorthippus montanus (CHARPEN-\nTIER)* \nSumpf...   2   3   V
# 5   Chorthippus parallelus (ZET-\nTERSTEDT) \nGeme...   -   -   -
# 6   Chorthippus pullus (PHILIPPI)* \nKiesbank-Gras...   1   1   1
# 7   Chorthippus vagans (EVERS-\nMANN)* \nSteppengr...   1   2   3
# 8   Chrysochraon dispar (GERMAR) \nGroße Goldschrecke   -   -   -
# 9   Conocephalus dorsalis (LATREIL-\nLE) \nKurzflü...   V   -   V
# 10  Conocephalus fuscus (THUNBERG) \nLangflüglige ...   -   -   -
# 11   Decticus verrucivorus (LINNAEUS)* \nWarzenbeißer   1   V   3
# 12       Gampsocleis glabra (HERBST)* \nHeideschrecke   0   0   1  §§
# 13  Gryllotalpa gryllotalpa (LINNAEUS)* \nMaulwurf...   G   V   2
# 14          Gryllus campestris LINNAEUS* \nFeldgrille   1   V   3
# 15  Leptophyes punctatissima (BOSC) \nPunktierte Z...   -   -   -
# 16  Meconema thalassinum (DE \nGEER) \nGemeine Eic...   -   -   -
# 1   Metrioptera bicolor (PHILIPPI) \nZweifarbige B...   V   3   -
# 2   Metrioptera brachyptera (LIN-\nNAEUS)* \nKurzf...   0   2   -
# 3   Metrioptera roeselii (HAGENBACH) \nRoesels Bei...   -   -   -
# 4   Myrmecophilus acervorum (PAN-\nZER) \nAmeiseng...   -   G   D
# 5   Myrmeleotettix maculatus (THUN-\nBERG) \nGefle...   V   -   -
# 6            Nemobius sylvestris (BOSC)* \nWaldgrille   G   V   -
# 7   Oedipoda caerulescens (LIN-\nNAEUS) \nBlauflüg...   V   -   3   §
# 8   Omocestus haemorrhoidalis \n(CHARPENTIER) \nRo...   V   -   V
# 9   Omocestus viridulus (LINNAEUS)* \nBunter Grash...   2   V   -
# 10  Pholidoptera griseoaptera (DE \nGEER) \nGewöhn...   -   -   -
# 11  Platycleis albopunctata (GOEZE) \nWestliche Be...   V   -   V
# 12  Platycleis montana (KOLLAR)* \nSteppen-Beißsch...   0   1   1  §§
# 13  Psophus stridulus (LINNAEUS)* \nRotflüglige Sc...   0   1   2   §
# 14  Sphingonotus caerulans (LIN-\nNAEUS)* \nBlaufl...   1   3   2   §
# 15  Stauroderus scalaris (FISCHER \nVON WALDHEIM)*...   0   0   2
# 1   Stenobothrus lineatus (PANZER)* \nHeidegrashüpfer   3   3   V
# 2   Stenobothrus nigromaculatus \n(HERRICH-SCHÄFFE...   0   1   2
# 3   Stenobothrus stigmaticus (RAM-\nBUR)* \nKleine...   1   1   2
# 4      Stethophyma grossum (LINNAEUS) \nSumpfschrecke   V   V   -
# 5      Tetrix subulata (LINNAEUS) \nSäbeldornschrecke   -   -   -
# 6   Tetrix tenuicornis (SAHLBERG)* \nLangfühler-Do...   G   G   -
# 7    Tetrix undulata (SOWERBY) \nGemeine Dornschrecke   -   -   -
# 8   Tettigonia cantans (FUESSLY)* \nZwitscherschrecke   1   3   -
# 9   Tettigonia caudata (CHARPEN-\nTIER)* \nÖstlich...   1   V   -
# 10  Tettigonia viridissima LINNAEUS \nGrünes Heupferd   -   -   -
# 11  Nicht etablierte oder nicht im Freiland etabli...
# 12            Acheta domesticus (LINNAEUS) \nHeimchen  ne   -  ne
# 13  Anacridium aegyptium (LIN-\nNAEUS)* \nÄgyptisc...  ne  ne  ne
# 14  Barbitistes serricauda (FABRICUS)* \nLaubholz-...  ne  ne   -
# 15  Leptophyes albovittata (KOLLAR)* \nGestreifte ...  ne   R   -
# 16  Locusta migratoria LINNAEUS* \nEuropäische Wan...  ne  ne   0
#
#               H              Vorzugs-habitate  Biol_ökol_Typ  \
# 1             -                          GT, H           xer
# 2             -                     GT, H, LBS           xer
# 3             h                          RS, G
# 4             h               RS, GA, \nGM, WG  (xer), \nmes
# 5             h                  GT, GZ, \nWGT         (xer)
# 1            sh   RR, GT, H, \nO, LBS, PS, \nA           xer
# 2             h               GA, GF, \nGM, GT
# 3             h                     GT, GAT, H           xer
# 4             s                     M, GF, GAF           hyg
# 5             h           GM, GA, GI, \nGZ, LB
# 6            ss                      GT, H, WR           xer
# 7                      ss  WK, GTS, \nWGT, ATK           xer
# 8             h               RSC, M, \nGF, GA         (hyg)
# 9            mh               FR, SR, M, \nGAF           hyg
# 10            h            RS, GAM, \nGAF, MEP
# 11           ss                  GT, GM, \nLBS           xer
# 12            -                          GT, H           xer
# 13            s                        G, M; P    hyg, \nmes
# 14           ss                          GT, H           xer
# 15            h           B, WG, P, \nGSM, GAF
# 16           mh                        B, W, P
# 1    mh  GT, H,                RSA, RSC, \nGAT           xer
# 2             -                          M, GF           hyg
# 3             h               RS, GF, \nGM, GA
# 4                              mh  GT, H, R, O           par
# 5     mh  GT, H                                          xer
# 6             s                          B, WT    xer, \nmes
# 7   mh  GTS, H,                  OVG, OAA, \nA           xer
# 8                            mh  GTS, GAT, \nH           xer
# 9             s                          M, GF           hyg
# 10                               mh  WG, B, GA
# 11                              mh  GT, H, ADO           xer
# 12            -                          GT, H           xer
# 13            -                          GT, H           xer
# 14           ss     GTS, AT, \nRRS, OAA, \nATK           xer
# 15            -                          GT, H           xer
# 1     mh  GT, H                                          xer
# 2             -                          GT, H           xer
# 3             -                             GT           xer
# 4            mh               FR, M, GF, \nGAF           hyg
# 5            mh         FP, GF, \nGAF, M, \nSW           hyg
# 6             s                      GT, H, AT           xer
# 7            mh            FP, RR, G, \nAT, SW
# 8            ss                GA, GS, \nWG, B           hyg
# 9            ss                     GA, GS, RS           xer
# 10            h  B, GA, GS, \nLB, P, RSB, \nWG
# 11
# 12                                                       syn
# 13            -                                          syn
# 14            -
# 15            -
# 16            -
#
#                Gefährdungsursachen
# 1
# 2
# 3
# 4
# 5
# 1
# 2
# 3
# 4           2d, 6b, 7b, \n14a, 14e
# 5
# 6                   7a, 13a, \n14e
# 7        7a, 11, \n12a, 14a, \n14e
# 8
# 9                      2d, 6b, 14a
# 10
# 11                     7a, 7b, 14e
# 12
# 13                      2d, 4b, 6a
# 14               7a, 8a, 11, \n13a
# 15
# 16
# 1            1a, 7, 8a, \n13a, 14e
# 2
# 3
# 4
# 5                               7a
# 6                         11b, 13a
# 7    1a, 7a, 8a, \n12a, 13a, \n14e
# 8               1a, 7a, \n13a, 14e
# 9                      2d, 7b, 14e
# 10
# 11                    2, 7, 8, 13a
# 12
# 13
# 14  7a, 8a, \n12a, 13a, \n14a, 14e
# 15                          1a, 7a
# 1                               7a
# 2
# 3
# 4                       2d, 6b, 7b
# 5
# 6               7, 11a, \n13a, 14e
# 7
# 8            2a, 2d, 6a, \n6b, 14e
# 9                      1c, 2a, 14e
# 10
# 11
# 12
# 13
# 14
# 15
# 16

# %%
df.describe()
# Out:
#                                   Wissenschaftlicher_Name  BE  BB  DE  GS   H  \
# count                                                  52  52  52  52  52  52
# unique                                                 52   9  10   9   3  10
# top     Arcyptera microptera (FISCHER \nVON WALDHEIM)*...   -   -   -       -
# freq                                                    1  17  22  25  45  13
#
#        Vorzugs-habitate  Biol_ökol_Typ Gefährdungsursachen
# count                 52            52                  52
# unique                38            10                  21
# top                                xer
# freq                   8            23                  31

# %%
df2 = df.loc[df["BE"] == "0"]
df2
# Out:
#                               Wissenschaftlicher_Name BE BB DE  GS  H  \
# 1   Arcyptera microptera (FISCHER \nVON WALDHEIM)*...  0  0  0  §§  -
# 2   Calliptamus italicus (LINNAEUS)* \nItalienisch...  0  1  1   §  -
# 12       Gampsocleis glabra (HERBST)* \nHeideschrecke  0  0  1  §§  -
# 2   Metrioptera brachyptera (LIN-\nNAEUS)* \nKurzf...  0  2  -      -
# 12  Platycleis montana (KOLLAR)* \nSteppen-Beißsch...  0  1  1  §§  -
# 13  Psophus stridulus (LINNAEUS)* \nRotflüglige Sc...  0  1  2   §  -
# 15  Stauroderus scalaris (FISCHER \nVON WALDHEIM)*...  0  0  2      -
# 2   Stenobothrus nigromaculatus \n(HERRICH-SCHÄFFE...  0  1  2      -
#
#    Vorzugs-habitate  Biol_ökol_Typ Gefährdungsursachen
# 1              GT, H           xer
# 2         GT, H, LBS           xer
# 12             GT, H           xer
# 2              M, GF           hyg
# 12             GT, H           xer
# 13             GT, H           xer
# 15             GT, H           xer              1a, 7a
# 2              GT, H           xer

# %%
df2.reset_index(inplace = True)
df2 = df2.drop(['index'], axis=1)
df2
# Out:
#                              Wissenschaftlicher_Name BE BB DE  GS  H  \
# 0  Arcyptera microptera (FISCHER \nVON WALDHEIM)*...  0  0  0  §§  -
# 1  Calliptamus italicus (LINNAEUS)* \nItalienisch...  0  1  1   §  -
# 2       Gampsocleis glabra (HERBST)* \nHeideschrecke  0  0  1  §§  -
# 3  Metrioptera brachyptera (LIN-\nNAEUS)* \nKurzf...  0  2  -      -
# 4  Platycleis montana (KOLLAR)* \nSteppen-Beißsch...  0  1  1  §§  -
# 5  Psophus stridulus (LINNAEUS)* \nRotflüglige Sc...  0  1  2   §  -
# 6  Stauroderus scalaris (FISCHER \nVON WALDHEIM)*...  0  0  2      -
# 7  Stenobothrus nigromaculatus \n(HERRICH-SCHÄFFE...  0  1  2      -
#
#   Vorzugs-habitate  Biol_ökol_Typ Gefährdungsursachen
# 0             GT, H           xer
# 1        GT, H, LBS           xer
# 2             GT, H           xer
# 3             M, GF           hyg
# 4             GT, H           xer
# 5             GT, H           xer
# 6             GT, H           xer              1a, 7a
# 7             GT, H           xer

# %%
df2.describe()
# Out:
#                                   Wissenschaftlicher_Name BE BB DE  GS  H  \
# count                                                   8  8  8  8   8  8
# unique                                                  8  1  3  4   3  1
# top     Arcyptera microptera (FISCHER \nVON WALDHEIM)*...  0  1  1  §§  -
# freq                                                    1  8  4  3   3  8
#
#        Vorzugs-habitate  Biol_ökol_Typ Gefährdungsursachen
# count                  8             8                   8
# unique                 3             2                   2
# top                GT, H           xer
# freq                   6             7                   7

# %%
# updated export location
# export the dataframe as CSV
df2.to_csv('../../../Transformation/Raw_csv/Grasshoppers_crickets.csv', 
           index=False)
