# %%
import camelot
import pandas as pd

# %% [markdown]
# ### 1. Read the pages with tables in stream format

# %%
# Using 'stream' as the table has colours as row seperators, a lot of white space and inconsistencies 
# in row height.

tables = camelot.read_pdf('Maerkische-Ent-Nachr_SH_7_0109-0122.pdf', pages='2', flavor='stream', edge_tol=500, row_tol=10)

#display parsed area
camelot.plot(tables[0], kind='contour').show()
# Out:
# /var/folders/sf/pjcpsvqj67b_pqmm82g4y8bm0000gq/T/ipykernel_96779/3071328541.py:7: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   camelot.plot(tables[0], kind='contour').show()

# %%
# The number of tables
tables
# Out:
# <TableList n=2>

# %%
# Export multiple tables as foo.csv : Don't need to do this
# tables.export('foo.csv', f='csv')

# %%
# Check out the shape of each table
tables[1]
# Out:
# <Table shape=(14, 8)>

# %%
# print the parsing report
tables[0].parsing_report
# Out:
# {'accuracy': 65.38, 'whitespace': 29.41, 'order': 1, 'page': 2}

# %%
# Convert each table to separate csv files : Don't need to do this
# tables[0].to_csv('foo.csv')

# %% [markdown]
# ### 2. Assign table to dataframe : manual

# %%
df_1 = tables[1].df
df_1
# Out:
#        0                                       1            2             3  \
# 0                                                              Nachweise in
# 1                                                                Berlin bis
# 2                                                                      1989
# 3   Lfd.                                                          ( letzter
# 4    Nr.                                     Art  Brandenburg     Nachweis)
# 5                         Narycia STEPHENS, 1836            ●             X
# 6      1                duplicella (GOEZE, 1783)
# 7                         Diplodoma ZELLER, 1852            ●             X
# 8      2  laichartingella (GOEZE, 1783) (Abb. 1)
# 9                        Dahlica ENDERLEIN, 1912
# 10           triquetrella (HÜBNER, 1813) (parth.            ●             X
# 11     3                          form) (Abb. 2)
# 12           lichenella (LINNAEUS, 1761) (parth.            ●             X
# ...

# %%
df_1.drop([0,1,2,3], axis=0, inplace=True)
df_1
# Out:
#       0                                       1            2          3     4  \
# 4   Nr.                                     Art  Brandenburg  Nachweis)  2022
# 5                        Narycia STEPHENS, 1836            ●          X     X
# 6     1                duplicella (GOEZE, 1783)
# 7                        Diplodoma ZELLER, 1852            ●          X    X*
# 8     2  laichartingella (GOEZE, 1783) (Abb. 1)
# 9                       Dahlica ENDERLEIN, 1912
# 10          triquetrella (HÜBNER, 1813) (parth.            ●          X     X
# 11    3                          form) (Abb. 2)
# 12          lichenella (LINNAEUS, 1761) (parth.            ●          X    X*
# 13    4                                   form)
#
#             5    6    7
# 4     Habitat  Nr.  Nr.
# 5   BuW,FW,WS    4
# 6                   751
# 7      BuW,FW    7
# 8                   747
# 9
# 10          U   10  762
# 11
# 12     BuW,FW
# 13              11  765

# %%
tables = camelot.read_pdf('Maerkische-Ent-Nachr_SH_7_0109-0122.pdf', pages='3', flavor='stream', edge_tol=500, row_tol=10)

#display parsed area
camelot.plot(tables[0], kind='contour').show()
# Out:
# /var/folders/sf/pjcpsvqj67b_pqmm82g4y8bm0000gq/T/ipykernel_96779/2251157493.py:4: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   camelot.plot(tables[0], kind='contour').show()

# %%
tables
# Out:
# <TableList n=1>

# %%
tables[0]
# Out:
# <Table shape=(30, 8)>

# %%
tables[0].parsing_report
# Out:
# {'accuracy': 99.51, 'whitespace': 42.5, 'order': 1, 'page': 3}

# %%
df_2 = tables[0].df
df_2
# Out:
#                                       0                                     1  \
# 0   Märkische Ent. Nachr., Sonderheft 7
# 1                                     5           listerella (LINNAEUS, 1758)
# 2                                                       Taleporia HÜBNER,1825
# 3                                     6              tubulosa (RETZIUS, 1783)
# 4                                                        Psyche Schrank, 1801
# 5                                     7                  casta (PALLAS, 1767)
# 6                                     8           crassiorella (BRUAND, 1850)
# 7                                                          Proutia TUTT, 1899
# 8                                     9              betulina  (ZELLER, 1839)
# 9                                                          Bacotia TUTT, 1899
# 10                                   10   claustrella (BRUAND, 1845) (Abb. 3)
# ...

# %%
df_2.drop([0], axis=0, inplace=True)
df_2
# Out:
#      0                                     1  2        3   4          5    6  \
# 1    5           listerella (LINNAEUS, 1758)  ●        X   X         KW   65
# 2                      Taleporia HÜBNER,1825  ●        X   X          U
# 3    6              tubulosa (RETZIUS, 1783)                              77
# 4                       Psyche Schrank, 1801  ●        X   X          U
# 5    7                  casta (PALLAS, 1767)                             116
# 6    8           crassiorella (BRUAND, 1850)  ●        X  X*         TR  117
# 7                         Proutia TUTT, 1899  ●        X   X      FW,WS
# 8    9              betulina  (ZELLER, 1839)                             119
# 9                         Bacotia TUTT, 1899  ●        X   X      FW,WS
# 10  10   claustrella (BRUAND, 1845) (Abb. 3)                             128
# 11                Epichnopterix HÜBNER, 1825                   MGL,MW,W
# ...

# %%
df_1.shape
# Out:
# (10, 8)

# %%
df_2.shape
# Out:
# (29, 8)

# %%
df = pd.concat([df_1, df_2], axis = 0)
df
# Out:
#       0                                       1            2          3     4  \
# 4   Nr.                                     Art  Brandenburg  Nachweis)  2022
# 5                        Narycia STEPHENS, 1836            ●          X     X
# 6     1                duplicella (GOEZE, 1783)
# 7                        Diplodoma ZELLER, 1852            ●          X    X*
# 8     2  laichartingella (GOEZE, 1783) (Abb. 1)
# 9                       Dahlica ENDERLEIN, 1912
# 10          triquetrella (HÜBNER, 1813) (parth.            ●          X     X
# 11    3                          form) (Abb. 2)
# 12          lichenella (LINNAEUS, 1761) (parth.            ●          X    X*
# 13    4                                   form)
# 1     5             listerella (LINNAEUS, 1758)            ●          X     X
# 2                         Taleporia HÜBNER,1825            ●          X     X
# 3     6                tubulosa (RETZIUS, 1783)
# ...

# %%
df = df.loc[(df[3] != 'X') & (df[3] != '')]
df
# Out:
#       0                                  1            2          3     4  \
# 4   Nr.                                Art  Brandenburg  Nachweis)  2022
# 14   12           sieboldii (REUTTI, 1853)            ●       1965    -*
# 15           Acanthopsyche HEYLAERTS, 1881            ●       1982    -*
# 19              Pachythelia WESTWOOD, 1848            ●       1963    -*
# 21             Phalacropterix HÜBNER, 1825            ●    um 1900    -*
# 24       viciella (DENIS & SCHIFFERMÜLLER,            ●       1966    -*
#
#            5    6    7
# 4    Habitat  Nr.  Nr.
# 14     CB,TR  139  932
# 15  CB,WS,ZM
# 19  CB,TR,ZM
# 21     CB,ZM
# 24    MGL,NM  234  999

# %%
df.drop([0], axis=1, inplace=True)
df
# Out:
# /var/folders/sf/pjcpsvqj67b_pqmm82g4y8bm0000gq/T/ipykernel_96779/3158899764.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop([0], axis=1, inplace=True)
#                                     1            2          3     4         5  \
# 4                                 Art  Brandenburg  Nachweis)  2022   Habitat
# 14           sieboldii (REUTTI, 1853)            ●       1965    -*     CB,TR
# 15      Acanthopsyche HEYLAERTS, 1881            ●       1982    -*  CB,WS,ZM
# 19         Pachythelia WESTWOOD, 1848            ●       1963    -*  CB,TR,ZM
# 21        Phalacropterix HÜBNER, 1825            ●    um 1900    -*     CB,ZM
# 24  viciella (DENIS & SCHIFFERMÜLLER,            ●       1966    -*    MGL,NM
#
#       6    7
# 4   Nr.  Nr.
# 14  139  932
# 15
# 19
# 21
# 24  234  999

# %%
df
# Out:
#                                     1            2          3     4         5  \
# 4                                 Art  Brandenburg  Nachweis)  2022   Habitat
# 14           sieboldii (REUTTI, 1853)            ●       1965    -*     CB,TR
# 15      Acanthopsyche HEYLAERTS, 1881            ●       1982    -*  CB,WS,ZM
# 19         Pachythelia WESTWOOD, 1848            ●       1963    -*  CB,TR,ZM
# 21        Phalacropterix HÜBNER, 1825            ●    um 1900    -*     CB,ZM
# 24  viciella (DENIS & SCHIFFERMÜLLER,            ●       1966    -*    MGL,NM
#
#       6    7
# 4   Nr.  Nr.
# 14  139  932
# 15
# 19
# 21
# 24  234  999

# %%
df.reset_index(inplace = True, drop = True)

# %%
df
# Out:
#                                    1            2          3     4         5  \
# 0                                Art  Brandenburg  Nachweis)  2022   Habitat
# 1           sieboldii (REUTTI, 1853)            ●       1965    -*     CB,TR
# 2      Acanthopsyche HEYLAERTS, 1881            ●       1982    -*  CB,WS,ZM
# 3         Pachythelia WESTWOOD, 1848            ●       1963    -*  CB,TR,ZM
# 4        Phalacropterix HÜBNER, 1825            ●    um 1900    -*     CB,ZM
# 5  viciella (DENIS & SCHIFFERMÜLLER,            ●       1966    -*    MGL,NM
#
#      6    7
# 0  Nr.  Nr.
# 1  139  932
# 2
# 3
# 4
# 5  234  999

# %%
df.columns=df.iloc[0]

# %%
df
# Out:
# 0                                Art  Brandenburg  Nachweis)  2022   Habitat  \
# 0                                Art  Brandenburg  Nachweis)  2022   Habitat
# 1           sieboldii (REUTTI, 1853)            ●       1965    -*     CB,TR
# 2      Acanthopsyche HEYLAERTS, 1881            ●       1982    -*  CB,WS,ZM
# 3         Pachythelia WESTWOOD, 1848            ●       1963    -*  CB,TR,ZM
# 4        Phalacropterix HÜBNER, 1825            ●    um 1900    -*     CB,ZM
# 5  viciella (DENIS & SCHIFFERMÜLLER,            ●       1966    -*    MGL,NM
#
# 0  Nr.  Nr.
# 0  Nr.  Nr.
# 1  139  932
# 2
# 3
# 4
# 5  234  999

# %%
df = df.drop([0], axis=0)
df
# Out:
# 0                                Art Brandenburg Nachweis) 2022   Habitat  \
# 1           sieboldii (REUTTI, 1853)           ●      1965   -*     CB,TR
# 2      Acanthopsyche HEYLAERTS, 1881           ●      1982   -*  CB,WS,ZM
# 3         Pachythelia WESTWOOD, 1848           ●      1963   -*  CB,TR,ZM
# 4        Phalacropterix HÜBNER, 1825           ●   um 1900   -*     CB,ZM
# 5  viciella (DENIS & SCHIFFERMÜLLER,           ●      1966   -*    MGL,NM
#
# 0  Nr.  Nr.
# 1  139  932
# 2
# 3
# 4
# 5  234  999

# %%
df.rename(columns={'Nachweis)' : 'Nachweise in Berlin bis 1989',
                   '2022' : 'nachweise in Berlin 1990 bis 2022'
                  }, inplace = True)
df
# Out:
# 0                                Art Brandenburg Nachweise in Berlin bis 1989  \
# 1           sieboldii (REUTTI, 1853)           ●                         1965
# 2      Acanthopsyche HEYLAERTS, 1881           ●                         1982
# 3         Pachythelia WESTWOOD, 1848           ●                         1963
# 4        Phalacropterix HÜBNER, 1825           ●                      um 1900
# 5  viciella (DENIS & SCHIFFERMÜLLER,           ●                         1966
#
# 0 nachweise in Berlin 1990 bis 2022   Habitat  Nr.  Nr.
# 1                                -*     CB,TR  139  932
# 2                                -*  CB,WS,ZM
# 3                                -*  CB,TR,ZM
# 4                                -*     CB,ZM
# 5                                -*    MGL,NM  234  999

# %%
df.drop(["Nr."], axis=1, inplace=True)
df
# Out:
# 0                                Art Brandenburg Nachweise in Berlin bis 1989  \
# 1           sieboldii (REUTTI, 1853)           ●                         1965
# 2      Acanthopsyche HEYLAERTS, 1881           ●                         1982
# 3         Pachythelia WESTWOOD, 1848           ●                         1963
# 4        Phalacropterix HÜBNER, 1825           ●                      um 1900
# 5  viciella (DENIS & SCHIFFERMÜLLER,           ●                         1966
#
# 0 nachweise in Berlin 1990 bis 2022   Habitat
# 1                                -*     CB,TR
# 2                                -*  CB,WS,ZM
# 3                                -*  CB,TR,ZM
# 4                                -*     CB,ZM
# 5                                -*    MGL,NM

# %%
df
# Out:
# 0                                Art Brandenburg Nachweise in Berlin bis 1989  \
# 1           sieboldii (REUTTI, 1853)           ●                         1965
# 2      Acanthopsyche HEYLAERTS, 1881           ●                         1982
# 3         Pachythelia WESTWOOD, 1848           ●                         1963
# 4        Phalacropterix HÜBNER, 1825           ●                      um 1900
# 5  viciella (DENIS & SCHIFFERMÜLLER,           ●                         1966
#
# 0 nachweise in Berlin 1990 bis 2022   Habitat
# 1                                -*     CB,TR
# 2                                -*  CB,WS,ZM
# 3                                -*  CB,TR,ZM
# 4                                -*     CB,ZM
# 5                                -*    MGL,NM

# %%
df.drop(["nachweise in Berlin 1990 bis 2022"], axis=1, inplace=True)
df
# Out:
# 0                                Art Brandenburg Nachweise in Berlin bis 1989  \
# 1           sieboldii (REUTTI, 1853)           ●                         1965
# 2      Acanthopsyche HEYLAERTS, 1881           ●                         1982
# 3         Pachythelia WESTWOOD, 1848           ●                         1963
# 4        Phalacropterix HÜBNER, 1825           ●                      um 1900
# 5  viciella (DENIS & SCHIFFERMÜLLER,           ●                         1966
#
# 0   Habitat
# 1     CB,TR
# 2  CB,WS,ZM
# 3  CB,TR,ZM
# 4     CB,ZM
# 5    MGL,NM

# %%
df.reset_index(drop = True, inplace = True)
df
# Out:
# 0                                Art Brandenburg Nachweise in Berlin bis 1989  \
# 0           sieboldii (REUTTI, 1853)           ●                         1965
# 1      Acanthopsyche HEYLAERTS, 1881           ●                         1982
# 2         Pachythelia WESTWOOD, 1848           ●                         1963
# 3        Phalacropterix HÜBNER, 1825           ●                      um 1900
# 4  viciella (DENIS & SCHIFFERMÜLLER,           ●                         1966
#
# 0   Habitat
# 0     CB,TR
# 1  CB,WS,ZM
# 2  CB,TR,ZM
# 3     CB,ZM
# 4    MGL,NM

# %%
# Updating Art column with missing genus names
# 0 Epichnopterix sieboldii
df.at[0, "Art"] = "Epichnopterix sieboldii"
# 1 Acanthopsyche atra
df.at[1, "Art"] = "Acanthopsyche atra"
# 2 Pachythelia villosella
df.at[2, "Art"] = "Pachythelia villosella"
# 3 Phalacropterix graslinella
df.at[3, "Art"] = "Phalacropterix graslinella"
# 4 Megalophanes viciella
df.at[4, "Art"] = "Megalophanes viciella"
df
# Out:
# 0                         Art Brandenburg Nachweise in Berlin bis 1989  \
# 0     Epichnopterix sieboldii           ●                         1965
# 1          Acanthopsyche atra           ●                         1982
# 2      Pachythelia villosella           ●                         1963
# 3  Phalacropterix graslinella           ●                      um 1900
# 4       Megalophanes viciella           ●                         1966
#
# 0   Habitat
# 0     CB,TR
# 1  CB,WS,ZM
# 2  CB,TR,ZM
# 3     CB,ZM
# 4    MGL,NM

# %%
# Updated the export location
# export the dataframe as CSV
df.to_csv('../../../Transformation/Raw_csv/Psychidae.csv', index = False)
